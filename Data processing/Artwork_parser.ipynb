# %% [markdown]
# This notebook parse the catalogue into atomic artworks.

# %%
from bs4 import BeautifulSoup

from tqdm.autonotebook import tqdm
import pandas as pd
import numpy as np

from string import punctuation
from enum import Enum
import re

import functools

dashes = ["-","—","--"]
# Out:
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\tqdm\autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# # Raw OCR to items parsing

# %%
def parse_page(words_list,target_list,trash_list,parity):
    """ 
    Parse a page into a list of entries. 
  
    Parameters: 
    words_list : list of OCR blocks that represent words.
    target_list : list that gather the valid entries.
    trash_list : control list that gather items that are rejected (header of a page, caption of illustration, etc).
    parity : parity of the page.
  
    """
    
    param = {"even":{"left_threshold":800,"right_threshold":1150},"odd":{"left_threshold":550,"right_threshold":900}}
    artwork_headers = ["*","S","S.","PEINTURES"]
    page_header = set(["MUSÉE","NATIONAL","DU","LOUVRE"]) #"Paris" not included because OCR may give "PARIS" or "PARIS,"
    separator_dashes = ["-","—"]
    
    
    previous_position = float("inf")
    prev_subcontent = False
    
    artwork = []
    
    for word in words_list:
        
        current_position = int(word["HPOS"])
        
        cond_position_left_first_word = current_position < param[parity]["left_threshold"]
        cond_position_right_first_word = previous_position > param[parity]["right_threshold"]
        cond_format_first_word = (word["CONTENT"].strip("()").isdigit() or word["CONTENT"] in artwork_headers)
        
        #Check if new artwork begins here
        if cond_position_left_first_word and cond_position_right_first_word and cond_format_first_word:          
            
            
            #Differentiate real artwork description from page header and picture legends
            cond_artwork_len = len(artwork) > 0
            cond_artwork_vs_header = not page_header <= set(artwork)
            cond_artwork_dash = any(dash in artwork for dash in separator_dashes) # Bad condition - not use
            cond_artwork_capital = not all(word.isupper() or len(word) == 1 \
                                           or all(char in punctuation or char.isdigit() for char in word)for word in artwork)
            
            if cond_artwork_len and cond_artwork_capital:
                target_list.append(artwork)
            else:
                trash_list.append(artwork)
                
            artwork = []
       
        if not prev_subcontent:
            if not word.has_attr("SUBCONTENT"):
                artwork.append(word["CONTENT"])
            else:
                artwork.append(word["SUBCONTENT"])
                prev_subcontent = True
        else:
            prev_subcontent = False
        
        previous_position = current_position

# %%
catalogue_index = range(21,193)

filename_alto = "data/alto_louvre_1923/alto_louvre_1923_{}.xml"

words_pages_even = []
words_pages_odd = []

for i in tqdm(catalogue_index):
    xml_file = open(filename_alto.format(i),"rb")
    xml = xml_file.read()
    xml_file.close()
    
    soup = BeautifulSoup(xml,"lxml-xml")
    
    l = []
    
    for word in soup.findAll("String"):
        l.append(word)
    
    if i%2 == 0:
        words_pages_even.append(l)
    else:
        words_pages_odd.append(l)

raw_artworks_pages = []
trash_list = [] # Detect artworks that would have been thrown away by error when OCR parsing.

for i in range(max(len(words_pages_even),len(words_pages_odd))):
    
    odd = []
    even = []
    trash_odd = []
    trash_even = []
    
    if i < len(words_pages_odd):
        parse_page(words_pages_odd[i],odd,trash_odd,"odd")
    
    raw_artworks_pages.append(odd)
    trash_list.append(trash_odd)
    
    if i < len(words_pages_even):
        parse_page(words_pages_even[i],even,trash_even,"even")

    raw_artworks_pages.append(even)
    trash_list.append(trash_even)
# Out:
# HBox(children=(IntProgress(value=0, max=172), HTML(value='')))

# %%
for n, page in enumerate(raw_artworks_pages):
    print("\nPAGE",n+1)
    for artwork in page:
        print(artwork)
# Out:
# PAGE 1
# ['*', 'Alaux,', 'Jean', "(1786-1864').", '—', 'Poussin', 'arrivant', 'de', 'Rome', 'est', 'présenté', 'par', 'Richelieu', 'au', 'roi', 'Louis', 'XIII.', 'Plafond.', 'Ire', 'S.', 'de', 'la', 'Céramique', 'antique']
# ['*', '-', 'Douze', 'médaillons', "d'or", 'représentant', 'les', 'travaux', "d'", 'Hercule.', 'Voussures.', '—']
# ['2', 'Aligny,', 'Claude-François-Théodore', 'Caruelle', "d'.", '(r', '798-', '1871).', '-', 'Une', 'villa', 'itaJienne.', 'VIII-E']
# ['S.', 'N°', 'Amaury-Duval.', '(1808-1885).', '—', 'Portrait', 'de', 'Mille', 'X..', 'Palier', 'esc.T.T.']
# ['9', 'Aved.', 'André-Joseph.', '(1702-1766).', '—', 'Portrait', 'du', 'marquis', 'de', 'Mirabeau.', 'XVI-S']
# ['*', 'Balze,', 'Paul-Jean-Etienne.', '(1815-1884)', 'et', 'Balze,', 'Ray-', 'mond-Joseph-Antoine.', '(', '1818-1909).', 'Homère', 'déifié,', "d'après", 'Ingres.', 'Plafond.', 'Musée', 'Charles', 'X', 'Salle', 'IX', 'Baptiste,', 'J.-B.', 'Monnoyer', 'dit.', 'Voir', 'Monnoyer.']
# ['2800', 'Barye,', 'Antoine-Louis.', '(1795-1875).', '—', 'Lions', 'près', 'de', 'leur', 'antre.', 'T.', 'T.']
# ['(209)', '—', 'Tigre', 'cherchant', 'une', 'proie.', 'Aquarelle', 'Coll.', 'Camondo']
# ['S.', 'N"', '—', 'Portrait', "d'une", 'fille', 'de', "l'artiste.", 'S.', 'Barye']
# ['S.', 'N"', '—', 'Le', 'Jean-de-Paris,', 'forêt', 'de', 'Fontainebleau', '—']
# ['S.', 'N"', '—', 'Combat', 'de', 'cerfs.', '—']
# ['S.', 'N"', '—', 'Lion', 'mangeant.,.', '—']
#
# PAGE 2
# ['11', 'a', 'Bastien-Lepage,', 'Jules.', '(1848-1884).', '—', 'Portrait', 'de', 'Henri', 'Wallon', 'E.', 'F.', 'XIX', 'S.', '2e', 'étage', 'II']
# ['S.', 'N°', '—', 'Portrait', "d'Edouard,", 'Prince', 'de', 'Galles,', 'plus', 'tard', 'Edouard', 'VII.', '—']
# ['12', 'Baugin,', 'Lubin.', '(vers', '1610-1663).', '—', 'La', 'Sainte', 'Famille', 'XIV-S']
# ['12', 'a', 'Bellangé,', 'Hippolyte.', '(1800-1866)', 'et', 'Dauzats,', 'Adrien.', '(1804-1868).', '—', 'Une', 'revue', 'sous', "l'Empire,", 'aux', 'Tuileries.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['995', 'Bellechose,', 'Henri', '(travaillait', 'à', 'Dijon', 'de', '1415', 'à', '1431,', 'mort', 'vers', '1440).', '-', 'La', 'dernière', 'communion', 'et', 'le', 'martyre', 'de', 'saint', 'Denis,', 'premier', 'évêque', 'de', 'Paris.', '-', ',', ',', ',', 'X']
# ['13', 'a', 'Bellegambe,', 'Jean.', '(I4', '70', '?', '-', '1535).', '—', 'Saint', 'Adrien', '(Attribué).', 'X']
# ['13', 'b', 'Belloc,', 'Jean-Hilaire.', '(1786-1866).', '—', 'Portrait', 'de', 'Mille', 'Belloc', 'et', 'de', 'sa', 'fille;', 'dans', 'le', 'fond', 'le', 'peintre', 'lui-même', 'Esc.', 'T.', 'T.']
# ['14', 'Belly,', 'Léon-Auguste-Adolphe.', '(1827-1N77).', '—', 'Pèle-', 'rins', 'allant', 'à', 'la', 'Mecque', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['14', 'a', '-', 'Vue', 'du', 'Nil.', '—']
# ['14', 'b', '—', 'Pêcheurs', 'le', 'soir.', '—']
# ['16', 'Benoist,', 'Marie-Guilhelmine.', '(r', '768-', 'l', '86).', '—', 'Portrait', "d'une", 'négresse.', 'II-E']
# ['17', 'Benouville,', 'François-Léon.', '(1821-1859».', '—', 'Saint', 'Fran-', 'çois', "d'Assise,", 'transporté', 'mourant', 'à', 'Sainte-', 'Marie-des-Anges,', 'bénit', 'la', 'ville', "d'Assise.", 'VIII-0']
#
# PAGE 3
# ['20', 'Bidault,', 'Jean-Joseph-Xavier.', '(1758-1846).', '-', 'Vue', 'prise', 'de', 'Subiaco', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'I']
# ['21', '—', 'Vue', "d'Avezzano", 'et', 'du', 'lac', 'de', 'Celano', '-']
# ['*', 'Biennoury,', 'Victor-François-Eloi.', '(1823-1893)', '—', 'Les', 'sculptures', 'grecque,', 'romaine,', 'française.', 'Ca-', 'maïeux.', 'Dans', 'les', 'tympans.', 'S.', 'de', 'Mécène']
# ['*', '-', "L'empire", 'romain,', "l'empire", 'français.', 'Camaï-', 'eux.', 'Dans', 'les', 'tympans.', 'S.', "d'Auguste"]
# ['23', 'Blain', 'ou', 'Belin', 'de', 'Fontenay,', 'Jean-Baptiste.', '(1653-', '1715).', '—', 'Vase', "d'or,", 'fleurs', 'et', 'fruits', 'S.', 'Meubles', 'XVIIe']
# ['24', '—', 'Vase', 'doré', 'rempli', 'de', 'fleurs', '—']
# ['25', 'Blanchard,', 'Jacques.', '(16oo-r638).', '—', 'La', 'Charité', 'XIV-S']
# ['S.', 'N°', '—', 'Cimon', 'et', 'Iphigénie.', ',', 'XIV-N']
# ['*', 'Blondel,', 'Merry-Joseph.', '(1781-1853).,', '—', 'Le', 'soleil;', 'la', ',', 'chute', "d'Icare.", 'Coupole', 'circulaire,', 'partie', 'cen-', 'traie.', 'Gai.', "d'Apollon"]
# ['*', '—', 'Différend', 'de', 'Neptune', 'et', 'de', 'Minerve.', 'Plafond,', 'tableau', 'du', 'centre.', 'II']
# ['*', '—', 'Mars.', 'La', 'Paix.', 'Plafond,', 'côtés', 'gauche', 'et', 'droit', 'II']
# ['*', '—', 'La', 'France', 'victorieuse', 'à', 'Bouvines.', 'Plafond', 'S.', 'Meubles', 'XVIIe', 'S.']
#
# PAGE 4
# ['28', 'Boilly,', 'Louis-Léopold.', '(1761-1845).', '—', "L'arrivée", "d'une", 'diligence', 'dans', 'la', 'cour', 'des', 'Messageries', 'à', 'Paris.', 'XVI-N']
# ['28', 'a', '—', 'Les', 'amateurs', "d'estampes.", ',', 'XVI-E']
# ['S.', 'N°', '—', 'Réunion', "d'artistes", 'dans', "l'atelier", "d'Isabey", 'XVI-N']
# ['S.', 'N°', 'Bonheur,', 'Rosa.', '(1822-1899).', '—', 'Labourage', 'nivernais.', 'Marine', '1']
# ['S.', 'N°', 'Borowikoffsky,', 'Wladimir.', '(1757-1825).', '—', 'Portrait', 'de', "l'impératrice", 'Elisabeth', 'de', 'Russie', "(D'après)", '-', '(Ecole', 'russe)', 'Coll.', 'Schlichting']
# ['30', 'Boucher,', 'François.', '(1703-1770).', '—', 'Diane', 'sortant', 'du', 'bain', 'avec', 'une', 'de', 'ses', 'compagnes.', 'XVI-S']
# ['31', '—', 'Vénus', 'commandant', 'à', 'Vulcain', 'des', 'armes', 'pour', 'Enée.', 'XVI-N']
# ['32', '—', 'La', 'bergère', 'endormie.', 'XVI-S']
# ['33', '—', 'La', 'musette.', 'XVI-S']
# ['34', '-', 'Sujet', 'pastoral:', 'Le', 'nid.', 'XVI-N']
# ['35', 'Boucher,', 'François.', '(1703-1770).', '—', 'Sujet', 'pastoral:', 'Berger', 'et', 'bergères.', 'XVI-N']
# ['36', '—', 'Vulcain', 'présentant', 'à', 'Vénus', 'des', 'armes', 'pour', 'Enée', 'XVI-S']
# ['37', '-', 'Vertumne', 'et', 'Pomone.', 'XVI-S']
# ['38', '—', 'Céphale', 'et', "l'Aurore", 'XVI-N']
# ['39', '-', "L'enlèvement", "d'Europe", 'XVI-S']
# ['41', '—', 'Neptune', 'et', 'Amymone', 'Esc.', 'Henri', 'IV']
# ['42', '—', 'Les', 'jeux', 'de', "l'amour", '(La', 'cible', "d'Amour)", 'XVI-N']
# ['43', '—', 'La', 'toilette', 'de', 'Vénus.', 'XVI-N']
# ['44', '—', 'Vénus', 'désarmant', "l'Amour", 'XVI-N']
# ['45', '—', 'Pastorale', "III'1", 'S.', 'Meubles', 'XVIIIe']
# ['45', 'a', '—', "L'oiseau", 'pris', 'dans', 'les', 'filets', 'XVI-N']
# ['46', '—', 'Vénus', 'chez', 'Vulcain.', 'I-E']
#
# PAGE 5
# ['48', 'Boucher,', 'François.', '(1703-1770).', '—', 'Le', 'peintre', 'dans', 'son', 'atelier.', 'I-E']
# ['49', '—', 'Les', 'forges', 'de', 'Vulcain.', 'I-E']
# ['50', '—', 'Portrait', 'de', 'jeune', 'femme', 'I-E']
# ['50', 'a', '—', 'Le', 'déjeuner.', 'XVI-S']
# ['S.', 'N°', '—', 'Renaud', 'et', 'Armide.,', 'XVI-S']
# ['S.', 'N°', '—', 'Paysage.', 'Le', 'pont.', 'XVI-S']
# ['S.', 'N°', '—', 'Paysage.', 'Le', 'moulin.', 'XVI-S']
# ['S.', 'N°', '—', 'Portrait', 'supposé', 'de', 'la', 'Mise', 'de', 'Pompadour', '(Attr.)', 'Coll.', 'Schlichting']
# ['S.', 'N°', '—', "L'Odalisque,", 'Victoire', "O'Murphy.", ';']
# ['S.', 'N°', '—', 'Le', 'sommeil', 'des', 'amours', '—']
# ['S.', 'N°', '—', 'Mme', 'de', 'Pompadour.', 'Pastel.', '(Attribué).', '-']
# ['S.', 'N°', '—', 'Tête', "d'étude.", 'Pastel.', 'S.', 'des', 'Pastels']
# ['(148)', 'Boudin,', 'Eugène-Louis.', '(182.1-1898).', '—', 'Baigneurs', 'sur', 'la', 'plage', 'de', 'Trou', 'ville', '(1869)', 'Coll.', 'Camondo']
# ['(149)', '—', 'La', 'jetée', 'de', 'Dt::auville.', '—']
# ['(150)', '—', 'Voiliers.', '-']
# ['(210)', '—', 'Etude', 'de', 'ciel.', 'Pastd.', '-']
# ['50', 'c', 'Boulanger,', 'Louis.(1806-1867).', '—', 'Portrait', 'de', 'jeune', 'femme', 'E.', 'F.', 'XIX^', 'S.', '1er', 'étage', 'III']
#
# PAGE 6
# ['55', 'Boulogne,', 'Louis,', 'ou', 'de', 'Boullongne.', '(1654-17331.', '—', 'Mariage', 'de', 'Sainte', 'Catherine', 'XIV-N']
# ['56', 'Boulongne,', 'Valentin,', 'dit', 'Le', 'Valentin.', '(1591-1634).', '—', "L'innocence", 'de', 'Suzanne', 'reconnue', 'XV-0']
# ['57', '—', 'Le', 'jugement', 'de', 'Salomon.', 'XV-0']
# ['59', '—', 'Un', 'concert', 'XIV-N']
# ['60', '—', 'Un', 'concert', 'XIV-N']
# ['62', '—', 'Un', 'cabaret', 'XII']
# ['64', 'Bourdon,', 'Sébastien.', '(1616-1671).', '—', 'Le', 'sacrifice', 'de', 'Noé', 'à', 'la', 'sortie', 'de', "l'arche", 'XV-N']
# ['65', '—', 'Salomon', 'sacrifiant', 'aux', 'idoles', 'S.', 'Meubles', 'XVIIe']
# ['69', '—', 'La', 'présentation', 'au', 'temple', 'XIV-S']
# ['70', '—', 'Le', 'Christ', 'et', 'les', 'enfants', 'XIV-N']
# ['74', '—', 'Auguste', 'devant', 'le', 'tombeau', "d'Alexandre", 'XIV-S']
# ['45', 'FR.', 'BOUCHER', '5°', 'FR.', 'BOUCHER']
# ['75', 'Bourdon,Sébastien.(1616-1671).', 'UnehaltedeBohémiens', 'XIV-N']
# ['76', '—', 'Les', 'mendiants.', 'XIV-S']
# ['77', '—', 'Scène', "d'intérieur.", 'I-E']
# ['78', '—', 'Portrait', 'de', 'René', 'Descartes', 'XIV-N']
# ['80', '—', 'Son', 'portrait', 'par', 'lui-même.', 'XIV-N', 'Bourguignon,', 'Jacques', 'Courtois,', 'dit', 'le.', '-', 'Voir', 'Courtois']
# ['S.', 'N°', 'Boze,', 'Joseph,', '(vers', '1746-1826).', '—', 'Portrait', 'de', 'Boze,', 'par', 'lui-même.', 'Pastel.', 'S.', 'des', 'Pastels']
# ['S.', 'N°', '—', 'Le', 'duc', "d'Angoulême,", 'enfant.', 'Pastel', '-']
# ['S.', 'N°', '—', 'Portrait', 'de', 'Madame', 'de', 'Provence', 'en', 'robe', 'blanche.', 'Pastel.,..', '-']
#
# PAGE 7
# ['83', 'Brascassat,', 'Jacques-Raymond.', '(1804-1867).', '—', 'Pay-', 'sage', 'et', 'animaux', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'I']
# ['S.', 'o', 'Breton,', 'Jules.', '(1827-1906)', '—', 'Le', 'rappel', 'des', 'glaneuses', 'en', 'Artois.', 'Marine', '1']
# ['S.', 'N°', '—', 'La', 'bénédiction', 'des', 'blés', 'en', 'Artois', '—']
# ['S.', 'N°', '—', 'La', 'glaneuse', '—', 'Brun,', '(Charles', 'Le)', 'et', 'Brun', '(Mme', 'Vigée', 'Le).', '—', 'Voir', 'Le', 'Brun', 'S.', 'N°', 'Bureau,', 'Pierre-Isidore.', '(1822-1876).', '—', 'Clair', 'de', 'lune', 'sur', 'les', 'bords', 'de', "l'Oise", 'à', "l'Isle", '-', 'Adam', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'N°', '—', 'La', 'route', '-', 'III']
# ['2931', 'Cabat,', 'Louis-Nicolas.', '(1812-1893).', '—', "L'étang", 'de', "Vilk-d'Avray.", 'E.', 'F', 'XIXe', 'S.', '2e', 'étage', '1']
# ['85', 'Callet,', 'Antoine-François.', '(1741-1823).', '—', 'Les', 'Satur-', 'nales', 'ou', "l'Hiver.", 'XVI-E']
# ['86', '—', "L'Automne", 'ou', 'les', 'fêtes', 'de', 'Bacchus.', 'XVI-E']
# ['87', '—', 'Le', 'triomphe', 'de', 'Flore.', '1-0']
# ['*', '—', 'Le', 'printemps.', 'Plafond.', 'Gai.', "d'Apollon"]
# ['2932', 'Cals,', 'Adolphe-Félix.', 'i', 'i', 'S', 'i', 'o-', 'i', 'SSo).', '—', 'Femmes', 'effilant', 'de', "l'étoupe", 'E.', 'F.', 'XIXe', 'S.2e', 'étage', 'II']
# ['2933', '—', 'Lard', 'et', 'harengs', '—']
# ['2934', '—', 'Soleil', 'couchant.', '—']
# ['2935', '—', 'Etude', 'de', 'femme.', '2936', '—', 'Le', 'déjeuner', 'à', 'Honfleur..,.', '—']
# ['*', 'Carolus-Duran,', 'Emile-Auguste.', '11837-1917).', '-', 'Le', 'tri-', 'omphe', 'de', 'Marie', 'de', 'Médicis.', 'Plafond.', '4me', 'S.', 'Meubles', 'XVIIIme']
# ['87', 'a', 'Carpeaux,', 'Jean-Baptiste.', '(1827-1875).', '—', 'Bal', 'costumé', 'aux', 'Tuileries', '1867', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['87', '1,', '-', 'Bal', 'aux', 'Tuileries', '1867.', '-']
# ['87', 'c', '—', "L'attentat", 'de', 'Berezowski', 'au', 'bois', 'de', 'Boulogne', '(Juillet', '1867)', '.,.', '—']
# ['(151)', 'Cézanne,', 'Paul.', '1839-1906).', '—', 'La', 'maison', 'du', 'pendu', 'à', 'Auvers-sur-Oise', 'Coll.', 'Camondo']
# ['(152)', '—', 'Dahlias', 'dans', 'un', 'vase', 'en', 'faïence', 'de', 'Delft', '-']
# ['(153)', '—', 'Les', 'joueurs', 'de', 'cartes.', '-']
# ['(154)', '—', 'Le', 'vase', 'bleu.', 'Iris', 'et', 'pois', 'de', 'senteur', '—']
# ['(155)', '—', 'Pommes', 'et', 'oranges.', '-']
# ['S.', 'N"', 'Challes,', 'Noël', '(milieu', 'du', 'XVIIIe', 'S.)', '-', "L'amour", '(Attr.)', 'Coll.', 'Schlichting']
# ['S.', 'N"', '—', 'Bacchus', ',', 'Attribué)', '—']
#
# PAGE 8
# ['89', 'Chardin,', 'Jean-Baptiste-Siméon.', '(1699-1779).', '—', 'La', 'raie,', 'ou', 'le', 'chat', 'dans', 'le', 'garde-manger', 'XVI-N']
# ['90', '—', 'Le', 'buffet.', 'Fruits,', 'chien', 'et', 'perroquet.', 'XVI-N']
# ['90', 'a', '—', "L'enfant", 'au', 'toton.', 'Portrait', 'de', 'Gabriel', 'Gode-', 'froy,', 'fils', 'cadet', 'du', 'joaillier', 'Ch.', 'Godefroy.', 'XVI-N']
# ['90', 'b', '—', 'Le', 'jeune', 'homme', 'au', 'violon.', 'Portrait', 'de', 'Char-', 'les', 'Godefroy,', 'frère', 'aîné', 'du', 'précédent.', 'XVI-N']
# ['91', '—', 'La', 'mère', 'laborieuse', 'XVI-N']
# ['92', '—', 'Le', 'bénédicité', 'XVI-N']
# ['93', '—', 'Le', 'bénédicité', '1-0']
# ['94', '—', 'Lapin', 'mort', 'et', 'ustensiles', 'de', 'chasse.', 'XVI-S']
# ['95', 'Chardin,', 'Jean-Baptiste-Siméon.', '(1699-1779).', '-', 'Menu', 'de', 'maigre.', 'XVI-N']
# ['96', '—', 'Menu', 'de', 'gras.', 'XVI-N']
# ['97', '—', 'Le', 'singe', 'antiquaire.', 'XVI-S']
# ['98', '—', 'Les', 'attributs', 'des', 'arts.', 'XVI-S']
# ['99', '—', 'La', 'pourvoyeuse,.', 'XVI-N']
# ['100', '—', 'Les', 'attributs', 'de', 'la', 'musique.', 'XVI-S']
# ['101', '—', 'Ustensiles', 'variés.', 'Pipe', 'et', 'vases', 'à', 'boire,', 'sur', 'une', 'table', 'de', 'pierre.', 'XVI-N']
# ['102', '—', 'Panier', 'de', 'pêches', 'sur', 'une', 'table', 'de', 'pierre', 'XVI-N']
# ['103', '—', 'Le', 'château', 'de', 'cartes.', '1-0']
# ['104', '—', 'Le', 'singe', 'peintre.', 'I-E']
# ['105', '—', 'Melon,', 'poires', 'et', 'pêches', '1-0']
# ['106', '—', 'Raisins', 'et', 'grenades.', ',', '1-0']
#
# PAGE 9
# ['108', 'Chardin,', 'Jean-Baptiste-Siméon.', '(1699-1779).', '—', 'La', 'fontaine', 'de', 'cuivre,', 'I-E']
# ['109', '—', 'Un', 'dessert.', '1-0']
# ['110', '—', 'Pêches,', 'noix,', 'raisins', 'et', 'verre', 'de', 'vin.,', 'I-E']
# ['111', '—', 'Ustensiles', 'divers.', '1-0']
# ['112', '—', 'Poires', 'et', 'verre', 'de', 'vin.', '1-0']
# ['113', '—', 'Le', 'gobelet', "d'argent.,", '1-0']
# ['114', '—', 'La', 'table', 'de', 'cuisine.', '1-0']
# ['115', '—', 'Le', 'panier', 'de', 'raisins.', '1-0']
# ['116', '—', 'Ustensiles', 'de', 'cuisine', 'et', 'œufs.', ',', 'I-E']
# ['117', 'Chardin,', 'Jean-Baptiste-Siméon.', 'nooo-tyyo).', '—', 'Les', 'apprêts', 'du', 'pot-au-feu.', '(Attribué).', '1-0']
# ['118', '-', 'Le', 'retour', 'de', "l'école.", '(École', 'dei.', 'I-E']
# ['S.', 'N°', '--', 'Le', 'souffleur.', ',', ',', 'XVI-S']
# ['S.', 'X"', '—', 'Portrait', 'en', 'buste', 'de', 'la', 'femme', 'de', 'Chardin.', 'Pastel.', 'S.', 'des', 'Pastels']
# ['S.', 'N"', '-', 'Portrait', 'de', 'Chardin', 'par', 'lui-même,', 'avec', 'abat-jour', 'vert', 'par-dessus', 'le', 'bonnet', 'blanc.', 'Pastel.', '—']
#
# PAGE 10
# ['120', 'Chassériau,', 'Théodore.', '(1819-1856).', '-', 'Le', 'tepidarium', 'E.F.', 'XIXe', 'S.', '2e', 'étage', 'I']
# ['121', '—', 'La', 'chaste', 'Suzanne', 'VIII-N']
# ['121', 'a', '—', 'La', 'Paix.', 'Fragment', 'de', 'décoration', 'provenant', 'de', 'la', 'Cour', 'des', 'Comptes', 'Palier', 'esc.T.', 'T']
# ['121', 'b', '—', 'Une', 'Océanide', '-', '-', '-']
# ['121', 'c', '—', 'Le', 'père', 'Lacordaire', 'VIII-0', ',', '121', 'd', '—', 'Portrait', 'du', 'peintre', 'Marilhat..', ',', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['S.', 'N°', '—', 'Portrait', 'de', 'Melle', 'Adèle', 'Chassériau', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['S.', 'N°', '—', 'Les', 'deux', 'soeurs', 'de', "l'artiste", 'VIII-0']
# ['S.', 'N°', '—', 'Caïd', 'visitant', 'un', 'douar.', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'I']
# ['S.', 'N°', '—', 'Vénus', 'marine', '-', 'II']
# ['S.', 'N°', '—', 'Chefs', 'arabes', 'se', 'défiant', 'en', 'combat', 'singulier', '-', 'II']
# ['S.', 'N°', '—', 'Macbeth', 'rencontre', 'les', 'sorcières', 'sur', 'la', 'bruyère', '-', 'II']
# ['123', 'Chintreuil,', 'Antoine.', '(1814-1873).', '—', "L'espace", 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'I']
# ['125', '—', 'Pluie', 'et', 'soleil.', ',', '—']
# ['125', 'a', '—', 'Etude.', '—', 'H']
# ['125', 'a', '—', 'Etude', '—']
# ['125', 'a', '—', 'Le', 'bateau', 'abandonné,', 'Villebon,', 'étude.', '—']
# ['125', 'a', '—', 'Etude', 'de', 'paysage', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'II']
# ['126', 'Clouet', '(attribué', 'à)', 'Jean,', 'dit', 'Jehannet,', 'Jeannet', 'ou', 'Janet.', '(vers', '14', '75-1540).', '—', 'Portrait', 'de', 'Fran-', 'çois', 'Ier,', 'roi', 'de', 'France', 'XI']
# ['127', '—', 'Portrait', 'de', 'François', '1er,', 'roi', 'de', 'France', 'XI']
#
# PAGE 11
# ['128', 'Clouet,', 'François,', 'dit', 'Jehannet,', 'ou', 'Janet.', '(mort', 'en', '1572).', '-', 'Portrait', 'de', 'Charles', 'IX,', 'roi', 'de', 'France', 'i', "D'après)", 'XI']
# ['129', '—', 'Portrait', 'de', 'Henri', 'H,', 'roi', 'de', 'France.', "(D'aprèsi", 'XI']
# ['130', '—', 'Portrait', "d'Elisabeth", "d'Autriche,", 'reine', 'de', 'France,', 'femme', 'de', 'Charles', 'IX', '(Attribué).', 'XI']
# ['131', '—', 'Portrait', 'de', 'François', 'de', 'Lorraine,', 'duc', 'de', 'Guise,', 'tué', 'au', 'siège', "d'Orléans", 'en', '1563.', '(réplique', 'présumée)', '.,.,.', 'XI']
# ['131', 'a', '—', 'Portrait', 'de', 'Henri', 'II,', 'en', 'buste', '(réplique', 'présumée', '1', 'XI']
# ['132', '—', 'Portrait', 'de', 'Charles', 'IX,', 'en', 'buste,', '(réplique', 'présumée).', 'XI']
# ['133', '—', 'Portrait', "d'Elisabeth", "d'Autriche,", 'reine', 'de', 'France,', 'femme', 'de', 'Charles', 'IX,', 'en', 'buste,', 'avec', 'toque', 'à', 'plumes', '(réplique', 'présumée)', '-', 'XI']
# ['133', 'a', '—', 'Portrait', 'de', 'Claude', 'de', 'Beaune,', 'dame', 'de', 'Château-', 'brun,', 'duchesse', 'de', 'Roannois', '(réplique', 'présumée)', 'XI']
# ['133', 'b', '—', 'Portrait', 'de', 'Jean', 'Babou,', 'seigneur', 'de', 'la', 'Bour-', 'daisière,', 'maréchal', 'général', 'de', "l'artillerie", 'en', '1567', '(réplique', 'présumée)', 'XI']
# ['S.', 'X"', '-', 'Portrait', 'de', 'François', 'Ier', 'à', 'cheval;', 'miniature', '(Ec.', 'de)', 'XI']
# ['*', '—', 'Portrait', 'de', 'Henri', 'II', "(d'après,", 'par', 'Gé-', 'rôme)', 'IIlme', 'S.', 'de', 'la', 'Colonnade']
# ['134', '—', 'Portrait', 'de', 'Louis', 'de', 'Saint-Gelais,', 'dit', 'de', 'Lezignem,', 'baron', 'de', 'La-Mothe-Saint-Héraye', 'seigneur', 'de', 'Lansac', '(Ecole', 'de).', 'XI']
# ['135', 'Cochereau,', 'Léon-Mathieu.', '(1793-1817).', '-', 'Intérieur', 'de', "l'atelier", 'des', 'élèves', 'de', 'David', 'au', 'Collège', 'des', 'Quatre', 'Nations,', 'à', 'Paris.', 'III-E']
# ['*', 'Cogniet,', 'Léon.', '(', '1794-1KN0).', '—', 'Plafond:', 'Expédition', "d'Egypte", 'sous', 'les', 'ordres', 'de', 'Bonaparte.', '—', 'Voussures', ':', 'Bataille', "d'Aboukir,", 'Révolte', 'du', 'Caire,', 'le', 'Pardon', 'aux', 'révoltés', 'du', 'Caire,', 'Peste', 'de', 'Jaffa.', 'S.', 'des', 'fresques', 'et', 'verres', 'antiques', 'i^l)', 'Constant,', 'Benjamin.', '(1815-1902).', 'Portrait', "d'A.", 'Chau-', 'chard', 'Coll.', 'Chauchard', 'III']
#
# PAGE 12
# ['138', 'Corot,', 'Jean-Baptiste-Camille.', '(1796-1875).', '—', 'Une', 'matinée.', 'La', 'danse', 'des', 'nymphes.', 'VIII-0']
# ['139', '—', 'Vue', 'du', 'Forum', 'romain', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['140', '—', 'Vue', 'du', 'Colisée,', 'à', 'Rome.', '-']
# ['141', '—', 'Paysage.', 'Souvenir', 'de', 'Mortefontaine', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['141', 'a', '—', 'Chevrier', 'italien;', 'effet', 'de', 'soleil', 'couchant', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['141', 'b', '—', 'Souvenir', 'de', 'Castel-Gondolfo;', 'paysage', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['141', 'c', '—', 'Madeleine', 'lisant.', '2e', '—', '1']
# ['141', 'd', '—', 'Le', 'repos', 'des', 'chevaux.', '—', '1']
# ['141', 'e', '—', 'Les', 'baigneuses.', '—', '1']
# ['141', 'f', 'Corot,', 'Jean-Baptiste-Camille.', '(1796-1875).', '—', 'Le', 'beffroi', 'de', 'Douai', '1871', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'N°', '—', 'Venise.', 'La', 'piazetta,', '1834', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['S.', 'N°', '—', 'Le', 'coup', 'de', 'vent', '—', 'II']
# ['S.', 'N°', '—', 'Homme', 'en', 'armure.', 'Palier', 'esc.', 'T.', 'T.']
# ['S.', 'N°', '-', 'Portrait', 'de', 'Melle', 'Sennegon,', 'nièce', 'de', "l'artiste", 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'N°', '—', 'Intérieur', 'de', 'la', 'cathédrale', 'de', 'Sens', '—', 'II']
# ['S.', 'N°', '—', 'Portrait', 'de', 'femme,', 'dite', 'la', 'femme', 'à', 'la', 'perle..', 'VIII-N']
#
# PAGE 13
# ['S.', 'N°', 'Corot,', 'Jean-Baptiste-Camille.', '(1796-1875).', '—', 'La', 'Trinité-des-Monts,', 'vue', 'de', "l'Académie", 'de', 'France', 'à', 'Rome', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'II']
# ['2801', '—', 'Le', 'vallon.', 'T.', 'T.']
# ['2802', '—', 'La', 'porte', 'de', 'jerzual', 'à', 'Dinan.', 'T.', 'T.']
# ['2803', '—', 'Le', 'chemin', 'de', 'Sevrés.', 'T.', 'T.']
# ['2804', '—', 'Danse', 'de', 'bergers', 'de', 'Sorrente', 'T.', 'T.']
# ['2805', '—', 'La', 'Saulaie.', ',.', 'T.', 'T.']
# ['2806', '—', 'Souvenir', "d'Italie.", 'T.', 'T.']
# ['2807', '—', "L'étang.", 'T.', 'T.']
# ['2808', '—', 'Entrée', 'de', 'village', '(environs', 'de', 'Beauvais)', 'T.', 'T.']
# ['2809', 'Corot,', 'Jean-Baptiste-Camille.', '(1796-1875).', '—', 'Les', 'chaumières.', 'T.', 'T.']
# ['2810', '—', 'La', 'route', 'de', 'Sin-le-Noble,', 'près', 'Douai', '(dite', 'la', 'Route', "d'Arras!", ',', 'T.', 'T.']
# ['2811', '—', 'Le', 'soir.', ',', ',', 'T.', 'T.']
# ['2812', '—', "L'églogue.", 'T.', 'T.']
# ['(2)', '—', 'Le', 'pêcheur', 'en', 'barque', 'sur', "['étang", 'Coll.', 'Chauchard,', 'galerie']
# ['(3)', '-', 'La', 'charrette.', 'Souvenir', 'de', 'Marcoussis.', '—']
# ['(4)', '-', 'Une', 'soirée.', ',', '—', 'II']
#
# PAGE 14
# ['(6)', 'Corot,', 'Jean-Baptiste-Camille.', '(1796-1875).', '—', 'Che-', 'vrier', 'jouant', 'de', 'la', 'flûte', 'dans', 'une', 'clairière', 'Coll.', 'Chauchard,', 'IV']
# ['(7)', '—', 'Nymphe', 'désarmant', "l'Amour.", '—', 'IV']
# ['(8)', '—', 'Danse', 'des', 'nymphes.', '—', 'IV']
# ['(9)', '—', 'Les', 'chevriers', 'des', 'lies', 'Borroiiiées', '—', 'IV']
# ['(10)', '—', 'La', 'route', '—', 'IV']
# ['(11)', '—', 'Le', 'matin,', 'ou', 'la', 'clairière', 'au', 'lever', 'du', 'jour', '—', 'galerie']
# ['(12)', '-', "L'étang", 'de', 'Ville', "d'Avray", '—', 'III']
# ['(13)', '—', 'Le', 'passeur.', '—', 'III']
# ['(14)', '—', 'Le', 'pâtre', 'devant', "l'étang.", '—', 'galerie']
# ['(15)', '—', 'Le', 'repos', 'sous', 'les', 'saules', '—', 'galerie']
# ['(16)', '—', 'Le', 'passage', 'du', 'gué.', '—', 'galerie']
# ['(17)', '—', 'Le', 'matin.', '—', 'IV']
# ['(18)', 'Corot,', 'Jean-Baptiste-Camille.', '(171)6-18751.', '—', 'Le', 'soir', 'Coll.', 'Chauchard,', 'IV']
# ['(19)', '—', 'Le', 'catalpa.', 'Souvenir', 'de', 'Ville', "d'A\\Tay.", '—', 'IV']
# ['(20)', '—', 'La', 'clairière.', 'Souvenir', 'de', 'Ville', "d'Avray", '—', 'IV']
# ['(21)', '—', 'Les', 'marécages', 'à', 'la', 'Tour', 'carrée', '—', 'galerie']
# ['(22)', '—', 'La', 'levée', 'des', 'htets.', '—', '1']
# ['(23)', '—', 'Le', 'pont', 'de', 'Palluel', '—', 'III', '(24>', '—', 'La', 'danse', 'des', 'bergères.', 'Souvenir', "d'Arleux", '-', 'galerie']
# ['(25)', '—', 'Près', 'Arras.', 'Les', 'bûcheronnes.', '—', 'IV']
# ['(26)', '—', 'Souvenir', 'des', 'Landes.', '—', 'IV']
# ['(27', '—', 'Le', 'Moulin', 'de', 'Saint-Nicolas-lès-Arras', '—', '1']
# ['(156)', '-', 'Fillette', 'à', 'sa', 'toilette', 'Coll.', 'Camondo']
#
# PAGE 15
# ['*', 'Couder,', 'Louis-Charles-Auguste.', '(1790-1873).', '—', 'La', 'Terre;', 'combat', "d'Hercule", 'et', "d'Antée.", '—', "L'eau:", 'Achille', 'près', "d'être", 'englouti', 'par', 'le', 'Xanthe', 'et', 'le', 'Simoïs.', '—', 'Le', 'feu:', 'Vénus', 'recevant', 'de', 'Vul-', 'cain', 'les', 'armes', 'pour', 'Enée', 'Vestibule', 'Galerie', "d'Apollon,", 'Coupole']
# ['143', 'Courbet,', 'Gustave.', '(1819-1877).', '—', 'Un', 'enterrement', 'à', 'Ornans.', 'VIII-E']
# ['144', '—', "L'homme", 'blessé..', ',', '.,', 'VIII-S']
# ['144', 'a', '—', 'Portrait', 'de', 'Champfleury.', ',', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['145', '—', 'Combat', 'de', 'cerfs', 'VIII-E']
# ['145', 'a', '—', 'Remise', 'de', 'chevreuils', 'VIII-0']
# ['146', '—', 'Chevreuil', 'sous', 'bois', 'E.', 'F.', 'XIXe', "S'", '1er', 'étage', 'II']
# ['146', 'a', '1', '—', 'Le', 'ruisseau', 'couvert', '—']
# ['147', 'Courbet,', 'Gustave.', '(1819-1877).', '—', "L'homme", 'à', 'la', 'ceinture', 'de', 'cuir.', 'Son', 'portrait,', 'par', 'lui-même', 'VIII-E']
# ['147', 'a', '—', 'La', 'mer', 'orageuse', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['S.', 'N°', '-', 'La', 'source.', ';', 'VIII-E']
# ['S.', 'N°', '—', "L'atelier", 'du', 'peintre,', 'allégorie', 'réelle.', 'VIII-E']
# ['S.', 'N°', '—', 'Portrait', 'de', 'Berlioz', '(en', 'buste,', 'de', 'trois', 'quarts', 'à', 'droite1)', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'I']
# ['151', 'Courtois,', 'Jacques,', 'dit', 'le', 'Bourguignon.', '(1621-1676).', '—', 'Combat', 'de', 'cavalerie', 'XIV-N']
# ['155', 'Cousin', 'le', 'fils,', 'Jean.', '\\mort', 'vers', '1592).', '-', 'Le', 'Jugement', 'dernier', 'XI']
#
# PAGE 16
# ['157', 'Coypel,', 'Noël.', '(1628-1707).', '—', 'Solon', 'défendant', 'ses', 'lois', 'devant', 'les', 'Athéniens.', 'XIV-S']
# ['158', '—', 'Ptolémée', 'Philadelphe', 'donnant', 'la', 'liberté', 'aux', 'juifs', 'XIV-N']
# ['159', '—', 'Trajan', 'donnant', 'des', 'audiences', 'publiques', 'XIV-N']
# ['160', '—', 'Alexandre', 'Sévère', 'faisant', 'distribuer', 'du', 'blé', 'au', 'peuple,', 'XIV-S']
# ['162', '—', 'Hercule', 'combattant', 'Acheloüs', 'S.', 'Blarenberghe']
# ['163', '—', 'Hercule,', 'Déjanîre', 'et', 'le', 'centaure', 'Nessus', '—']
# ['164', '—', 'Apollon', 'couronné', 'par', 'la', 'Victoire.', 'XIV-S']
# ['S.', 'N°', '—', 'Deux', 'Cartons', 'de', 'bandes', 'de', 'tapisserie.', 'Esc.', 'Daru']
# ['S.', 'N°', '—', 'Quatre', 'Cartons', 'de', 'bandes', 'de', 'tapisserie', 'XIV-N']
# ['167', 'Coypel,', 'Antoine.', '(1661-1722).-', 'Athalie', 'chassée', 'du', 'temple', 'XVI-N']
# ['170', '—', 'Esther', 'en', 'présence', "d'Assuérus.", 'XVI-N']
# ['172', '—', 'Une', 'jeune', 'fille', 'caressant', 'un', 'chien', 'XVI-S']
# ['174', '—', 'Démocrite.', 'I-E']
# ['176', 'Coypel,', 'Noël-Nicolas.', '(1692-1734).', '—', 'Vénus,', 'Bacchus', 'et', "l'Amour", 'Esc.', 'Henri', 'IV']
# ['177', '—', "L'Innocence", 'et', "l'Amour", 'XVI-S']
# ['178', '—', 'Nymphe', 'et', 'Amour.', 'XVI-S']
# ['180', 'Coypel,', 'Charles-Antoine.', '(1694-17521.', '—', 'Persée', 'dé-', 'livrant', 'Andromède.', 'XVI-N']
# ['182', '—', 'Portrait', 'de', "l'acteur", 'Jelyotte', 'en', 'costume', 'de', 'femme', 'I-S']
# ['S.', 'N"', 'Danloux,', 'Henri-Pierre.', '(1753-1809:.', '—', 'Portrait', 'de', 'M.', 'Délavai.', 'XVI-E']
# ['S.', 'o', '-', 'Portrait', 'de', 'Mgr.', 'J.-F.', 'De', 'la', 'Marche,', 'évêque', 'de', 'S1.', 'Pol', 'de', 'Léon.,.', 'XVI-E']
# ['S.', 'N"', '-', 'Jeune', 'fille', '(Attribué)', 'Coll.', 'Schlichting']
# ['S.', 'N"', '-', 'Les', 'petits', 'espiègles.', ',', '—']
# ['184', 'Daubigny,', 'Charles-François.', 'Ils', '1', 'ï-', 'r', "SIS)'", '-', 'Les', 'vendanges', 'en', 'Bourgogne.,.', 'VIII-N']
# ['184', 'il', '—', 'La', 'mare.', '(La', 'grande', 'vallée', "d'Optevoz)", 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
#
# PAGE 17
# ['185', 'a', 'Daubigny,', 'Charles-François.', '(1817-', '1878).', '—', 'La', 'moisson', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'I']
# ['2813', '—', 'Un', 'coin', 'de', 'NormanJie', 'T.', 'T.']
# ['2814', '—', 'Le', 'marais.', 'T.', 'T.']
# ['2815', '—', 'La', 'mare', 'aux', 'cigognes', 'T.', 'T.']
# ['2816', '—', 'Soleil', 'couchant', 'T.', 'T.']
# ['2817', '—', 'Les', 'graves', 'de', 'Vi11erville.', ',', 'T.', 'T.']
# ['2818', '—', 'La', 'vanne', "d'Optevoz.", ',', ',', 'T.', 'T.']
# ['2819', '—', 'Bateaux', 'sur', "l'Oise..,.", ',', 'T.', 'T.']
# ['2820', '—', 'Les', 'péniches.,.', 'T.', 'T.']
# ['2821', '—', 'La', 'Tamise', 'à', 'Erith.', 'T.', 'T.']
# ['2822', '—', 'Le', 'moulin', 'de', 'Gylieu', 'T.', 'T.']
# ['2823', '—', 'Les', 'bords', 'de', "l'Oise.", 'T.', 'T.']
# ['2824', '—', 'Le', 'matin.', 'T.', 'T.']
# ['2825', '—', "L'étang.,.", 'T.', 'T.']
# ['(28)', 'Daubigny,', 'Charles-François.', '(1817-1878).', '—', 'La', 'Seine', 'à', 'Bezons.', 'Coll.', 'Chauchard,', 'galerie']
# ['(29)', '—', 'Gardeuse', 'de', 'dindons.', '—']
# ['(30)', '—', 'Les', 'laveuses', '-', 'Effet', 'de', 'soleil', 'couchant.', '—', '1']
# ['(31)', '—', 'Soleil', 'couchant', 'sur', "l'Oise", '-', 'II']
# ['(32)', '—', 'La', 'vallée', "d'Arques..,.", '—', 'galerie']
# ['(33)', '—', 'La', 'mare', 'au', 'Clair', ':', '—', 'III']
# ['(34)', '—', 'Bords', 'de', "l'Oise,", 'le', 'pêcheur.,.', '—', 'II']
# ['2937', 'Daumier,', 'Honoré.', '(1808-1879).', '—', 'Les', 'voleurs', 'et', "l'âne", 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['S.', 'N°', '—', 'Crispin', 'et', 'Scapin.,.', 'VIII-S']
# ['S.', 'N"', 'Dauzats,', 'Adrien.', '(1804-1868).', '—', 'Le', 'couvent', 'du', 'mont', 'Athos.,', '.,.,', 'Palier', 'esc.', 'T.', 'T.']
# ['186', '—', 'Vue', 'intérieure', "d'une", 'église', "d'Espagne", 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['186', 'a', '—', 'La', 'giralda', 'à', 'Séville.', '2e', 'II']
#
# PAGE 18
# ['187', 'David,', 'Jacques-Louis.', '(1748-1825).', '—', 'Léonidas', 'aux', 'Thermopyles.', 'III-N']
# ['188', '—', 'Les', 'Sabines..', ',', ',', 'II-S']
# ['189', '—', 'Le', 'serment', 'des', 'Horaces.', '111-0']
# ['190', '-', 'Le', 'serment', 'des', 'Horaces;', 'esquisse', 'du', 'tableau', 'précédent..', ',', ',', ',', ',', '11-0']
# ['191', '-', 'Les', 'licteurs', 'rapportant', 'à', 'Brutus', 'les', 'corps', 'de', 'ses', 'fils.', '111-0']
# ['192', '—', 'Bélisaire', 'demandant', "l'aumône", 'III-E']
# ['193', '—', 'Combat', 'de', 'Minerve', 'contre', 'Mars', '111-0']
# ['194', '—', 'Les', 'amours', 'de', 'Pâris', 'et', "d'Hélene.,.", '111-0']
# ['195', '—', 'Figure', 'académique', '(Patrocle)', 'II-S']
# ['196', '—', 'Portrait', 'de', 'M.', 'Pécoul,', 'entrepreneur', 'des', 'bâti-', 'ments', 'du', 'roi,', 'beau-père', 'de', 'David', 'III-E']
# ['197', '—', 'Portrait', 'du', 'Mme', 'Pécoul,', 'femme', 'du', 'précédent.', 'III-E']
# ['199', 'J.-L.', 'DAVID', '202', 'il', 'J.-L.', 'DAVID']
# ['197', 'a', 'David,', 'Jacques-Louis.', '(1748-1825).', '—', 'Portrait', 'de', 'Monsieur', 'Sériziat', 'III-N']
# ['197', 'b', '—', 'Portrait', 'de', 'Madame', 'Sériziat', 'III-N']
# ['198', '—', 'Portrait', 'du', 'pape', 'Pie', 'VII', '111-0']
# ['199', '—', 'Portrait', 'de', 'Mrae', 'Récamier.', 'III-N']
# ['199', 'a', '—', 'Portrait', 'de', 'Mme', 'Chalgrin', 'III-E']
# ['200', '—', 'Portrait', "d'Antoine", 'Mongez,', 'membre', 'de', "l'Insti-", 'tut,', 'administrateur', 'des', 'Monnaies,', 'et', 'de', 'Mme', 'Mongez,', 'Angélique', 'Levol,', 'peintre', '111-0']
# ['200', 'a', '-', 'Les', 'trois', 'dames', 'de', 'Gand.', 'Portraits', 'de', 'Madame', 'Morel', 'de', 'Tangry', '(née', 'van', 'Thiegem)', 'et', 'de', 'ses', 'deux', 'filles.', '111-0']
# ['201', '—', 'Portrait', 'de', 'Bailly.', 'I-S']
# ['202', '—', 'Portrait', 'de', 'David', 'dans', 'sa', 'jeunesse', 'III-E']
#
# PAGE 19
# ['S.', 'X"', 'David,', 'Jacques-Louis.', '(1748-1825).', '-', 'Portrait', 'de', 'Catherine', 'Marie', 'Jeanne', 'Tallard,', '1795.', 'III-E']
# ['S.', 'o', '—', 'Portrait', 'du', 'conventionnel', 'Milhaud,', 'représentant', 'du', 'peuple', '111-0']
# ['S.', 'X"', '—', 'Portrait', 'de', "l'acteur", 'Wolf,', 'dit', 'Bernard.', '111-0']
# ['S.', 'X"', '—', 'Portrait', "d'Alexandre", 'Lenoir,', '1817', '11-0']
# ['S.', 'X"', '-', 'Vue', 'du', 'jardin', 'du', 'Luxembourg', 'en', '1794', 'III-E']
# ['203', 'Debar,', 'Bonaventure.', '(1700-1729).', '—', 'Fête', 'champêtre', 'XVI-N']
# ['204', 'Decamps,', 'Alexandre-Gabriel.', '(1803-1860).', '—', 'Les', 'chevaux', 'de', 'halage', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['205', '—', 'La', 'caravane', ';', 'esquisse', '—', 'II']
# ['205', 'a', '—', 'Paysage', '—', 'II']
# ['205', 'b', '—', 'La', 'défaite', 'des', 'Cimbres', 'VIII-S', 'H)7', 'J.-L.', 'DAVID', '(Ibo)', 'E.', 'DEGAS']
# ['205', '(', 'Decamps,', 'Alexandre-Gabriel.', '(1S03-1X60L', '—', 'Murs', "d'Aigues-Mortes", 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'I']
# ['206', '-', 'Bouledogue', 'et', 'terrier', 'écossais:', '—', 'II']
# ['2826', '—', 'Le', 'singe', "pt'intre.", '-', '-', ',..', 'T.', 'T.']
# ['2827', '-', 'Une', 'rue', 'de', 'Smyrne.', '-', 'T.', 'T.']
# ['2828', '—', 'Chiens', 'de', 'chasse', 'au', 'repos.', 'T.', 'T.']
# ['2829', '-', 'Chiens', 'bassets.', 'T.', 'T.']
# ['2830', '—', 'Chien', 'basset', 'noir', 'et', 'blanc,', 'au', 'chenil', 'T.', 'T.']
# ['2831', '—', 'Le', 'remouleur', 'T.', 'T.']
# ['2832', '—', 'Les', 'sonneurs.', 'T.', 'T.']
# ['2833', '—', 'Le', 'campement', 'des', 'bohémiens', 'T.', 'T.']
# ['2834', '—', 'Le', 'rat', 'retiré', 'du', 'monde', 'T.', 'T.']
#
# PAGE 20
# ['2836', 'Decamps,', 'Alexandre-Gabriel.', '(1803-1860).', '—', 'Les', 'nlendiants', 'T.', 'T.']
# ['2837', '—', 'Bouledogue', 'et', 'terrier', 'écossais', 'T.', 'T.']
# ['2838', '—', 'Le', 'valet', 'de', 'chiens.', 'T.', 'T.']
# ['2839', '—', 'Chiens', 'brifauts,.', 'T.', 'T.']
# ['2840', '—', 'Eléphant', 'et', 'tigre', 'à', 'la', 'source.', 'T.', 'T.']
# ['2841', '—', 'Bertrand', 'et', 'Raton.,.', 'T.', 'T.']
# ['2842', '—', 'La', 'cour', 'de', 'ferme.', 'T.', 'T.']
# ['35)', '—', 'Le', 'marchand', 'turc', 'fumant', 'dans', 'sa', 'boutique.', 'Coll.', 'Chauchard,', 'IV', 'i36)', '—', 'Le', 'marchand', "d'oranges.", ',', '—', 'galerie']
# ['(37)', '—', 'Intérieur', 'de', 'cour', 'rustique.,.', '—', 'IV', '(38i', '—', 'Le', 'Christ', 'au', 'prétoire', '—', 'galerie', '158>', 'Degas,', 'Edgar.', '1', '1', 'g', '31', '-', '1', 'l)', 'l', '7).', '—', 'Course', 'de', 'Gentlemen', '-', 'Avant', 'le', 'départ', 'Coll.', 'Camondo', '(159^', '—', 'La', 'femme', 'à', 'la', 'potiche.', ',', '-']
# ['(160)', '—', 'Le', 'foyer', 'de', 'la', 'danse', 'à', "l'Opéra", 'de', 'la', 'rue', 'Le', 'Peletier', '.,', '-', '1I6I)', '—', 'Le', 'pédicure.', '-']
# ['162)', '—', 'Répétition', "d'un", 'ballet', 'sur', 'la', 'scène', '-']
# ['163)', '—', 'Classe', 'de', 'danse', '-']
# ['1164)', '—', "L'absinthe.", '—']
# ['165)', '—', 'Devant', 'les', 'tribunes.', ',', '-']
# ['1166', ')', '—', 'Aux', 'courses.', 'Jockeys', 'amateurs', 'près', "d'une", 'voiture', '—']
# ['167)', '—', 'Danseuses', 'montant', 'un', 'escalier', '—']
# ['168)', '—', 'Les', 'repasseuses.', '—']
# ['217)', '—', 'La', 'Danseuse', 'au', 'bouquet', 'saluant', 'sur', 'la', 'scène.', 'Pastel', '—']
# ['(218)', '—', 'Danseuse', 'vue', 'de', 'dos.', 'Dessin', '—', 'v219)', '—', 'Danseuse', 'tenant', 'un', 'bouquet.', 'Fin', "d'arabesque", 'Pastel.', '-']
# ['1220)', '—', 'Le', 'Café-Concert.', 'Pastel', '-']
# ['(221)', '—', 'Après', 'le', 'bain.', '—', 'Femme', "s'essuyant", 'les', 'pieds', '-', '(222*', '—', 'Le', 'tub.', '—']
# ['1223', '>', '—', 'Trois', 'études', 'de', 'la', 'tête', "d'une", 'danseuse.', 'Dessin', '-']
# ['(224)', '—', 'Femme', 'dans', 'une', 'baignoire', "s'épongeant", 'la', 'jambe', 'Pastel.', '—']
#
# PAGE 21
# ['(227)', 'Degas,', 'Edgar.', '(1X3.1-1917).', '—', 'Au', 'Louvre.', 'Devant', 'le', 'sarcophage', 'étrusque.', 'Mary', 'Cassatt', '(Eau-forte)', 'Coll.', 'Camondo']
# ['(228)', '—', 'Le', 'lever.', 'Femme', 'assise', 'mettant', 'ses', 'bas.', 'Monotype', '—']
# ['(229)', '—', 'Femme', 'debout', 'dans', 'une', 'baignoire.', 'Monotype.', '—']
# ['1230', '—', 'Femme', "s'essuyant", 'les', 'pieds,', 'près', "d'une", 'bai-', 'gnoire.', 'Monotype', '—']
# ['206', 'a', 'Dehodencq,', 'Edme-Alfred-Alexis.', '(1822-1882).', '—', 'Por-', 'trait', 'du', 'peintre.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1', "206'", 'b', '—', 'Arrestation', 'de', 'Charlotte', 'Corday', '—', 'II']
# ['206', 'c', '—', 'Portrait', 'du', 'peintre', 'J.', 'L.', 'Hamon.', 'Marine', '1']
# ['207', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '—', 'Dante', 'et', 'Virgile,', 'conduits', 'par', 'Phlégias,', 'tra-', 'versent', 'le', 'lac', 'qui', 'entoure', 'la', 'ville', 'infernale', 'de', 'Dite', 'VIII-N']
# ['208', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '—', 'Scènes', 'des', 'massacres', 'de', 'Scio', 'VIII-0']
# ['209', '—', 'La', 'Liberté', 'guidant', 'le', 'peuple,', '28', 'Juillet', '1830..', 'VIII-0']
# ['210', '—', 'Femmes', "d'Alger", 'dans', 'leur', 'appartement', 'VIII-0']
# ['211', '-', 'Noce', 'juive', 'au', 'Maroc', 'VIII-N']
# ['212', '—', 'Le', 'naufrage', 'de', 'Don', 'Juan.', 'VIII-N']
# ['212', 'h', '—', 'Jeune', 'tigre', 'jouant', 'avec', 'sa', 'mère', 'VIII-S']
# ['213', '—', 'Prise', 'de', 'Constantinople', 'par', 'les', 'croisés.', 'VIII-E']
# ['213', 'a', '—', 'Portrait', 'de', 'Chopin.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['214', '—', 'Son', 'portrait,', 'par', 'lui-même', 'VIII-N']
# ['2843', '-', 'La', 'fiancée', "d'Abydos", 'T.', 'T.']
# ['2844', '-', 'La', 'mort', "d'Ophélie.,.", 'T.', 'T.']
#
# PAGE 22
# ['2846', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '-', 'Le', 'lion', 'au', 'sanglier.', 'T.', 'T.']
# ['2847', '—', 'Le', 'lion', 'au', 'caïman.', 'T.', 'T.']
# ['2848', '—', 'Le', 'lion', 'au', 'Japin', 'T.', 'T.']
# ['2849', '—', 'Le', 'Christ', 'en', 'croix,.', 'T.', 'T.']
# ['2850', '—', "L'enlèvement", 'de', 'Rébecca.', 'T.', 'T.']
# ['2851', '—', 'Hamlet', 'et', 'Horatio.', 'T.', 'T.']
# ['2852', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '—', 'Médée.', 'T.', 'T.']
# ['2853', '—', 'Lionne', 'prête', 'à', "s'élancer.", 'T.', 'T.']
# ['S.', 'N°', '—', 'Hamlet', 'et', 'Horatio', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['S.', 'N°', '—', 'Le', 'poêle;', 'coin', "d'atelier.", 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'N°', '—', "L'appartement", 'du', 'comte', 'de', 'Mornay', '—']
# ['S.', 'N°', '—', 'Portrait', 'de', 'Georges', 'Sand.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['S.', 'N°', '—', 'La', 'mort', 'de', 'Sardanapale.', 'VIII-0']
# ['S.', 'N°', 'DELACROIX', '213', 'DELACROIX', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '—', 'Apollon', 'vainqueur', 'du', 'serpent', 'Python.', 'Plafond.', 'Gai.', "d'Apollon"]
# ['(39)', '—', 'La', 'chasse', 'au', 'tigre.', 'Coll.', 'Chauchard,', 'galerie']
# ['(40)', '—', 'Le', 'puma.', '-']
# ['(169)', '—', 'Passage', "d'un", 'gué', 'au', 'Maroc', 'Coll.', 'Camondo']
#
# PAGE 23
# ['(231)', 'Delacroix,', 'Ferdinand-Victor-Eugène.', '(1798-1863).', '-', 'Tigre', 'attaquant', 'un', 'cheval', 'sauvage.', 'Aquarelle.', 'Coll.', 'Camondo']
# ['(232)', '—', 'Lion', 'dévorant', 'un', 'cheval.', 'Aquarelle:.', '—']
# ['216', 'Delaroche,', 'Paul.', '(1797-1856).', '—', 'Mort', "d'Elisabeth,", 'reine', "d'Angleterre,", 'en', '1603.', 'VIII-N']
# ['217', '—', 'Les', 'enfants', "d'Edouard", 'IV', ':', 'Edouard', 'V,', 'roi', 'mi-', 'neur', "d'Angleterre,", 'et', 'Richard,', 'duc', "d'York,", 'son', 'frère', 'pumé.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1', 'r', '[217', 'a', '—', 'La', 'jeune', 'Martyre.', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', 'III']
# ['221', 'De', 'Marne,', 'Jean-Louis.', '(1744-1829).', '—', 'Une', 'route..', 'XVI-S']
# ['222', '—', 'Une', 'foire', 'à', 'la', 'porte', "d'une", 'auberge', 'XVI-S']
# ['229', 'Desportes,', 'François.', '(1661-1743).', '—', 'Diane', 'et', 'Blonde,', 'chiennes', 'de', 'la', 'meute', 'de', 'Louis', 'XIV.,..', 'XVI-N']
#
# PAGE 24
# ['234', 'Desportes,', 'François.', '(1661-1743).', '—', 'Une', 'chienne', 'et', 'deux', 'perdrix', 'Ile', 'S.', 'Meubles', 'XVIIIe']
# ['237', '—', 'Nature', 'morte.', 'Volaille,', 'gibier', 'et', 'légumes', 'XVI-S']
# ['240', 'a', '—', 'Gibier', 'gardé', 'par', 'un', 'chien.', 'XVI-N']
# ['241', '—', 'Gibier,', 'fleurs', 'et', 'fruits', 'Ile', 'S.', 'Meubles', 'XVIIIe']
# ['242', '—', 'Gibier,', 'fleurs', 'et', 'fruits.,.,..', '—']
# ['245', '—', 'Fruits', 'et', 'gibier.,.', 'XVI-S']
# ['247', '—', 'Deux', 'chiens', 'gardant', 'du', 'gibier.', 'IIe', 'S.', 'Meubles', 'XVIIIe']
# ['249', '—', 'Son', 'portrait,', 'par', 'lui-même,', 'en', 'chasseur.', 'XVI-N']
# ['250', 'Devéria,', 'Eugène-François-Marie-Joseph.', '(1805-1865).', '—', 'La', 'naissance', 'de', 'Henri', 'IV', 'VIII-N']
# ['250', 'a', '—', 'Puget', 'présentant', 'le', 'Milon', 'de', 'Crotone', 'à', 'Louis', 'XIV.', 'Esq', 'uisse', 'du', 'plafond', 'de', 'la', '3e', 'salle', 'de', 'céramique', 'antique.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['(46)', 'DIAZ', 'S.', 'Nü', 'FANTIN-LATOUR']
# ['*', 'Devéria,', 'Eugène-François-Marie-Joseph.', '(', '180s-1865).', 'Plafond.', 'Puget', 'présentant', 'le', 'Milon', 'de', 'Crotone', 'à', 'Louis', 'XIV.', '—', 'Voussures:', 'Quatre', 'tableaux', 'représentant', 'des', 'épisodes', 'du', 'règne', 'de', 'Louis', 'XIV,', 'et', 'des', 'médaillons', 'rappelant', 'les', 'principales', 'fondations', 'du', 'règne.', 'Illme', 'S.', 'de', 'Céramique', 'antique']
# ['251', 'Diaz', 'de', 'la', 'Pena,', 'Narcisse.', '(1809-1876).', '—', 'Les', 'Pyrénées;', 'étude', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
# ['252', '—', 'Etude', 'de', 'bouleau', '—']
# ['255', '—', 'Les', 'Bohémiens.', '—']
# ['257', 'a', '—', 'Chiens', 'dans', 'la', 'forêt', '—']
# ['2854', '—', 'Nymphes', 'sous', 'bois.', 'T.', 'T.']
# ['2855', '—', 'Baigneuses.', 'T.', 'T.']
# ['2856', '—', 'Le', 'valet', 'de', 'chiens.', 'T.', 'T.']
#
# PAGE 25
# ['2858', 'Diaz', 'de', 'la', 'Pena,', 'Narcisse.', '(1K09-1876).', '—', 'Vénus', 'et', 'Adonis.', 'T.', 'T.']
# ['2859', 'V', "l'nus", 'désarmant', "l'Amour", 'T.', 'T.']
# ['2860', '—', 'Les', 'deux', 'rivales', 'T.', 'T.']
# ['2861', '—', 'Sous', 'hois.', 'T.', 'T.']
# ['2862', '-', 'La', 'charité.', 'T.', 'T.']
# ['2863', '-', "L'éplorée.", '-.,.', '-.', 'T.', 'T.', ',41', '—', 'Vaches', 'dans', 'la', 'forêt.', 'Coll.', 'Chauchard', 'II']
# ['(42', '—', 'Mare', 'sous', 'les', 'chênes.,.,.', '—', '1', "143'", '-', 'La', 'route', 'sous', 'bois..,.', '-', ',', ',', '.,', '-', 'galerie', '\\44-1', '—', 'Les', 'hauteurs', 'de', 'Jean-de-Paris.', 'Forêt', 'de', 'Fontainebleau', '—', 'galerie', '(45*', '—', 'La', 'forêt', 'de', 'Fontainebleau,', 'enceinte', 'palissadée', '—', 'galerie']
# ['146', '*', '—', 'Le', 'braconnier.', '-', '—', 'III']
# ['(47)', '-', 'La', 'ninro', 'au', 'gamin', 'agenouillé.', '—', '1']
# ['(481', '-', 'Lisière', 'de', 'forêt.', '—', 'III']
# ['(491', '—', 'Le', 'puits.', 'Nymphes', 'et', 'Amours', '-', 'galerie', '150,', 'ymphc', 'endormie.,.', '—', '1']
# ['(51', '—', 'Nymphe', 'caressant', "l'Amour.,.", '—', 'galerie', "(52'", '—', 'Nymphe', 'réprimandant', "l'Amour", '—', 'IV']
# ['(531', '—', 'Les', 'caresses', 'de', "l'Amour.", '-', ',', '-', ',', '-', 'galerie', '<54)', '—', 'La', 'magicienne.,', '-', ',', ',', '—', 'IV']
# ['(55', '—', 'Le', 'matéfice.', '-', 'galerie']
# ['260', 'Doyen,', 'Gabriel-François.', '(1726-1806).', '—', 'Triomphe', "d'Amphitrite", '-.', 'XVI-S']
# ['261', 'Drolling,', 'Martin.', '1,1752-18171.', '-', 'Intérieur', "d'une", 'cuisine', 'XVI-N']
# ['262', '—', 'Femme', 'à', 'une', 'fenêtre.', '-', ',', '1-0']
# ['263', '—', 'Joueur', 'de', 'violon', 'à', 'une', 'ienêtre.', '1-0']
# ['*', 'Drolling,', 'Michel-Martin.', '(1786-1851).', '—', 'Plafond:', 'Louis', 'Xill', 'proclamé', 'père', 'du', 'peuple', 'aux', 'états-', 'généraux', 'de', 'Tours,', 'en', '1506.', '—', 'Voussures:', 'Armes', 'de', 'différentes', 'villes.', 'VlIlllle', 'S.', 'de', 'Céramique', 'antique']
# ['*', '-', 'La', 'Loi', 'descend', 'sur', 'la', 'terre.', '—', 'Voussures', ':', 'La', 'Sagesse', 'inspirant', 'la', 'Loi,', 'la', 'Justice', 'diri-', 'geant', 'la', 'Force.', 'IIme', 'S.', 'Meubles', 'XVIIIe']
# ['S.', 'N"', 'Drouais,', 'Hubert.', '(16^9-17671.', '—', 'Portrait', 'de', 'Melle', 'Pélissier', "(d'après", 'i', 'Coll.', 'Schlichting']
#
# PAGE 26
# ['267', 'Drouais,', 'François-Hubert.', '(i727-1775).', '—', 'Portrait', 'du', 'sculpteur', 'Edme', 'Bouchardon', 'XVI-N']
# ['S.', 'N°', '—', 'Portrait', 'de', 'jeune', 'femme.', 'Coll.', 'Schlichting']
# ['S.', 'N°', '—', 'Portrait', 'de', 'Mme', 'Loys.', 'Vest.', 'S.', 'anglaises']
# ['269', 'Drouais,', 'Jean-Germain.', '(1763-1788).', '—', 'Le', 'Christ', 'et', 'la', 'Chananéenne.', 'XV-E']
# ['272', 'Dubois,', 'Ambroise.', '(15/13-1614).', '—', 'Le', 'baptême', 'de', 'Clorinde', 'par', 'Tancrède.', 'XI']
# ['271', 'Du', 'Breuil,', 'Toussaint.', '(1562-1602).', '-', 'Sacrifice', 'antique', 'XI']
# ['272', 'a', 'Dubufe,', 'Edouard.', '(1820-1883).', '—', 'Portrait', 'du', 'peintre', 'Philippe', 'Rousseau.', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'N°', '—', 'Portrait', 'de', 'la', 'Comtesse', 'Hallez', 'Claparède', '—']
# ['S.', 'N°', 'Ducreux,', 'Joseph.', '(1737-1802).', '—', 'Son', 'portrait,', 'par', 'lui-même', 'XVI-E']
# ['S.', 'N°', '—', 'Portrait', 'de', 'J.-Ch.', 'Laveaux.', 'Pastel.', 'S.', 'des', 'Pastels']
# ['S.', 'Nu', '—', 'Son', 'portrait,', 'par', 'lui-même.', 'Pastel.', ',', '—']
# ['*', 'Dumas,', 'Michel.', '(1814-1885).', '—', 'Homère', 'déifié,', "d'après", 'Ingres.', 'Plafond', 'Musée', 'Charles', 'X,', 'S.', 'IX']
# ['275', 'Dumont,', 'Jacques.', '(1701-1781).', '—', 'Mme', 'Mercier,', 'nourrice', 'du', 'duc', "d'Anjou", '(Louis', 'XV)', 'entourée', 'de', 'sa', 'famille.', 'XVI-S']
# ['276', 'Duplessis,', 'Joseph-Siffrein', 'ou', 'Siffred', '(1725-1802).', '-', 'Por-', 'trait', 'du', 'sculpteur', 'Christophe-Gabriel', 'Allegrain', 'XVI-S']
# ['277', '—', 'Portrait', 'du', 'peintre', 'Joseph-Marie', 'Vien', 'XVI-E']
# ['277', 'a', '—', 'Portrait', 'de', 'femme', 'tenant', 'une', 'brochure', '(Attribué)', '1-0']
# ['S.', 'N°', '—', 'Portrait', 'de', 'M"', 'Lenoir.', 'XVI-N']
# ['2864', 'Dupré,', 'Jules.', '(1811-1889).', '—', "L'étang", 'T.', 'T.']
# ['2865', '—', 'La', 'petite', 'charrette.,.', 'T.', 'T.']
# ['2866', '—', "L'automne.", '-', 'T.', 'T']
# ['2867', '—', 'La', 'mare.', 'T.', 'T.']
# ['2868', '—', 'Pâturage', 'de', 'Normandie.,..', 'T.', 'T.']
# ['2869', '—', 'Paysage', 'avec', 'rivière', 'T.', 'T.']
# ['2870', '—', 'Vaches', 'au', 'bord', 'de', "l'eau", 'T.', 'T.']
# ['2871', '—', 'Les', 'landes.', 'T.', 'T.']
# ['2872', '—', 'Bords', 'de', 'rivière.', 'T.', 'T.']
# ['2873', '—', 'Le', 'grand', 'chêne', 'T.', 'T.']
# ['2874', '-', 'Soleil', 'couchant', 'sur', 'un', 'marais.', 'T.', 'T.']
# ['2875', '-', 'Soleil', 'couchant', 'après', "l'orage", 'T.', 'T.', '(']
# ['2940', '—', 'Le', 'matin,', 'panneau', 'décoratif.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
#
# PAGE 27
# ['2942', 'Dupré,', 'Jules.', '(1811-1889).', '—', 'Paysage.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', 'II']
# ['2943', '—', 'Son', 'portrait,', 'par', 'lui-même.', '—', 'II']
# ['(56)', '—', 'La', 'mare', 'aux', 'chênes.,.', 'Coll.', 'Chauchard,', 'galerie']
# ['(57)', '—', 'La', 'vanne.', '—', 'II']
# ['(58)', '—', 'Le', 'chemin', 'de', 'la', 'ferme', '—', 'galerie']
# ['(59)', '—', 'Le', 'berger.', 'Soleil', 'couchant', '—', 'galerie']
# ['(60)', '—', 'Le', 'chêne.', '—', 'III']
# ['(61)', '—', 'La', 'mare', 'près', 'du', 'moulin', '-', 'galerie']
# ['*', 'Durameau,', 'Louis-Jacques.', '(1733-1796).', '—', "L'été", 'ou', 'Cérès', 'et', 'ses', 'compagnes', 'implorant', 'le', 'soleil.', 'Plafond', 'Gai.', "d'Apollon"]
# ['S.', 'N°', 'Dutilleux,', 'Henri-Joseph-Constant.', '(1807-1865).', '—', "L'enfant", 'au', 'papillon', 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['S.', 'Nu', 'Eriksen,', 'Vigilius.', '—', 'Portrait', 'de', "l'empereur", 'de', 'Russie', 'Paul', 'ier,', 'enfant', "(D'après)", '-;.', 'Coll.', 'Schlichting']
# ['S.', 'Nu', 'Fantin-Latour,', 'Henri.', '(18^,0-1004).', '-', 'Le', 'coin', 'de', 'table', '1,1872)', 'Portraits', 'des', 'poètes', 'P.', 'Verlaine,', 'A.', 'Rimbaud,', 'etc.', 'Marine', '1']
# ['279', 'Favray,', 'le', 'chevalier', 'Antoine', 'de.', '11706-1791).', '—', 'Dames', 'de', 'Malte', 'se', 'faisant', 'visite', 'XVI-N']
# ['280', '—', 'Portrait', 'de', 'jeune', 'femme', 'maltaise.', '1-0']
# ['283', 'Flandrin,', 'Jean-Hippolyte.', '(180^-1864).', '—', 'Figure', "d'étude", 'E.', 'F.', 'XIXe', 'S.', '1er', 'étage', '1']
# ['284', '—', 'Portrait', 'de', 'jeune', 'fille', 'VIII-N']
# ['285', '—', 'Portrait', 'de', 'Mille', 'Vinet.', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1']
#
# PAGE 28
# ['286', 'Fiers,', 'Camille.', '(1802-1868).', '—', 'Paysage.', 'Environs', 'de', 'Paris', 'E.', 'F.', 'XIXe', 'S.', '2e', 'étage', '1', 'Fontenay.', '—', 'Voir', 'Blain', 'ou', 'Belin', 'de', 'Fontenay']
# ['288', 'Fouquet,', 'Jean.', '(vers', '1415', 'ou', '1.120?', '—', 'vers', '1480).', '—', 'Portrait', 'de', 'Guillaume', 'Juvénal', 'ou', 'Jouvenel', 'des', 'Ursins,', 'chancelier', 'de', 'France', 'sous', 'Charles', 'VII', 'et', 'Louis', 'XI.', '(Attribué!.', 'X']
# ['289', '—', 'Portrait', 'de', 'Charles', 'VII,', 'roi', 'de', 'France.', 'X']
# ['*', 'Fragonard,', 'Alexandre-Evariste.', '(1780-1850).', '—', 'Plafond:', 'François', 'ier', 'reçoit', 'les', 'tableaux', 'et', 'statues', 'rapportés', "d'Italie", 'par', 'le', 'Primatice.', '—', 'Voussures', ':', 'Génies', 'présidant', 'aux', 'arts,', 'dans', 'des', 'médaillons.,.', 'Céramique', 'antique', 'IVe', 'S.']
# ['284', 'FLANDRIN', '¿lj3', 'FKAÙOSAKD']
# ...
# ['2553', '—', 'Portrait', 'de', 'Rembrandt', 'avec', 'une', 'toque', 'et', 'une', 'chaîne', "d'or,", 'de', "l'année", '1634', 'VI', 'tr.', 'F-N']
# ['2554', '—', 'Portrait', 'de', 'Rembrandt', 'à', 'la', 'toque,', 'de', "l'année", '1617', 'e', 'VI', 'tr.', 'F-S']
# ['2555', '—', 'Portrait', 'de', 'Rembrandt', 'devant', 'Un', 'chevalet,', 'de', "l'année", '1660.', 'VI', 'tr.', 'F-S']
# ['2541', '-i', '—', 'Ermite', 'lisant', 'XXII']
# ['2555', 'a', '—', 'Les', 'pèlerins', "d'EmmaÜs.", 'VI', 'tr.', 'F-N']
# ['S.', 'N"', '-', 'Portrait', 'du', 'frère', 'de', 'Rembrandt,', 'Adriaen', 'Har-', 'mensz', 'van', 'Rijn,', 'avec', 'un', 'médaillon', 'suspendu', 'à', 'une', 'chaîne', "d'or", 'VI', 'tr.', 'F-N']
#
# PAGE 162
# ['2557', 'Ruisdael', 'ou', 'Ruysdael,', 'Jacob', 'van.', '(1628', 'ou', '1620-', '1682).', '-', 'La', 'forêt', 'VI', 'tr.', 'F-S']
# ['2558', '—', 'Une', 'tempête', 'sur', 'le', 'bord', 'des', 'digues', 'en', 'Hollande.', 'XXII']
# ['2559', '—', 'Paysage,', 'dit', 'le', 'Buisson', 'VI', 'tr.', 'F-S']
# ['2560', '—', 'Paysage,', 'dit', 'le', 'Coup', 'de', 'soleil', 'VI', 'tr.', 'F-S']
# ['2560', 'a', '—', 'La', 'route', 'VI', 'tr.', 'F-N']
# ['2561', '-', 'Paysage.', 'XXII']
# ['2561', 'a', '—', "L'entrée", "d'un", 'bois.', 'XXV']
# ['S.', 'N°', '—', 'Paysage.', '(Attribué)', 'Coll.', 'Thiers']
# ['2561', 'b', 'Ruysdael,', 'Salomon', 'van', '(vers', '1600-1670).', '—', 'Le', 'bac.', 'XXIII']
# ['2561', 'c', '—', 'La', 'grosse', 'tour.', 'XXI']
# ['2561', 'd', '—', 'Bord', 'de', 'rivière', 'VI', 'tr.', 'F-N']
# ['2562', 'Saftleven,', 'dit', 'aussi', 'Zachtleven,', 'Cornelis', 'vers', '1607-']
# ['1681', '1.', '—', 'Portrait', "d'un", 'peintre.', 'XXIV']
# ['2563', 'Saftleven,', 'dit', 'aussi', 'Zachtleven,', 'Herman', '1600-1685', '—', 'Vue', 'des', 'bords', 'du', 'Rhin', 'XXV']
# ['2564', 'Santvoort,', 'Dirk', 'Dircksz.', '(1610-1680).', '-', 'Jésus-Christ', 'à', 'EmmaÜs.', 'XXI']
#
# PAGE 163
# ['2565', 'Schalcken,', 'Godfried.', '<643-1706', '—', 'La', 'Sainte', 'Famille.', 'XXI']
# ['2567', '-', 'Vieillard', 'répondant', 'à', 'une', 'lettre.', 'XXV']
# ['2567', 'a', 'Scorel,', 'Jan', 'van.', '(149-1', '502).', '—', 'Portrait', 'du', 'méde-', 'cin', 'ParaceJse.', '(Attribue.', 'XXXI']
# ['2568', 'Slingeland,', 'Pieter', 'Cornelisz', 'van.', '(', '1640-1001', '—', 'Portrait', 'de', 'Johannes', 'Meerman.', 'bourgmestre', 'de', 'Leyde,', 'avec', 'sa', 'femme', 'Dina', 'van', 'Nes', 'et', 'ses', 'enfants.,', 'XXVI']
# ['2571', 'Sorgh,', 'dit', 'Rokes,', 'Hendrik', 'Martensz.', 'vers', '1011-', '167°1.', '-', 'Intérieur', 'de', 'cuisine.', 'XXV']
# ['2572', '—', 'Intérieur', "d'estaminet.", 'XX']
# ['2577', 'Staveren,', 'Johan-Andriaensz', 'van.', 'vers', '1625-peu', 'après', '1668', '—', 'Un', 'savant', 'dans', 'son', 'cabinet', 'XXV']
# ['2578', 'Steen,', 'Jan.', '(vers', '1626-1670).', '—', 'Fête', 'dans', "l'intérieur", "d'une", 'auberge.', 'XXIII']
# ['2579', '—', 'Repas', 'de', 'famille.', 'XX']
# ['2580', '—', 'La', 'mauvaise', 'compagnie.', 'XXIV']
# ['2581', 'Steenwyk,', 'Hendrik', 'van,', 'le', 'jeune,', '(vers', '1580-vers', '16491.', '—', 'Jésus-Christ', 'chez', 'Marthe', 'et', 'Marie.', '(Figuresattribuées', 'à', 'Cornelis', 'van', 'Poelenburgh).', 'XXI']
# ['2408', 'Stomer,', 'Matthàus.', '(travaillait', 'en', 'Italie', 'vers', '1620-1640).', '—', 'Pilate', 'se', 'lavant', 'les', 'mains', 'devant', 'le', 'peu-', 'ple.', '(Autrefois', 'attribué', 'à', 'Gerard', 'van', 'Honthorst).', 'VI', 'tr.', 'F-S']
#
# PAGE 164
# ['2585', 'Swanevelt,', 'Herman', 'van,', 'dit', 'Herman', "d'Italie.", '(vers', '1600-1655).', '—', 'Paysage', 'XXVI']
# ['2586', '—', 'Paysage.', 'XXVI']
# ['2453', 'Sweerts,', 'Michael.', '(vers', '1615-1620-mort', 'vers', '1656).', '—', 'Intérieur', "d'un", 'corps', 'de', 'garde.', '(Autrefois', 'attribué', 'à', 'Aart', 'van', 'Maes,', 'Maas', 'ou', 'Waes)', 'XXIII']
# ['2586', 'a', 'Tempel,', 'Abraham', 'van', 'den.', '(1622', 'ou', '1623-1672).', '—', 'Portrait', 'de', 'femme.', 'XXVI']
# ['2587', 'Terborch', 'ou', 'Terburg,', 'Gérard.', '(1617-1681).', '—', 'Le', 'galant', 'militaire', 'offrant', 'des', 'pièces', "d'or", 'à', 'une', 'jeune', 'femme.', 'XXIII']
# ['2588', 'Terborch', 'ou', 'Terburg,', 'Gérard.', '(1617-108', '1).', '—', 'La', 'leçon', 'de', 'musique.', 'XXIV']
# ['2589', '—', 'Le', 'concert.', 'XXV']
# ['2590', '—', 'Assemblée', "d'ecclésiastiques.,", 'XXV']
# ['2591', '—', 'La', 'leçon', 'de', 'lecture.', 'XX']
# ['S.', 'N°', '—', 'Portrait', "d'homme.", '(École', 'de)', 'Coll.', 'Thiers.']
# ['2593', 'Velde,', 'Adriaen', 'van', 'de.', '(1636-1672).', '—', 'La', 'plage', 'de', 'Scheveningen.', 'XXIII']
# ['2594', '-', 'Paysage', 'et', 'animaux', 'XXII']
# ['2595', '-', 'Paysage', 'et', 'animaux', 'XXV']
# ['2596', '-', 'Paysage', 'et', 'animaux.,', 'XXVI']
# ['2597', '-', 'La', 'famille', 'du', 'pâtre.,.,.', 'XXV']
# ['2598', '-', 'Un', 'canal', 'g!acë.', 'XXII']
#
# PAGE 165
# ['2600', 'Velde,', 'Willem', 'van', 'de.', '(1633-1707).', '—', 'Marine.', 'Ba-', 'teau', 'de', 'guerre', 'hollandais.,.,.,..', 'XXIII']
# ['2601', 'Venne,', 'Adriaen', 'Pietersz', 'van', 'de.', '(1589-1662).', '—', 'Fête', 'donnée', 'à', "l'occasion", 'de', 'la', 'trêve', 'conclue', 'en', '1600', 'entre', "l'archiduc", 'Albert', "d'Autriche,", 'souverain', 'des', 'Pays-Bas,', 'et', 'les', 'Hollandais', 'XXI']
# ['2602', 'Verkolje,', 'Johannes.', '(1650-1601).', '-', 'Scène', "d'intérieur.", 'XXVI']
# ['2603', 'Verkolje,', 'Nicolaas.', '(1673-1746).', '—', 'Proserpine', 'cueillant', 'des', 'fleurs', 'avec', 'ses', 'compagnes', 'dans', 'la', 'prairie', "d'Enna", 'XXVII']
# ['2456', 'Vermeer,', 'Johannes,', 'dit', 'Vermeer', 'de', 'Delft.', '(1632-', '1675).', '-', 'La', 'dentellière.,.', 'XXII']
# ['2603', 'b', 'Verspronck,', 'Johannes', 'Cornelisz.', '(15.97-1662).', '—', 'Por-', 'trait', 'de', 'femme.', 'XXII']
# ['S.', 'N"', '—', 'Portrait', 'de', 'femme', 'Coll.', 'Schlichting', 'Victors,', 'Jan,', 'voir', 'Fictoor.', '2604', 'Vlieger,', 'Simon', 'de.', '(1601-1613).', '—', 'Marine', 'par', 'un', 'temps', 'calme.,.,.,.,.",.,.', 'XXII']
# ['2605', 'Vliet,', 'Hendrick', 'Cornelis', 'van', 'der.', '(IÔII', 'ou', '1612-', '167s).', '—', 'Portrait', 'de', 'jeune', 'lioiiinie', 'XXV']
#
# PAGE 166
# ['2606', 'Vois,', 'Arie', 'de.', '(vers', '1632-1680).', '—', 'Portrait', "d'un", 'homme', 'assis', 'à', 'son', 'bureau.', 'XXV']
# ['2607', '—', 'Portrait', "d'un", 'peintre', 'à', 'son', 'chevalet.', '(Portrait', 'présumé', 'de', 'Pynacker)', 'o.,.', 'XXI']
# ['2608', '—', 'Femme', 'coupant', 'un', 'citron', 'XX']
# ['2609', 'Weenix,', 'Jan-Baptist,', 'ou', 'Giovanni-Battista.', '1621', '-1660).', '—', 'Les', 'corsaires', 'repoussés', 'XXIII']
# ['2610', 'Weenix,', 'Jan.', '(1640', 'ou', '1644-1719).', '—', 'Gibier', 'et\'"', 'us-', 'tensiles', 'de', 'chasse.', 'XXV']
# ['2612', '—', 'Port', 'de', 'mer.', 'XXV']
# ['2612', 'a', '-', 'Nature', 'morte,', 'gibier..', 'XXV', 'XXV']
# ['2617', 'Werff,', 'Le', 'chevalier', 'Adriaen', 'van', 'der.', '(1659-1722).', '—', 'La', 'Madeleine', 'dans', 'le', 'désert', 'XXVII']
# ['2619', '—', 'Nymphes', 'dansant..,.,.,', 'XXVII']
# ['2620', '—', 'Groupe', "d'amateurs.,.", 'XX']
# ['2621', 'Wouwerman,', 'Philips.', '(161', 'q-', '1668).', '—', 'Le', 'bœuf', 'gras', 'en', 'Hollande', 'XXVI']
# ['2622', '—', 'Le', 'pont', 'de', 'bois', 'sur', 'le', 'torrent.,.,.,.', 'XXII']
# ['2623', '—', 'Départ', 'pour', 'la', 'chasse.,.', 'XXV']
# ['2625', '—', 'La', 'chasse', 'au', 'cerf.', 'XXVI']
# ['2626', '—', 'Le', 'manège.,.,.,.', 'XXVI']
# ['2628', '—', 'Choc', 'de', 'cavalerie.', 'XXV']
# ['2630', '—', 'Halte', 'de', 'chasseurs', 'et', 'de', 'cavaliers', 'devant', 'une', 'hôtellerie,.,.', 'XXI']
# ['2631', '—', 'Halte', 'de', 'cavaliers', 'près', "d'une", 'tente.,.,..', 'XXIII']
# ['2632', '—', 'Halte', 'de', 'militaires.,.,.', 'XXVI']
# ['2633', '—', 'Paysans', 'conduisant', 'une', 'charrette', 'de', 'foin.', 'XXIII']
# ['2634', '—', 'Les', 'pèlerins.,.,.', 'XX']
#
# PAGE 167
# ['2635', 'Wouwerman,', 'Pieter.', '(1621-1682*.', '—', 'Vue', 'de', 'la', 'tour', 'et', 'de', 'la', 'porte', 'de', 'Nesle,', 'à', 'Paris,', 'vers', '1664..', 'XXIII']
# ['2636', 'Wynants,', 'Jan.', 'i', '1625-1682', ').', '—', 'Lisière', 'de', 'forêt', 'XXIV']
# ['2637', '-', 'Paysage.', '(Les', 'figures', 'sont', "D'ADRIAEN", 'VAN', 'DE', 'VELDE.).', 'XXIV']
# ['2638', '-', 'Paysage.', '(Les', 'figures', 'sont', "D'ADRIAEN", 'VAN', 'DE', 'VELDE.', 'o.', 'XXIII']
# ['2639', 'Wyntrak,', 'Dirck.', 'lavant', '1625-1678).', '—', 'La', 'ferme', 'XXVI', 'Zeeman;', 'voir', 'Nooms,', 'Reinier.', '2640', 'Zustris', 'ou', 'Sustris,', 'Frederik,', 'dit', 'Frederigo', 'di', 'Lam-', 'berto', '(vers', '1520', 'ou', '1526-1', 'soi', 'ou', 'vers', '1590).', '—', 'Vénus', 'et', ")'Amour.", 'XXXI']
# ['2197', 'École', 'hollandaise,', 'deuxième', 'moitié', 'du', 'XVlIle', 'siècle.', '—', 'Scènes', 'de', 'la', 'Sainte', 'Famine.', 'XXIX']
# ['S.', 'N"', 'École', 'hollandaise,', 'commencement', 'du', 'XVIme', 'siècle.', '—', 'Le', 'Christ', 'couronné', "d'épines", 'et', 'la', 'Vierge', 'de', 'doulcur', 'o.', 'o.', 'XXX']
# ['2205', 'École', 'hollandaise', 'du', 'XVlllle', 'siècle.', '—', 'Portrait', "d'homme", 'tenant', 'un', 'œillet.', '"o', 'XXX']
# ['2641', 'b', '—', 'Portrait', "d'homme", 'âgé', '(-le', '-,:!', 'XXXI']
# ['2641', 'r', 'École', 'de', 'la', 'Frise,', 'XVIme', 'siècle.', '—', 'Femme', 'et', 'cnfant.', 'XXX']
# ['S.', 'N"', 'École', 'hollandaise', 'du', 'XVII""', 'siècle.', '—', 'Portrait', "d'homme", 'âgé', 'de', '45', 'ans', 'Coll.', 'Schlichting']
# ['S.', 'N"', '—', 'Portrait', "d'homme.", 'XXVI']
# ['2324', '-', 'Vue', 'de', 'la', 'colonne', 'Trajane', 'et', 'de', "l'église", 'Sainte-', 'Marie', 'de', 'Lorette,', 'à', 'Rome.', 'XXVI']
# ['S.', 'N"', 'Ecole', 'de', 'Dordrecht,', 'XVII', 'me', 'siècle.', '—', 'La', 'bai-', 'gnade', '00', '00', '00.', 'Coll.', 'Schlichting']
#
# PAGE 168
# ['168', 'PARIS,', 'MUSÉE', 'NATIONAL', 'DU', 'LOUVRE', 'ÉCOLE', 'ALLEMANDE', '2701', 'Beham,', 'Hans', 'Sebald.', '(', '1500-1', '5=,o).', '—', 'Sujets', 'tirés', 'de', "l'histoire", 'de', 'David', 'XXXII', 'i"', 'Entrée', 'du', 'roi', 'Saiïl', 'à', 'Jérusalem', 'après', 'la', 'dé-', 'faite', 'des', 'Philistins.', '2°', 'David', 'et', 'Bethsabée.', '-', 'A', 'droite:', 'Le', 'cardi-', 'nal', 'Albert.', '3"', 'Siège', 'de', 'Rabbath.', '5"', 'Le', 'prophète', 'Nathan', 'devant', 'David.', '—', 'A', 'gau-', 'che:', 'Le', 'peintre', 'debout', 'derrière', 'son', 'bureau.']
# ['2701', 'J', 'Bruyn,', 'Bartholomœus', 'ou', 'Barthel.', '(1493-', 'entre', '1553', 'et', '1', 's', 'S', '7^-', '—', 'Portrait', 'de', 'Philipp', 'Gail', 'à', '49', 'ans,', 'avec', 'ses', 'fils', 'dont', ':', 'Philip', 'et', 'Andréas.', 'XXXII']
# ['2701', 'b', '—', 'Portrait', 'de', 'la', 'deuxième', 'femme', 'de', 'Philipp', 'Gail,', 'à', '37', 'ans,', 'avec', 'les', 'filles', 'de', 'celui-ci.', 'XXXII']
# ['2702', 'Cranach,', 'Lucas,', 'dit', 'le', 'vieux.', '(1472-1553).', '—', 'Les', 'effets', 'de', 'la', 'jalousie.', 'o.', 'o.', ',', 'XXXII']
# ['2702', 'a', '-', 'Portrait', 'de', 'jeune', 'fille.', 'o.', 'XXXII']
# ['2703', '-', 'Vénus', 'dans', 'un', 'paysage', 'XXXII']
# ['2703', 'a', '—', 'Portrait', "d'homme.", 'XXXII']
# ['2705', '—', 'Portrait', "d'homme.", 'XXXII']
#
# PAGE 169
# ['2707', 'Denner,', 'Balthasar.', '(1685-1740).', '—', 'Portrait', 'de', 'vieille', 'femme', 'I-S']
# ['2709', 'Durer,', 'Albrecht.', '(1471-1528).', '—', 'Tête', 'de', 'vieillard.', 'XXXIII']
# ['2709', 'a', '—', 'Tête', 'de', 'jeune', 'garçon..,..,.', 'XXXIII']
# ['S.', 'N°', '—', 'Portrait', "d'Erasme.", '(Dessin).,.', 'XXXIII']
# ['S.', 'N°', '—', 'Portrait', 'de', "l'artiste,", 'âgé', 'de', '22', 'ans.,', 'XXXIII', '2702', 'a', 'CRANACH']
# ['27', 'r,', 'HOLBEIN', '2714', 'Holbein']
# ['2710', 'Elsheimer,', 'Adam,', 'dit', 'Adamo', 'Tedesco.', '(1578-1610).', '—', 'La', 'fuite', 'en', 'Egypte.,.', 'XXXIII']
#
# PAGE 170
# ['2711', 'a', 'Holbein,', 'Hans,', 'le', 'vieux,', '(vers', '1400-1', '524).', '—', "L'A-", 'doration', 'des', 'mages.', '(Ecole', 'de)', 'XXXII']
# ['2713', 'Holbein,', 'Hans,', 'le', 'jeune.', '(1497-1543).', '—', 'Portait', 'de', 'Nicolas', 'Kratzer,', 'astronome', 'du', 'roi', "d'Angleterre", 'Henry', 'VIII.', '(Daté', '1528)', 'XXXIII']
# ['2714', '-', 'Portrait', 'de', 'William', 'Warham,', 'archevêque', 'de', 'Can-', 'terbury', 'en', '1504,', 'représenté', 'à', "l'âge", 'de', '69', 'ans.', 'XXXIII']
# ['2715', '—', 'Portrait', "d'Erasme.", 'XXXIII']
# ['2717', '-', 'Portrait', 'de', 'sir', 'Henry', 'Wyat,', 'conseiller', 'royal', 'XXXIII']
# ['2718', '—', 'Portrait', "d'Anne", 'de', 'Clèves,', 'reine', "d'Angleterre,", 'quatrième', 'femme', 'de', 'Henry', 'VIII.', 'XXXIII']
# ['2719', '—', 'Portrait', 'de', 'Sir', 'Richard', 'Southwell,', 'maître', 'de', "l'ar-", 'tillerie', 'en', 'Angleterre', 'sous', 'la', 'reine', 'Elisabeth,', 'représenté', 'à', "l'âge", 'de', '33', 'ans.', "(D'après).", 'XXXIII']
# ['2720', 'Holbein,', 'Hans,', 'le', 'jeune.', '(1497-', '1543).', '—', 'Portrait', "d'homme", 'âgé', 'de', '25', 'ans.', '(École', 'de)', 'XXXIII']
# ['S.', 'Nu', '—', 'Portrait', "d'homme,", '(vers', '1516)', 'XXXIII']
# ['S.', 'N°', '—', 'Portrait', 'de', 'la', 'femme', 'de', "l'artiste.", '\\Dessin).', 'XXXIII']
# ['S.', 'N°', '—', 'Le', 'triomphe', 'de', 'la', 'richesse.', '\\Dcssin)', 'XXXIII']
# ['S.', 'N°', '—', 'Deux', 'dessins:', '1°', 'Etudes', 'de', 'mains,', '2"', 'Etude', 'de', 'main', 'et', 'croquis', 'du', 'visage', "d'Erasmc", 'XXXIII']
#
# PAGE 171
# ['S.', 'NI)', 'Maître', 'de', 'Gôttingen.', '(vers', '1420).', '—', 'Le', 'Christ', 'des-', 'cendu', 'de', 'la', 'croix.', '(Genre', 'du)', 'XXXII']
# ['S.', 'N°', 'Maître', 'du', 'Livre', 'de', 'Raison,', '(travaillait', 'vers', '[460', '-IC:;IO).', '-', 'Saint', 'Georges.', 'Nouv.', 'Acq.']
# ['2739', 'Maître', 'de', 'Messkirch.', '(XVlme', 'siècle).', '—', 'Le', 'Christ', 'devant', 'Pilate.', 'XXXII']
# ['2737', 'Maître', 'de', 'Saint', 'Barthélemy.', '(vers', '1400-1', 'soo).', '—', 'Le', 'Christ', 'descendu', 'de', 'la', 'croix.', 'XXXII']
# ['2738', 'Maître', 'de', 'la', 'Sainte', 'Parenté,', '(vers', '1486-1520).', '—', 'La', 'présentation', 'nu', 'temple.', "L'Adoration", 'des', 'ma-', 'ges.', 'Le', 'Christ', 'apparaissant', 'à', 'sa', 'mère.', 'Cen-', 'tre', 'de', 'retable..,.o.', 'XXXII']
# ['2715', 'HoLBEiN', '2738', 'MAÎTRE', 'DE', 'LA', 'SAINTE', 'PARENTÉ']
# ['2738', 'a', 'Maître', 'de', 'Saint', 'Séverin.', '(fin', 'du', 'XVme', 'siècle).', '—', 'Sain-', 'te', 'Ursule', 'demandée', 'en', 'mariage.', 'XXXII']
# ['2738', 'b', '—', 'Départ', 'de', 'sainte', 'Ursule.,.,.', 'XXXII']
# ['2724', 'Mignon,', 'Abraham.', '(', '1640-1679).', '-', 'Le', 'nid', 'de', 'pinsons.', 'XXXII']
# ['2728', '—', 'Fleurs', 'et', 'fruits,', 'oiseaux,', 'insects.', 'XXXII']
# ['2730', 'Pencz,', 'Georg.', '(vers', '1500-1550).', '—', 'Saint', 'Jérôme.', '(Attribué)', 'XXXIII']
# ['S.', 'N"', 'Ring,', 'Ludger', 'Tom,', 'le', 'vieux.', '(1496-1547).', '—', 'Por-', 'trait', 'de', 'femme.', '(Attribué)', 'XXXII']
# ['2732', 'Rottenhammer,', 'Johann.', '(1564-1623).', '—', 'La', 'mort', "d'Adonis.", '(Attribué).', 'XXXIII']
# ['2734', 'Ruthart,', 'Karl', 'Andreas.', 'levers', '1640-après*', '1672).', '—', 'Chasse', 'à', "l'ours.", 'XXXIII']
#
# PAGE 172
# ['2735', 'Schweickardt', 'ou', 'Schweickhardt,', 'Heinrich', 'Wilhelm.', '(1746-1797).', '—', 'Patineurs', 'sur', 'un', 'canal', 'gelé.', 'XXXIII']
# ['S.', 'N°', 'Zeitblom,', 'Bartholme.', '(entre', '1450', 'et', '1455-', 'après', '1517).', '—', "L'Annonciation,", 'sainte', 'Anne', 'et', 'saint', 'Antoine.', '(Triptyque)', 'Coll.', 'Arconati-Visconti']
# ['2736', 'a', 'École', 'rhénane,', '(vers', '1340).', '—', 'L', 'Annonciation,', 'la', 'Nativité,', "l'Adoration", 'des', 'mages,', 'la', 'Présentation', 'au', 'temple.,.,.', 'XXXII']
# ['2740', 'École', 'de', "l'Allemagne", 'du', 'Sud,', 'commencement', 'du', 'XVIe', 'siècle.', '—', 'Portrait', 'de', 'Maximilien', 'r..r,', 'vers', '48', 'ans.', 'XXXII']
# ['2743', 'École', 'allemande,', 'commencement', 'du', 'XVIe', 'siècle.', '—', 'Portrait', 'de', 'Jean', 'Cingisus', 'XXXII']
# ['2745', '—', 'Le', 'jugement', 'de', 'Pâris.', 'XXXII']

# %% [markdown]
# # Items to artwork informations parsing

# %%
class Artwork():
    
    def __init__(self):
        self.author = ""
        self.number = ""
        self.life = ""
        self.title = ""
        self.position = ""
        self.note = ""
        self.raw = ""
    
    def todict(self):
        return {"number": self.number,"author":self.author,"life":self.life,\
                "title":self.title,"position":self.position, "raw":self.raw}

# %%
def merge_position(raw_position,current_position):
    """ 
    Fill a raw position containing a dash based on the current known position
  
    Parameters: 
    raw_position : the position to clean
    current_position : the known position
  
    Returns: 
    string : cleaned position 
  
    """
    
    dashes = ["-","—"]
    regex_dashes = "^- |^— | - | — |^-$|^—$| -$| —$"
    
    if re.search(regex_dashes,raw_position) == None:
        return raw_position
    
    raw_position = raw_position.split(" ")
    current_position = current_position.split(" ")
    
    raw_position.reverse()
    current_position.reverse()
    
    new_position = []
    
    if len(current_position) >= len(raw_position):
        i = 0
        while i < len(current_position):
            if i < len(raw_position) and raw_position[i] not in dashes:
                new_position.append(raw_position[i])
            else:
                new_position.append(current_position[i])
            i += 1
    else:
        new_position = raw_position
    
    new_position.reverse()
    
    return " ".join(new_position)

# %%
artwork_processed_list = []

for page in tqdm(raw_artworks_pages):
    
    current_author = ""
    current_life = ""
    current_position = ""
    
    for raw in page:
        
        art = Artwork()
        
        raw_text = " ".join(raw)
        
        art.raw = raw_text
        
        
        #Searching for number
        regex_num = "^\* |^\(?\d+\)? ?[a-z]? |^S\.? [NXo].? "

        for i, match in enumerate(re.finditer(regex_num,raw_text)):
            
            if i == 0 :
                (start,end) = match.span()
                art.number = raw_text[start:end]
                raw_text = raw_text[end:]
                
            else:
                raise ValueError("Multiple matches found for beginning of string")
        
        
        #Searching for author and his life
        regex_dash = "^- |^— "
        is_new_author = True
        
        for i, match in enumerate(re.finditer(regex_dash, raw_text)):
            if i == 0:
                is_new_author = False
                (start,end) = match.span()
                art.author = current_author
                art.life = current_life
                raw_text = raw_text[end:]
            else:
                raise ValueError("Multiple matches found for beginning of string")
        
        #First case standard, second case when only a century is indicated, third and fourth for OCR degenerated cases
        regex_life = "[ .]\([^()]+\d+[^()]+\)\.? |[ .]\([^()]+[IVX]+.?.? [^()]+\)\.? | .?.\d+-\d+..? | .\S*\d\S*-\S*\d\S*. "
        if is_new_author:
            #Case of anonymous authors
            regex_anonymous = "^Ecole .+ — |^École .+ — |^Première moitié du .+ — |^[XVI]+e Siècle.+ — |^Fin du .+ — "
            anonymous_match = re.search(regex_anonymous,raw_text)
            if anonymous_match != None:
                art.author = "<anonyme>"
                (start,end) = match.span()
                raw_text = raw_text[end:]
            else:    
                #Case of known authors
                for i, match in enumerate(re.finditer(regex_life, raw_text)):
                    if i == 0:
                        (start,end) = match.span()
                        art.life = raw_text[start:end]
                        art.author = raw_text[:start]
                        raw_text = raw_text[end:]
                    
                    
        #Searching for position
        #Three possible matches : dash, header (specials rooms), roman number (numbered rooms)
        
        #Eliminate some OCR parasits
        raw_text = re.sub("^\.|^\,|[.,][.,]+","",raw_text)
        raw_text = re.sub("--","-",raw_text)
        raw_text = raw_text.strip(" ")
        
        #Eliminate the dash at the begining of the line if it is still here
        for i, match in enumerate (re.finditer(regex_dash, raw_text)):
            if i == 0:
                (start, end) = match.span()
                raw_text = raw_text[end:]
            else:
                raise ValueError("Multiple matches found for beginning of string")
        
        
        regex_roman = "[1IXV]+-?.?$|[ABCD]-.$|[1IVX]+ tr\.? "
        roman_number_matches = re.finditer(regex_roman,raw_text)
        
        regex_header = " Ire | Palier | Musée | Coll\.? | Marine| Ga[li]\.? | Vest\.? | Esc\.? | Céramique | S\.? |" +\
    "T\.? T\.?$|E\.? F\.? | non exposé$| Nouv\.? Acq\.?$| Vestibule | Galerie | Ie? S\.? | IIe? S\.? | IIIe? S\.? | IVe? S\.? "
        header_matches = re.finditer(regex_header,raw_text)
        
        regex_dashes = " - | — | -$| —$"
        dash_matches = re.finditer(regex_dashes,raw_text)
        
        #Find separation. header has priority over dash, which has priority over roman number
        found_sep = False
        found_dash = False
        separator = len(raw_text)-1
        
        for i, match in enumerate(header_matches):
            if i == 0:
                found_sep = True
                separator = match.span()[0]
        
        if not found_sep:
            for i, match in enumerate(dash_matches):
                found_sep = True
                separator = match.span()[0]               
        
        if not found_sep:
            for i, match in enumerate(roman_number_matches):
                if i == 0:
                    found_sep = True
                    separator = match.span()[0]
        
        art.title = raw_text[:separator]
        
        if found_sep:
            art.position = merge_position(raw_text[separator:].strip(" "),current_position)
        
            
        current_author = art.author
        current_life = art.life
        current_position = art.position
        
        artwork_processed_list.append(art.todict())
# Out:
# HBox(children=(IntProgress(value=0, max=172), HTML(value='')))

# %%
artworks_df = pd.DataFrame(artwork_processed_list)

# %%
#Feedback loop
#for row in artworks_df[artworks_df.life.apply(lambda x : re.search("\d",x) == None)].iterrows():
#for row in artworks_df.iterrows():
    #print(row)

artworks_df.sample(20)
# Out:
#       number                                             author  \
# 257     158                                       Coypel, Noël.
# 629       *                     Guérin, Pierre-Narcisse, baron.
# 40    S. N°                            Borowikoffsky, Wladimir.
# 716     434                                     Jouvenet, Jean.
# 1636   1308   PARIS, MUSÉE NATIONAL DU LOUVRE U5 Ghirlandajo...
# 381     211                 Delacroix, Ferdinand-Victor-Eugène.
# 2128   1991            Franck ou Francken, Frans, dit le jeune.
# 48       37                                  Boucher, François.
# 2080   1943                             Champaigne, Philippe de
# 664    2947                                         Huet, Paul.
# 319   197 b                               David, Jacques-Louis.
# 1495   1147       Barbieri, Giovanni-Francesco, dit Le Guerchin
# 109       *                       Carolus-Duran, Emile-Auguste.
# 815           PARIS, MUSÉE NATIONAL DU LOUVRE 47 Le Nain, le...
# 2264   2156
# 732     454                                La Hyre, Laurent de.
# 463   S. Nu                                    Ducreux, Joseph.
# 1585   1250   Castiglione, Giovanni-Benedetto, dit Il Grechetto
# 2269   2162                       Teniers, David, dit le jeune.
# 1604   1295
#
#                                                    life  \
# 257                                       (1628-1707).
# 629                                       (1774-1833).
# 40                                        (1757-1825).
# 716                                       (1614-1717).
# 1636                                     (1632-170=;).
# 381                                       (1798-1863).
# 2128                                     i 1581-1642 —
# 48                                        (1703-1770).
# 2080                                      (1602-1674).
# 664                          (1803-1869).—L'inondation
# 319                                       (1748-1825).
# 1495                                      (1591-1666).
# 109                                       11837-1917).
# 815    (travaillaient dans la première moitié et le ...
# 2264
# 732                                       (1606-1656).
# 463                                       (1737-1802).
# 1585                              (1617-1665 ou 1670).
# 2269                                      (IÔIO-I6QO).
# 1604
#
#                                                   title  \
# 257   Ptolémée Philadelphe donnant la liberté aux ju...
# 629   Deux génies de l'immortalité; médaillon du pla...
# 40    Portrait de l'impératrice Elisabeth de Russie ...
# 716                          La résurrection de Lazare
# 1636                          Le mariage de la Vierge.
# 381                                Noce juive au Maroc
# 2128                              La Passion. , , , o.
# 48                                 Vertumne et Pomone.
# 2080                        Portrait de femme inconnue
# 664   Grande marée d'équinoxe aux environs de Hon- f...
# 319                        Portrait de Madame Sériziat
# 1495                                             Circé
# 109     Le tri- omphe de Marie de Médicis. Plafond. 4me
# 815                  Antoine (probablement i =188-1648)
# 2264  -* L'enfant prodigue à table avec des courtisa...
# 732   Saint Pierre guérissant les malades avec son o...
# 463               Son portrait, par lui-même. Pastel. ,
# 1585                           Melchisédech et Abraham
# 2269        La partie de cartes dans une hôtellerie o.
# 1604                          BOTTICELLI 12q6 BOTTICELL
#
#                       position  \
# 257                      XIV-N
# 629            S. des Antonins
# 40           Coll. Schlichting
# 716                      XIV-S
# 1636                       1-0
# 381                     VIII-N
# 2128                     XXXIV
# 48                       XVI-S
# 2080                       XII
# 664   E. F. XIXe S. 2e étage 1
# 319                      III-N
# 1495                VI tr. D-N
# 109         S. Meubles XVIIIme
# 815
# 2264                VI tr. E-N
# 732                      XIV-E
# 463             S. des Pastels
# 1585                VI tr. D-N
# 2269                     XXXIV
# 1604                         I
#
#                                                     raw
# 257   158 — Ptolémée Philadelphe donnant la liberté ...
# 629   * — Deux génies de l'immortalité; médaillon du...
# 40    S. N° Borowikoffsky, Wladimir. (1757-1825). — ...
# 716               434 — La résurrection de Lazare XIV-S
# 1636                1308 — Le mariage de la Vierge. 1-0
# 381                    211 - Noce juive au Maroc VIII-N
# 2128                  1991 — La Passion. , , , o. XXXIV
# 48                       37 - Vertumne et Pomone. XVI-S
# 2080              1943 — Portrait de femme inconnue XII
# 664   2947 — Grande marée d'équinoxe aux environs de...
# 319           197 b — Portrait de Madame Sériziat III-N
# 1495                            1147 — Circé VI tr. D-N
# 109   * Carolus-Duran, Emile-Auguste. 11837-1917). -...
# 815   PARIS, MUSÉE NATIONAL DU LOUVRE 47 Le Nain, le...
# 2264  2156 -* L'enfant prodigue à table avec des cou...
# 732   454 — Saint Pierre guérissant les malades avec...
# 463     S. Nu — Son portrait, par lui-même. Pastel. , —
# 1585  1250 Castiglione, Giovanni-Benedetto, dit Il G...
# 2269  2162 — La partie de cartes dans une hôtellerie...
# 1604                    1295 BOTTICELLI 12q6 BOTTICELLI

# %%
#Sample of some uncorrectely parsed paintings
artworks_df[artworks_df.author.apply(lambda p : len(p) == 0)].sample(10)
# Out:
#        number author life                                              title  \
# 434     2860                                               Les deux rivales
# 1141   S. N°                              Portrait de Mme A. Fouques Duparc.
# 1458   S. N"               Portrait présumé de Madame Louise, fille de Lo...
# 651      410                                                              CI
# 1339     950               Vue de la ville et du port de Bayonne, prise d...
# 370    (224)               Femme dans une baignoire s'épongeant la jambe ...
# 2153    2208                                                         et 2209
# 2326  2018 b               Religieux offrant son cœur à l'Enfant Jésus (G...
# 647        *               Plafond : Le Vésuve reçoit de Jupiter le feu q...
# 151    S. N°                                              Le souffleur. , ,
#
#                                                position  \
# 434                                               T. T.
# 1141                                           Marine 1
# 1458                                     S. des Pastels
# 651                        - La leçon de musique. XVI-S
# 1339
# 370   Coll. Camondo (159^ i36) La femme à la potiche...
# 2153  — Adam et Eve (Revers de deux volets de trip- ...
# 2326                                               XXXI
# 647                           Céramique antique S. VIII
# 151                                               XVI-S
#
#                                                     raw
# 434                       2860 — Les deux rivales T. T.
# 1141  S. N° — Portrait de Mme A. Fouques Duparc. Mar...
# 1458  S. N" — Portrait présumé de Madame Louise, fil...
# 651                 410 CI - La leçon de musique. XVI-S
# 1339  950 — Vue de la ville et du port de Bayonne, p...
# 370   (224) — Femme dans une baignoire s'épongeant l...
# 2153  2208 et 2209 — Adam et Eve (Revers de deux vol...
# 2326  2018 b — Religieux offrant son cœur à l'Enfant...
# 647   * - Plafond : Le Vésuve reçoit de Jupiter le f...
# 151                    S. N° -- Le souffleur. , , XVI-S

# %%
#Liste de problèmes:
# Gai. au lieu de Gal.
# Deux auteurs au lieu d'un
# ; au lieu de -
# Chiffre romain pas en fin de chaîne (Bourguignon)
# Erreur d'OCR qui se répercute (principalement des dates très dégénérées)
## Solution possible : parenthèse de fin et tiret souvent bien conservés, comme dans "nooo-tyyo)"
# Lettre post-numéro OCRisée en chiffre (87 1 au lieu de 87 b)
# Quelques mauvais split d'oeuvres (121 c)
# Parenthèse transformée en chevron (124>
# Oeuvres multiples séparées par des tirets
# Vestibule ou Galerie écrit en toutes lettres et pas abrégés.
# Manque une parenthèse gauche sur les numéros: 162)



for row in artworks_df\
[(artworks_df.author.apply(lambda p : len(p) == 0)) | (artworks_df.position.apply(lambda p : len(p) == 0))].iterrows():
#for row in artworks_df.iterrows():
    print("Raw@",row[1].raw)
    print("Numéro@",row[1].number)
    print("Auteur@",row[1].author)
    print("Vie@",row[1].life)
    print("Titre@",row[1].title)
    print("Position@",row[1].position)
    print("\n")
# Out:
# Raw@ S. N° — L'Odalisque, Victoire O'Murphy. ;
# Numéro@ S. N°
# Auteur@ Boucher, François.
# Vie@  (1703-1770).
# Titre@ L'Odalisque, Victoire O'Murphy.
# Position@
#
#
# Raw@ S. N° — Le sommeil des amours —
# Numéro@ S. N°
# Auteur@ Boucher, François.
# Vie@  (1703-1770).
# Titre@ Le sommeil des amours
# Position@
#
#
# Raw@ S. N° — Mme de Pompadour. Pastel. (Attribué). -
# Numéro@ S. N°
# Auteur@ Boucher, François.
# Vie@  (1703-1770).
# Titre@ Mme de Pompadour. Pastel. (Attribué).
# Position@
#
#
# Raw@ 45 FR. BOUCHER 5° FR. BOUCHER
# Numéro@ 45
# Auteur@
# Vie@
# Titre@ FR. BOUCHER 5° FR. BOUCHE
# Position@
#
#
# Raw@ 2932 Cals, Adolphe-Félix. i i S i o- i SSo). — Femmes effilant de l'étoupe E. F. XIXe S.2e étage II
# Numéro@ 2932
# Auteur@
# Vie@
# Titre@ Cals, Adolphe-Félix. i i
# Position@ S i o- i SSo). — Femmes effilant de l'étoupe E. F. XIXe S.2e étage II
#
#
# Raw@ 2933 — Lard et harengs —
# Numéro@ 2933
# Auteur@
# Vie@
# Titre@ Lard et harengs
# Position@ S i o- i SSo). — Femmes effilant de l'étoupe E. F. XIXe S.2e étage II
#
#
# Raw@ 2934 — Soleil couchant. —
# Numéro@ 2934
# Auteur@
# Vie@
# Titre@ Soleil couchant.
# Position@ S i o- i SSo). — Femmes effilant de l'étoupe E. F. XIXe S.2e étage II
#
#
# Raw@ 2935 — Etude de femme. 2936 — Le déjeuner à Honfleur..,. —
# Numéro@ 2935
# Auteur@
# Vie@
# Titre@ Etude de femme. 2936 — Le déjeuner à Honfleur
# Position@ S i o- i SSo). — Femmes effilant de l'étoupe E. F. XIXe S.2e étage II
#
#
# Raw@ 87 1, - Bal aux Tuileries 1867. -
# Numéro@ 87
# Auteur@
# Vie@
# Titre@ 1, - Bal aux Tuileries 1867.
# Position@ E. F. XIXe S. 2e étage II
#
#
# Raw@ 87 c — L'attentat de Berezowski au bois de Boulogne (Juillet 1867) .,. —
# Numéro@ 87 c
# Auteur@
# Vie@
# Titre@ L'attentat de Berezowski au bois de Boulogne (Juillet 1867)
# Position@ E. F. XIXe S. 2e étage II
#
#
# Raw@ 117 Chardin, Jean-Baptiste-Siméon. nooo-tyyo). — Les apprêts du pot-au-feu. (Attribué). 1-0
# Numéro@ 117
# Auteur@
# Vie@
# Titre@ Chardin, Jean-Baptiste-Siméon. nooo-tyyo).
# Position@ — Les apprêts du pot-au-feu. (Attribué). 1-0
#
#
# Raw@ 118 - Le retour de l'école. (École dei. I-E
# Numéro@ 118
# Auteur@
# Vie@
# Titre@ Le retour de l'école. (École dei.
# Position@ I-E
#
#
# Raw@ S. N° -- Le souffleur. , , XVI-S
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Le souffleur. , ,
# Position@ XVI-S
#
#
# Raw@ S. X" — Portrait en buste de la femme de Chardin. Pastel. S. des Pastels
# Numéro@ S. X"
# Auteur@
# Vie@
# Titre@ Portrait en buste de la femme de Chardin. Pastel.
# Position@ S. des Pastels
#
#
# Raw@ S. N" - Portrait de Chardin par lui-même, avec abat-jour vert par-dessus le bonnet blanc. Pastel. —
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait de Chardin par lui-même, avec abat-jour vert par-dessus le bonnet blanc. Pastel.
# Position@ S. des Pastels
#
#
# Raw@ 146 a 1 — Le ruisseau couvert —
# Numéro@ 146 a
# Auteur@
# Vie@
# Titre@ 1 — Le ruisseau couvert
# Position@ E. F. XIXe S' 1er étage II
#
#
# Raw@ 155 Cousin le fils, Jean. \mort vers 1592). - Le Jugement dernier XI
# Numéro@ 155
# Auteur@
# Vie@
# Titre@ Cousin le fils, Jean. \mort vers 1592).
# Position@ - Le Jugement dernier XI
#
#
# Raw@ 184 Daubigny, Charles-François. Ils 1 ï- r SIS)' - Les vendanges en Bourgogne.,. VIII-N
# Numéro@ 184
# Auteur@
# Vie@
# Titre@ Daubigny, Charles-François. Ils 1 ï- r SIS)'
# Position@ - Les vendanges en Bourgogne VIII-N
#
#
# Raw@ 184 il — La mare. (La grande vallée d'Optevoz) E. F. XIXe S. 2e étage 1
# Numéro@ 184
# Auteur@
# Vie@
# Titre@ il — La mare. (La grande vallée d'Optevoz)
# Position@ E. F. XIXe S. 2e étage 1
#
#
# Raw@ 199 J.-L. DAVID 202 il J.-L. DAVID
# Numéro@ 199
# Auteur@
# Vie@
# Titre@ J.-L. DAVID 202 il J.-L. DA
# Position@ VID
#
#
# Raw@ 205 b — La défaite des Cimbres VIII-S H)7 J.-L. DAVID (Ibo) E. DEGAS
# Numéro@ 205 b
# Auteur@ Decamps, Alexandre-Gabriel.
# Vie@  (1803-1860).
# Titre@ La défaite des Cimbres VIII-S H)7 J.-L. DAVID (Ibo) E. DEGA
# Position@
#
#
# Raw@ 1166 ) — Aux courses. Jockeys amateurs près d'une voiture —
# Numéro@ 1166
# Auteur@
# Vie@
# Titre@ ) — Aux courses. Jockeys amateurs près d'une voiture
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ 167) — Danseuses montant un escalier —
# Numéro@ 167)
# Auteur@
# Vie@
# Titre@ Danseuses montant un escalier
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ 168) — Les repasseuses. —
# Numéro@ 168)
# Auteur@
# Vie@
# Titre@ Les repasseuses.
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ 217) — La Danseuse au bouquet saluant sur la scène. Pastel —
# Numéro@ 217)
# Auteur@
# Vie@
# Titre@ La Danseuse au bouquet saluant sur la scène. Pastel
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ (218) — Danseuse vue de dos. Dessin — v219) — Danseuse tenant un bouquet. Fin d'arabesque Pastel. -
# Numéro@ (218)
# Auteur@
# Vie@
# Titre@ Danseuse vue de dos. Dessin — v219) — Danseuse tenant un bouquet. Fin d'arabesque Pastel.
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ 1220) — Le Café-Concert. Pastel -
# Numéro@ 1220)
# Auteur@
# Vie@
# Titre@ Le Café-Concert. Pastel
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ (221) — Après le bain. — Femme s'essuyant les pieds - (222* — Le tub. —
# Numéro@ (221)
# Auteur@
# Vie@
# Titre@ Après le bain. — Femme s'essuyant les pieds - (222* — Le tub.
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ 1223 > — Trois études de la tête d'une danseuse. Dessin -
# Numéro@ 1223
# Auteur@
# Vie@
# Titre@ > — Trois études de la tête d'une danseuse. Dessin
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ (224) — Femme dans une baignoire s'épongeant la jambe Pastel. —
# Numéro@ (224)
# Auteur@
# Vie@
# Titre@ Femme dans une baignoire s'épongeant la jambe Pastel.
# Position@ Coll. Camondo (159^ i36) La femme à la potiche. , galerie
#
#
# Raw@ (46) DIAZ S. Nü FANTIN-LATOUR
# Numéro@ (46)
# Auteur@
# Vie@
# Titre@ DIAZ
# Position@ S. Nü FANTIN-LATOUR
#
#
# Raw@ 2859 V l'nus désarmant l'Amour T. T.
# Numéro@ 2859
# Auteur@
# Vie@
# Titre@ V l'nus désarmant l'Amour
# Position@ T. T.
#
#
# Raw@ 2860 — Les deux rivales T. T.
# Numéro@ 2860
# Auteur@
# Vie@
# Titre@ Les deux rivales
# Position@ T. T.
#
#
# Raw@ 2861 — Sous hois. T. T.
# Numéro@ 2861
# Auteur@
# Vie@
# Titre@ Sous hois.
# Position@ T. T.
#
#
# Raw@ 2862 - La charité. T. T.
# Numéro@ 2862
# Auteur@
# Vie@
# Titre@ La charité.
# Position@ T. T.
#
#
# Raw@ 2863 - L'éplorée. -.,. -. T. T. ,41 — Vaches dans la forêt. Coll. Chauchard II
# Numéro@ 2863
# Auteur@
# Vie@
# Titre@ L'éplorée. - -. T. T. ,41 — Vaches dans la forêt.
# Position@ Coll. Chauchard II
#
#
# Raw@ (42 — Mare sous les chênes.,.,. — 1 143' - La route sous bois..,. - , , ., - galerie \44-1 — Les hauteurs de Jean-de-Paris. Forêt de Fontainebleau — galerie (45* — La forêt de Fontainebleau, enceinte palissadée — galerie
# Numéro@ (42
# Auteur@
# Vie@
# Titre@ Mare sous les chênes — 1 143' - La route sous bois - , ,  - galerie \44-1 — Les hauteurs de Jean-de-Paris. Forêt de Fontainebleau — galerie (45* — La forêt de Fontainebleau, enceinte palissadée
# Position@ Coll. Chauchard galerie
#
#
# Raw@ 146 * — Le braconnier. - — III
# Numéro@ 146
# Auteur@
# Vie@
# Titre@ * — Le braconnier.
# Position@ Coll. Chauchard III
#
#
# Raw@ (47) - La ninro au gamin agenouillé. — 1
# Numéro@ (47)
# Auteur@
# Vie@
# Titre@ La ninro au gamin agenouillé.
# Position@ Coll. Chauchard 1
#
#
# Raw@ (481 - Lisière de forêt. — III
# Numéro@ (481
# Auteur@
# Vie@
# Titre@ Lisière de forêt.
# Position@ Coll. Chauchard III
#
#
# Raw@ (491 — Le puits. Nymphes et Amours - galerie 150, ymphc endormie.,. — 1
# Numéro@ (491
# Auteur@
# Vie@
# Titre@ Le puits. Nymphes et Amours - galerie 150, ymphc endormie
# Position@ Coll. Chauchard 1
#
#
# Raw@ (51 — Nymphe caressant l'Amour.,. — galerie (52' — Nymphe réprimandant l'Amour — IV
# Numéro@ (51
# Auteur@
# Vie@
# Titre@ Nymphe caressant l'Amour — galerie (52' — Nymphe réprimandant l'Amour
# Position@ Coll. Chauchard IV
#
#
# Raw@ (531 — Les caresses de l'Amour. - , - , - galerie <54) — La magicienne., - , , — IV
# Numéro@ (531
# Auteur@
# Vie@
# Titre@ Les caresses de l'Amour. - , - , - galerie <54) — La magicienne - , ,
# Position@ Coll. Chauchard IV
#
#
# Raw@ (55 — Le matéfice. - galerie
# Numéro@ (55
# Auteur@
# Vie@
# Titre@ Le matéfice.
# Position@ Coll. Chauchard galerie
#
#
# Raw@ 2875 - Soleil couchant après l'orage T. T. (
# Numéro@ 2875
# Auteur@ Dupré, Jules.
# Vie@  (1811-1889).
# Titre@ Soleil couchant après l'orage T. T.
# Position@
#
#
# Raw@ S. Nu Eriksen, Vigilius. — Portrait de l'empereur de Russie Paul ier, enfant (D'après) -;. Coll. Schlichting
# Numéro@ S. Nu
# Auteur@
# Vie@
# Titre@ Eriksen, Vigilius. — Portrait de l'empereur de Russie Paul ier, enfant (D'après) -;.
# Position@ Coll. Schlichting
#
#
# Raw@ 284 FLANDRIN ¿lj3 FKAÙOSAKD
# Numéro@ 284
# Auteur@
# Vie@
# Titre@ FLANDRIN ¿lj3 FKAÙOSAK
# Position@
#
#
# Raw@ 299 — Figure de fantaisie. Portrait de l'abbé de St Non 1-0 2Q" FRAGONARD 298 FRAGONARD
# Numéro@ 299
# Auteur@ Fragonard, Jean-Honoré.
# Vie@  (1732-1806).
# Titre@ Figure de fantaisie. Portrait de l'abbé de St Non 1-0 2Q" FRAGONARD 298 FRAGONAR
# Position@
#
#
# Raw@ 314 GELLEE 31b GELLEE
# Numéro@ 314
# Auteur@
# Vie@
# Titre@ GELLEE 31b GELLE
# Position@
#
#
# Raw@ 335 — Portrait de l'impératrice Marie-Louise. I-S 32N GÉRARD 338 GERICAULT
# Numéro@ 335
# Auteur@ Gérard, François-Pascal-Simon, baron.
# Vie@  (1770-18; 7).
# Titre@ Portrait de l'impératrice Marie-Louise. I-S 32N GÉRARD 338 GERICAUL
# Position@
#
#
# Raw@ 360 Girodet de Roucy Trioson, Anne-Louis. (1707-1824). — Scène du déluge. Ill-E
# Numéro@ 360
# Auteur@ Girodet de Roucy Trioson, Anne-Louis.
# Vie@  (1707-1824).
# Titre@ Scène du déluge. Ill-
# Position@
#
#
# Raw@ * Gosse, Nicolas-Louis-François. Voir Vinchon.
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Gosse, Nicolas-Louis-François. Voir Vinchon
# Position@
#
#
# Raw@ 382 - Son portrait, par lui-même. L-E
# Numéro@ 382
# Auteur@ Greuze, Jean-Baptiste.
# Vie@  (1725-1805).
# Titre@ Son portrait, par lui-même. L-
# Position@
#
#
# Raw@ S. N° — Portrait d'Edouard Bertin.> XYPS
# Numéro@ S. N°
# Auteur@ Greuze, Jean-Baptiste.
# Vie@  (1725-1805).
# Titre@ Portrait d'Edouard Bertin.> XYP
# Position@
#
#
# Raw@ S. No - Portrait supposé de Jacques-Ange Gabriel,architecte :—
# Numéro@ S. No
# Auteur@ Greuze, Jean-Baptiste.
# Vie@  (1725-1805).
# Titre@ Portrait supposé de Jacques-Ange Gabriel,architecte :
# Position@
#
#
# Raw@ * Heim, François-Joseph. — Plafond: La renaissance des arts en France. — Voussures: Huit tableaux tirés de l'histoire de France Céramique antique S. V
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Heim, François-Joseph. — Plafond: La renaissance des arts en France. — Voussures: Huit tableaux tirés de l'histoire de France
# Position@ Céramique antique S. V
#
#
# Raw@ * - Plafond : Le Vésuve reçoit de Jupiter le feu qui doit consumer Herculanum, Pompeï et Stabies. — Voussures: six tableaux dont quatre de scènes de désolation, puis : mort de Pline l'ancien, Pline le jeune écrivant ses lettres — VIII
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Plafond : Le Vésuve reçoit de Jupiter le feu qui doit consumer Herculanum, Pompeï et Stabies. — Voussures: six tableaux dont quatre de scènes de désolation, puis : mort de Pline l'ancien, Pline le jeune écrivant ses lettres
# Position@ Céramique antique S. VIII
#
#
# Raw@ 410 CI - La leçon de musique. XVI-S
# Numéro@ 410
# Auteur@
# Vie@
# Titre@ CI
# Position@ - La leçon de musique. XVI-S
#
#
# Raw@ 410 b Hirn, Jean-Georges. \1 ïïï- r 839). - Heurs et fruits. S. dessins XIXe S.
# Numéro@ 410 b
# Auteur@
# Vie@
# Titre@ Hirn, Jean-Georges. \1 ïïï- r 839). - Heurs et fruits.
# Position@ S. dessins XIXe S.
#
#
# Raw@ 410 il — Vue du port de Lorient, prise des anciennes cales de Caudant , —
# Numéro@ 410
# Auteur@
# Vie@
# Titre@ il — Vue du port de Lorient, prise des anciennes cales de Caudant ,
# Position@ Marine
#
#
# Raw@ 410 e — Vue de l'intérieur du port de Brest, prise de l'ancienne cale de l'Intendance. —
# Numéro@ 410 e
# Auteur@
# Vie@
# Titre@ Vue de l'intérieur du port de Brest, prise de l'ancienne cale de l'Intendance.
# Position@ Marine
#
#
# Raw@ 410 f — Vue du même port, prise de la cale couverte, en regardant le château —
# Numéro@ 410 f
# Auteur@
# Vie@
# Titre@ Vue du même port, prise de la cale couverte, en regardant le château
# Position@ Marine
#
#
# Raw@ 416 INGRES pX b INGRES
# Numéro@ 416
# Auteur@
# Vie@
# Titre@ INGRES pX b INGRE
# Position@
#
#
# Raw@ 417 — Homère déifié., .,.,., , , VIII, panneau
# Numéro@ 417
# Auteur@ Ingres, Jean-Auguste-Dominique.
# Vie@  (1780-1*671.
# Titre@ Homère déifié  , , VIII, pannea
# Position@
#
#
# Raw@ S. Nu — Homère déifié; composition postérieure au tableau, dessin. XV, panneau
# Numéro@ S. Nu
# Auteur@ Ingres, Jean-Auguste-Dominique.
# Vie@  (1780-1*671.
# Titre@ Homère déifié; composition postérieure au tableau, dessin. XV, pannea
# Position@
#
#
# Raw@ S. Nu INGRES 430 a JACQUE
# Numéro@ S. Nu
# Auteur@
# Vie@
# Titre@ INGRES 430 a JACQU
# Position@
#
#
# Raw@ 494 Le Brun, Charles. ( IÔIQ-IÔOO). — L'adoration des bergers. XV-S
# Numéro@ 494
# Auteur@
# Vie@
# Titre@ Le Brun, Charles. ( IÔIQ-IÔOO).
# Position@ — L'adoration des bergers. XV-S
#
#
# Raw@ 496 — Sainte FamiDe, dite «Le Bénédicités. XIV-N
# Numéro@ 496
# Auteur@
# Vie@
# Titre@ Sainte FamiDe, dite «Le Bénédicités.
# Position@ XIV-N
#
#
# Raw@ 497 — Le Christ servi dans le désert par les anges. XIV-N
# Numéro@ 497
# Auteur@
# Vie@
# Titre@ Le Christ servi dans le désert par les anges.
# Position@ XIV-N
#
#
# Raw@ 498 — Entrée de Jésus-Christ dans Jérusalem XV-N
# Numéro@ 498
# Auteur@
# Vie@
# Titre@ Entrée de Jésus-Christ dans Jérusalem
# Position@ XV-N
#
#
# Raw@ 499 — Jésus portant sa croix. XV-S
# Numéro@ 499
# Auteur@
# Vie@
# Titre@ Jésus portant sa croix.
# Position@ XV-S
#
#
# Raw@ 500 — Jésus élevé en croix S. Isabey
# Numéro@ 500
# Auteur@
# Vie@
# Titre@ Jésus élevé en croix
# Position@ S. Isabey
#
#
# Raw@ 501 — Le crucifix aux anges. XIV-S
# Numéro@ 501
# Auteur@
# Vie@
# Titre@ Le crucifix aux anges.
# Position@ XIV-S
#
#
# Raw@ 502 — Le Christ mort sur les genoux de la Vierge XIV-S
# Numéro@ 502
# Auteur@
# Vie@
# Titre@ Le Christ mort sur les genoux de la Vierge
# Position@ XIV-S
#
#
# Raw@ 504 — Le martyre de St. Etienne. XIV-N
# Numéro@ 504
# Auteur@
# Vie@
# Titre@ Le martyre de St. Etienne.
# Position@ XIV-N
#
#
# Raw@ 505 — Sainte Madeleine renonçant aux vanités de la vie XIV-N
# Numéro@ 505
# Auteur@
# Vie@
# Titre@ Sainte Madeleine renonçant aux vanités de la vie
# Position@ XIV-N
#
#
# Raw@ 509 — Le passage du Granique XV-E
# Numéro@ 509
# Auteur@
# Vie@
# Titre@ Le passage du Granique
# Position@ XV-E
#
#
# Raw@ 510 — La bataille d'Arbelles XV-S
# Numéro@ 510
# Auteur@
# Vie@
# Titre@ La bataille d'Arbelles
# Position@ XV-S
#
#
# Raw@ 512 — Alexandre et Porus. XV-N
# Numéro@ 512
# Auteur@
# Vie@
# Titre@ Alexandre et Porus.
# Position@ XV-N
#
#
# Raw@ 513 — Entrée d'Alexandre le Grand dans Babylone XV-0 =>2 2 VIGÉE LE BRUN =;20 VIGÉE LE BRUN
# Numéro@ 513
# Auteur@
# Vie@
# Titre@ Entrée d'Alexandre le Grand dans Babylone XV-0 =>2 2 VIGÉE LE BRUN =;20 VIGÉE LE BRU
# Position@
#
#
# Raw@ 514 Le Brun, Charles. ( IÛIO-IOQO). — La chasse de Méléagre et d'Atalante , XIV-S
# Numéro@ 514
# Auteur@
# Vie@
# Titre@ Le Brun, Charles. ( IÛIO-IOQO).
# Position@ — La chasse de Méléagre et d'Atalante , XIV-S
#
#
# Raw@ 515 — La mort de Méléagre XIV-S
# Numéro@ 515
# Auteur@
# Vie@
# Titre@ La mort de Méléagre
# Position@ XIV-S
#
#
# Raw@ 518 — Portrait du peintre Louis Testelin XIV-N
# Numéro@ 518
# Auteur@
# Vie@
# Titre@ Portrait du peintre Louis Testelin
# Position@ XIV-N
#
#
# Raw@ S. N" — Portrait de Louis XIV jeune. Pastel. XIV-N — Le Soir, ou Morphée. Voûte Galerie d'Apollon — La Nuit, ou Diane. Voitte -
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait de Louis XIV jeune. Pastel. XIV-N — Le Soir, ou Morphée. Voûte
# Position@ Galerie d'Apollon — La Nuit, ou Diane. Voitte -
#
#
# Raw@ * — Le Triomphe des eaux, ou Neptune et Amphitrite. Voussures.. ".,.,.,.-
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Le Triomphe des eaux, ou Neptune et Amphitrite. Voussures "
# Position@
#
#
# Raw@ PARIS, MUSÉE NATIONAL DU LOUVRE 47 Le Nain, les frères Antoine, Louis et Mathieu. (travaillaient dans la première moitié et le milieu du XVIIme siècle). Antoine (probablement i =188-1648).
# Numéro@
# Auteur@ PARIS, MUSÉE NATIONAL DU LOUVRE 47 Le Nain, les frères Antoine, Louis et Mathieu.
# Vie@  (travaillaient dans la première moitié et le milieu du XVIIme siècle).
# Titre@ Antoine (probablement i =188-1648)
# Position@
#
#
# Raw@ 542 LE NAIN SOS LE SUEUR Ecole des Le Nain. 541 — Le repas villageois. XII
# Numéro@ 542
# Auteur@
# Vie@
# Titre@ LE NAIN SOS LE SUEUR Ecole des Le Nain. 541
# Position@ — Le repas villageois. XII
#
#
# Raw@ 580 Le Sueur, Eustache. (iôié-iô^). - Saint Bruno refuse l'archevêché de Reggio que lui offre Urbain II. XIV-S
# Numéro@ 580
# Auteur@
# Vie@
# Titre@ Le Sueur, Eustache. (iôié-iô^).
# Position@ - Saint Bruno refuse l'archevêché de Reggio que lui offre Urbain II. XIV-S
#
#
# Raw@ 581 — Saint Bruno en prière dans sa cellule rustique, non exposé
# Numéro@ 581
# Auteur@
# Vie@
# Titre@ Saint Bruno en prière dans sa cellule rustique,
# Position@ non exposé
#
#
# Raw@ 582 — Rencontre de saint Bruno par le comte Roger —
# Numéro@ 582
# Auteur@
# Vie@
# Titre@ Rencontre de saint Bruno par le comte Roger
# Position@ non exposé
#
#
# Raw@ 583 — Apparition de saint Bruno au comte Roger —
# Numéro@ 583
# Auteur@
# Vie@
# Titre@ Apparition de saint Bruno au comte Roger
# Position@ non exposé
#
#
# Raw@ 584 — Mort de saint Bruno. XIV-N
# Numéro@ 584
# Auteur@
# Vie@
# Titre@ Mort de saint Bruno.
# Position@ XIV-N
#
#
# Raw@ 585 — Saint Bruno est enlevé au ciel. non exposé
# Numéro@ 585
# Auteur@
# Vie@
# Titre@ Saint Bruno est enlevé au ciel.
# Position@ non exposé
#
#
# Raw@ 586 — Saint Bruno et ses compagnons distribuent tous leurs biens aux pauvres. Esquisse.,. XIII
# Numéro@ 586
# Auteur@
# Vie@
# Titre@ Saint Bruno et ses compagnons distribuent tous leurs biens aux pauvres. Esquisse
# Position@ XIII
#
#
# Raw@ 587 — Saint Bruno examine le plan de la Chartreuse de Rome. non exposé
# Numéro@ 587
# Auteur@
# Vie@
# Titre@ Saint Bruno examine le plan de la Chartreuse de Rome.
# Position@ non exposé
#
#
# Raw@ 588 — Plan de l'ancienne Chartreuse de Paris, porté par deux an ges XIV-S
# Numéro@ 588
# Auteur@
# Vie@
# Titre@ Plan de l'ancienne Chartreuse de Paris, porté par deux an ges
# Position@ XIV-S
#
#
# Raw@ 589 — Dédicace de l'église des Chartreux. XIV-S
# Numéro@ 589
# Auteur@
# Vie@
# Titre@ Dédicace de l'église des Chartreux.
# Position@ XIV-S
#
#
# Raw@ 590 — Réunion d'artistes. XV-0
# Numéro@ 590
# Auteur@
# Vie@
# Titre@ Réunion d'artistes.
# Position@ XV-0
#
#
# Raw@ 591 — La naissance de l'Amour. XIV-N
# Numéro@ 591
# Auteur@
# Vie@
# Titre@ La naissance de l'Amour.
# Position@ XIV-N
#
#
# Raw@ 592 — Vénus présente l'Amour à Jupiter.,. —
# Numéro@ 592
# Auteur@
# Vie@
# Titre@ Vénus présente l'Amour à Jupiter
# Position@ XIV-N
#
#
# Raw@ 593 — L'Amour, réprimandé par sa mère, se réfugie dans les bras de Cérès.,. —
# Numéro@ 593
# Auteur@
# Vie@
# Titre@ L'Amour, réprimandé par sa mère, se réfugie dans les bras de Cérès
# Position@ XIV-N
#
#
# Raw@ 594 — L'Amour reçoit l'hommage des dieux. —
# Numéro@ 594
# Auteur@
# Vie@
# Titre@ L'Amour reçoit l'hommage des dieux.
# Position@ XIV-N
#
#
# Raw@ 595 — L'Amour ordonne à Mercure d'annoncer son pouvoir à l'univers.,. XIV-S
# Numéro@ 595
# Auteur@
# Vie@
# Titre@ L'Amour ordonne à Mercure d'annoncer son pouvoir à l'univers
# Position@ XIV-S
#
#
# Raw@ 596 — L'Amour dérobe la foudre de Jupiter XIII
# Numéro@ 596
# Auteur@
# Vie@
# Titre@ L'Amour dérobe la foudre de Jupiter
# Position@ XIII
#
#
# Raw@ 597 — Phaéton demande à Apollon la conduite du char du Soleil.,. XIV-N
# Numéro@ 597
# Auteur@
# Vie@
# Titre@ Phaéton demande à Apollon la conduite du char du Soleil
# Position@ XIV-N
#
#
# Raw@ 598 — Clio, Euterpe et Thalie. —
# Numéro@ 598
# Auteur@
# Vie@
# Titre@ Clio, Euterpe et Thalie.
# Position@ XIV-N
#
#
# Raw@ 599 — Melpomène, Erato et Polymnie. —
# Numéro@ 599
# Auteur@
# Vie@
# Titre@ Melpomène, Erato et Polymnie.
# Position@ XIV-N
#
#
# Raw@ 600 — Uranie. —
# Numéro@ 600
# Auteur@
# Vie@
# Titre@ Uranie.
# Position@ XIV-N
#
#
# Raw@ 601 — Terpsichore. —
# Numéro@ 601
# Auteur@
# Vie@
# Titre@ Terpsichore.
# Position@ XIV-N
#
#
# Raw@ 602 — Call iope —
# Numéro@ 602
# Auteur@
# Vie@
# Titre@ Call iope
# Position@ XIV-N
#
#
# Raw@ 603 — Ganymède enlevé par Jupiter..,. XIII
# Numéro@ 603
# Auteur@
# Vie@
# Titre@ Ganymède enlevé par Jupiter
# Position@ XIII
#
#
# Raw@ 605 — Le Christ à la colonne. (Attribué). XIV-S
# Numéro@ 605
# Auteur@
# Vie@
# Titre@ Le Christ à la colonne. (Attribué).
# Position@ XIV-S
#
#
# Raw@ * — L'homme formé par Prométhée et animé par Minerve. Restauration de la peinture de Berthélemy. Plafond. Rotonde de Mars
# Numéro@ *
# Auteur@ Mauzaisse, Jean-Baptiste.
# Vie@  (1784-1844).
# Titre@ L'homme formé par Prométhée et animé par Minerve. Restauration de la peinture de Berthélemy. Plafond. Rotonde de Mar
# Position@
#
#
# Raw@ 1741 Le liseur noir. — IV
# Numéro@ 1741
# Auteur@
# Vie@
# Titre@ Le liseur noir.
# Position@ Coll. Chauchard IV
#
#
# Raw@ (75) — Au cabaret. Reître et son lévrier. — II
# Numéro@ (75)
# Auteur@
# Vie@
# Titre@ Au cabaret. Reître et son lévrier.
# Position@ Coll. Chauchard II
#
#
# Raw@ 76) — Le dessinateur. , — II
# Numéro@ 76)
# Auteur@
# Vie@
# Titre@ Le dessinateur. ,
# Position@ Coll. Chauchard II
#
#
# Raw@ 177 j — Le liseur blanc. , — IV ( QO ) MEISSONIER "7) MEISSOSII-K
# Numéro@ 177 j
# Auteur@
# Vie@
# Titre@ Le liseur blanc. ,
# Position@ — IV ( QO ) MEISSONIER "7) MEISSOSII-K
#
#
# Raw@ 644 — Les glaneuses. VIII-0 (10s) MILLET (100) MII.LET (qq) MILLET (102) MILLET
# Numéro@ 644
# Auteur@ Millet, Jean-François.
# Vie@  (1814-187:;).
# Titre@ Les glaneuses. VIII-0 (10s) MILLET (100) MII.LET (qq) MILLET (102) MILLE
# Position@
#
#
# Raw@ 651 a Paysage. (Attribué) XVI-E — L'hortensia S. des dessins XIXe
# Numéro@ 651 a
# Auteur@
# Vie@
# Titre@ Paysage. (Attribué) XVI-E — L'hortensia
# Position@ S. des dessins XIXe
#
#
# Raw@ S. N° Morisot, Berthe. (1841-1895). — Portrait de Mme Pontillon. Pastel XV-panneau
# Numéro@ S. N°
# Auteur@ Morisot, Berthe.
# Vie@  (1841-1895).
# Titre@ Portrait de Mme Pontillon. Pastel XV-pannea
# Position@
#
#
# Raw@ * Peyron, Jean-François-Pierre. (1744-18141.-L'Etude et la Renommée. Tympan., Salle des Antonins
# Numéro@ *
# Auteur@ Peyron, Jean-François-Pierre.
# Vie@  (1744-18141.-L'Etude
# Titre@ et la Renommée. Tympan Salle des Antonin
# Position@
#
#
# Raw@ 603 PATER 6qb PERRONNEAU
# Numéro@ 603
# Auteur@
# Vie@
# Titre@ PATER 6qb PERRONNEA
# Position@
#
#
# Raw@ 701 Pierre, Jean-Baptiste-Marie. 17";-( ,8o'!. — Aglaure métamorphosée en pierre XVI-N
# Numéro@ 701
# Auteur@
# Vie@
# Titre@ Pierre, Jean-Baptiste-Marie. 17";-( ,8o'!.
# Position@ — Aglaure métamorphosée en pierre XVI-N
#
#
# Raw@ 701 a — Junon empruntant la ceinture de Vénus. IIIe S. Meubles XVIIIe
# Numéro@ 701 a
# Auteur@
# Vie@
# Titre@ Junon empruntant la ceinture de Vénus.
# Position@ IIIe S. Meubles XVIIIe
#
#
# Raw@ S. X" — Les funérailles de Phocion; paysage XIV-N 75') PRUD'HON 751 PRUD'HON
# Numéro@ S. X"
# Auteur@ Poussin, Nicolas.
# Vie@  11594-1665).
# Titre@ Les funérailles de Phocion; paysage XIV-N 75') PRUD'HON 751 PRUD'HO
# Position@
#
#
# Raw@ 760 Puget, François. (?-1707)- — Portrait de Pierre Pu- get, sculpteur.:.-.------ XIV-N
# Numéro@ 760
# Auteur@
# Vie@
# Titre@ Puget, François. (?-1707)-
# Position@ — Portrait de Pierre Pu- get, sculpteur.:.-.--- XIV-N
#
#
# Raw@ 770 Regnault, Alexandre-Georges-Henri. (1843-1 87,).- Portrait équestre du général Prim VIII-N
# Numéro@ 770
# Auteur@
# Vie@
# Titre@ Regnault, Alexandre-Georges-Henri. (1843-1 87,).- Portrait équestre du général Prim
# Position@ VIII-N
#
#
# Raw@ 771 — Exécution sans jugement sous les rois Maures de Grenade. Marine 1
# Numéro@ 771
# Auteur@
# Vie@
# Titre@ Exécution sans jugement sous les rois Maures de Grenade.
# Position@ Marine 1
#
#
# Raw@ 772 — Portrait de la comtesse de Barck.. E. F. XIXe S. 1er étage II
# Numéro@ 772
# Auteur@
# Vie@
# Titre@ Portrait de la comtesse de Barck
# Position@ E. F. XIXe S. 1er étage II
#
#
# Raw@ S. N° — Portrait de Mme A. Fouques Duparc. Marine 1
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Portrait de Mme A. Fouques Duparc.
# Position@ Marine 1
#
#
# Raw@ 2903 ,-; Le printemps. , T. T.
# Numéro@ 2903
# Auteur@
# Vie@
# Titre@ -; Le printemps. ,
# Position@ T. T.
#
#
# Raw@ 2904 - Le petit pêcheur T. T.
# Numéro@ 2904
# Auteur@
# Vie@
# Titre@ Le petit pêcheur
# Position@ T. T.
#
#
# Raw@ 2905 - L'étang. T. T.
# Numéro@ 2905
# Auteur@
# Vie@
# Titre@ L'étang.
# Position@ T. T.
#
#
# Raw@ 107) —^ Avenue de la forêt de l'Isle-Adam. Coll. Chauchard, galerie
# Numéro@ 107)
# Auteur@
# Vie@
# Titre@ —^ Avenue de la forêt de l'Isle-Adam.
# Position@ Coll. Chauchard, galerie
#
#
# Raw@ (108) - La mare près de la route. Ferme dans le Berry — II
# Numéro@ (108)
# Auteur@
# Vie@
# Titre@ La mare près de la route. Ferme dans le Berry
# Position@ Coll. Chauchard, II
#
#
# Raw@ 109 - La mare au pied du coteau. — II
# Numéro@ 109
# Auteur@
# Vie@
# Titre@ La mare au pied du coteau.
# Position@ Coll. Chauchard, II
#
#
# Raw@ (110 - La passereMe. — IV
# Numéro@ (110
# Auteur@
# Vie@
# Titre@ La passereMe.
# Position@ Coll. Chauchard, IV
#
#
# Raw@ (111 La mare au chêne. , — IV
# Numéro@ (111
# Auteur@
# Vie@
# Titre@ La mare au chêne. ,
# Position@ Coll. Chauchard, IV
#
#
# Raw@ (112 — La route dans la forêt de Fontainebleau, effet d'orage. - galerie
# Numéro@ (112
# Auteur@
# Vie@
# Titre@ La route dans la forêt de Fontainebleau, effet d'orage.
# Position@ Coll. Chauchard, galerie
#
#
# Raw@ * Plafond: Charlemagne reçoit Alcuin. — Vous- sures: Médaillons, Pierre de Pise, Roland, Saint Benoît d Aniane et Angilbert, Génies des sciences, musique, arts, guerre, légis- lation. , Céramique Antique Salle VII
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Plafond: Charlemagne reçoit Alcuin. — Vous- sures: Médaillons, Pierre de Pise, Roland, Saint Benoît d Aniane et Angilbert, Génies des sciences, musique, arts, guerre, légis- lation. ,
# Position@ Céramique Antique Salle VII
#
#
# Raw@ 870 -- Portrait présumé de Dumarsais 1-0
# Numéro@ 870
# Auteur@
# Vie@
# Titre@ Portrait présumé de Dumarsais
# Position@ 1-0
#
#
# Raw@ 871 — Portrait du peintre Louis Galloche XVI-S
# Numéro@ 871
# Auteur@
# Vie@
# Titre@ Portrait du peintre Louis Galloche
# Position@ XVI-S
#
#
# Raw@ 884 —. La toilette d'Esther XVI-N
# Numéro@ 884
# Auteur@
# Vie@
# Titre@ —. La toilette d'Esther
# Position@ XVI-N
#
#
# Raw@ 885 — L'évanouissement d'Esther XVI-S
# Numéro@ 885
# Auteur@
# Vie@
# Titre@ L'évanouissement d'Esther
# Position@ XVI-S
#
#
# Raw@ 886 — Tête de femme I-S
# Numéro@ 886
# Auteur@
# Vie@
# Titre@ Tête de femme
# Position@ I-S
#
#
# Raw@ 887 - Portrait d'homme.,. I-E
# Numéro@ 887
# Auteur@
# Vie@
# Titre@ Portrait d'homme
# Position@ I-E
#
#
# Raw@ 888 - Portrait probable de François Bouquet, échevin de la ville de Paris 1-0 88q TKOYON 800 TROYON
# Numéro@ 888
# Auteur@
# Vie@
# Titre@ Portrait probable de François Bouquet, échevin de la ville de Paris 1-0 88q TKOYON 800 TROYO
# Position@
#
#
# Raw@ (117 ) — Le taureau .,. - galerie
# Numéro@ (117
# Auteur@
# Vie@
# Titre@ ) — Le taureau
# Position@ Coll. Chauchard galerie
#
#
# Raw@ 129) — Le pâturage, ciel nuageux galerie
# Numéro@ 129)
# Auteur@ Troyon, Constant.
# Vie@  (1810-1865).
# Titre@ Le pâturage, ciel nuageux galeri
# Position@
#
#
# Raw@ (122) TROYON ciio H. VERNET
# Numéro@ (122)
# Auteur@
# Vie@
# Titre@ TROYON ciio H. VERNE
# Position@
#
#
# Raw@ 938 Vernet, Claude-Joseph. 171 (-178g — Paysage et marine sur les bords de la Méditerranée Marine SUITE DES Ports DE MER DE FRANCE, commandée par Louis xv EN 175' ET EXECUTEE DE I7 54 A 1765.
# Numéro@ 938
# Auteur@
# Vie@
# Titre@ Vernet, Claude-Joseph. 171 (-178g — Paysage et marine sur les bords de la Méditerranée
# Position@ Marine SUITE DES Ports DE MER DE FRANCE, commandée par Louis xv EN 175' ET EXECUTEE DE I7 54 A 1765.
#
#
# Raw@ 940 — Vue de l'entrée du port de Marseille, prise de la montagne appelée Tête-de-More XVI-N
# Numéro@ 940
# Auteur@
# Vie@
# Titre@ Vue de l'entrée du port de Marseille, prise de la montagne appelée Tête-de-More
# Position@ XVI-N
#
#
# Raw@ 941 — Vue de l'intérieur du port de Marseille, prise du pavillon de l'horloge du parc Marine
# Numéro@ 941
# Auteur@
# Vie@
# Titre@ Vue de l'intérieur du port de Marseille, prise du pavillon de l'horloge du parc
# Position@ Marine
#
#
# Raw@ 942 — Vue du golfe de Bandol -
# Numéro@ 942
# Auteur@
# Vie@
# Titre@ Vue du golfe de Bandol
# Position@ Marine
#
#
# Raw@ 943 — Vue du port-neuf de Toulon, prise de l'angle du parc d'artillerie —
# Numéro@ 943
# Auteur@
# Vie@
# Titre@ Vue du port-neuf de Toulon, prise de l'angle du parc d'artillerie
# Position@ Marine
#
#
# Raw@ 944 - Vue de la ville et de la rade de Toulon XVI-N
# Numéro@ 944
# Auteur@
# Vie@
# Titre@ Vue de la ville et de la rade de Toulon
# Position@ XVI-N
#
#
# Raw@ 945 — Vue du vieux port de Toulon,prise du côté des magasins aux vivres. Marine
# Numéro@ 945
# Auteur@
# Vie@
# Titre@ Vue du vieux port de Toulon,prise du côté des magasins aux vivres.
# Position@ Marine
#
#
# Raw@ 946 — Vue de la rade d'Antibes, prise du côté de la terre —
# Numéro@ 946
# Auteur@
# Vie@
# Titre@ Vue de la rade d'Antibes, prise du côté de la terre
# Position@ Marine
#
#
# Raw@ 947 — Vue du port de Cette, prise du côté de la mer, derrière la jetée isolée
# Numéro@ 947
# Auteur@
# Vie@
# Titre@ Vue du port de Cette, prise du côté de la mer, derrière la jetée isolé
# Position@
#
#
# Raw@ 948 — Vue de la ville et du port de Bordeaux, prise du côté des Salinières.,. 949 — La même vue, prise du château Trompette —
# Numéro@ 948
# Auteur@
# Vie@
# Titre@ Vue de la ville et du port de Bordeaux, prise du côté des Salinières 949 — La même vue, prise du château Trompette
# Position@
#
#
# Raw@ 950 — Vue de la ville et du port de Bayonne, prise du glacis de la citadelle.
# Numéro@ 950
# Auteur@
# Vie@
# Titre@ Vue de la ville et du port de Bayonne, prise du glacis de la citadelle
# Position@
#
#
# Raw@ 951 — La même vue, prise près de la porte de Mous- serole —
# Numéro@ 951
# Auteur@
# Vie@
# Titre@ La même vue, prise près de la porte de Mous- serole
# Position@
#
#
# Raw@ 952 — Vue du port de La Rochelle, prise de la petite rive. —
# Numéro@ 952
# Auteur@
# Vie@
# Titre@ Vue du port de La Rochelle, prise de la petite rive.
# Position@
#
#
# Raw@ 953 — Vue du port de Rochefort, prise du magasin des colonies 954 — Vue de la ville et du port de Dieppe —
# Numéro@ 953
# Auteur@
# Vie@
# Titre@ Vue du port de Rochefort, prise du magasin des colonies 954 — Vue de la ville et du port de Dieppe
# Position@
#
#
# Raw@ 955 Vernet, Antoine-Charles-Horace, dit Carie. 11758- 1836]. - Chasse au cerf pour la Saint Hu- bert, le 5 novembre 1818, dans les bois de Fosse Repose. Le cerf forcé dans l'étang de Ville d'Avray Palier esc. T. T.
# Numéro@ 955
# Auteur@
# Vie@
# Titre@ Vernet, Antoine-Charles-Horace, dit Carie. 11758- 1836]. - Chasse au cerf pour la Saint Hu- bert, le 5 novembre 1818, dans les bois de Fosse Repose. Le cerf forcé dans l'étang de Ville d'Avray
# Position@ Palier esc. T. T.
#
#
# Raw@ 965 — L'ermite endormi. XVI-E Vigée Le Brun, Mme Elisabeth Louise. Voir Le Brun
# Numéro@ 965
# Auteur@ Vien, Joseph-Marie, comte.
# Vie@  (1716-1809).
# Titre@ L'ermite endormi. XVI-E Vigée Le Brun, Mme Elisabeth Louise. Voir Le Bru
# Position@
#
#
# Raw@ 975 ? * — Le Christ au tombeau XIV-0
# Numéro@ 975
# Auteur@
# Vie@
# Titre@ ? *
# Position@ — Le Christ au tombeau XIV-0
#
#
# Raw@ 976 — Portrait de Louis XIII S. Meubles XVIIe
# Numéro@ 976
# Auteur@
# Vie@
# Titre@ Portrait de Louis XIII
# Position@ S. Meubles XVIIe
#
#
# Raw@ 993 — Gibier mort. (Attribué) I. E.
# Numéro@ 993
# Auteur@ Watteau, Jean-Antoine.
# Vie@  (1684-172 r).
# Titre@ Gibier mort. (Attribué) I. E
# Position@
#
#
# Raw@ 1001 b Ec. D'AVIGNON XVe s. 996 Ec. FRANÇ. xve s.
# Numéro@ 1001 b
# Auteur@
# Vie@
# Titre@ Ec. D'AVIGNON XVe s. 996 Ec. FRANÇ. xve s
# Position@
#
#
# Raw@ 1001 d — L'invention de la Sainte Croix. Ste. Hélène age- nouillée avec sa suite, assiste à la résurrection d'une morte (école de Valenciennes, vers
# Numéro@ 1001 d
# Auteur@ <anonyme>
# Vie@
# Titre@ L'invention de la Sainte Croix. Ste. Hélène age- nouillée avec sa suite, assiste à la résurrection d'une morte (école de Valenciennes, ver
# Position@
#
#
# Raw@ S. N° -- Guerre de Troie. Mission d'Anthénor en Grèce. Le jugement de Paris. Dessin aquarcllé. XI. pupitre milieu
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Guerre de Troie. Mission d'Anthénor en Grèce. Le jugement de Paris. Dessin aquarcllé. XI. pupitre milie
# Position@
#
#
# Raw@ S. N" — Guerre de Troie. Quatrième bataille. Le roi Thoas est fait prisonnier. Dans la chambre de la beauté. Dessin aquarellé , ..,
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Guerre de Troie. Quatrième bataille. Le roi Thoas est fait prisonnier. Dans la chambre de la beauté. Dessin aquarellé
# Position@
#
#
# Raw@ S. N° — Guerre de Troie. Dix-huitième bataille. Mort d'Achille. Vingtième bataille. Dessin aquarellé. —
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Guerre de Troie. Dix-huitième bataille. Mort d'Achille. Vingtième bataille. Dessin aquarellé.
# Position@
#
#
# Raw@ S. Nu — Guerre de Troie. Arrivée de Penthésilée, reine des Amazones. Les Amazones au combat. Pyrrhus reçoit les armes d'Achille. Pyrrhus au combat. Dessin aquarellé —
# Numéro@ S. Nu
# Auteur@
# Vie@
# Titre@ Guerre de Troie. Arrivée de Penthésilée, reine des Amazones. Les Amazones au combat. Pyrrhus reçoit les armes d'Achille. Pyrrhus au combat. Dessin aquarellé
# Position@
#
#
# Raw@ S. Nu — Guerre de Troie. Mort de Penthésilée. Tra- hison d'Anthénor. Dessin aquarellé —
# Numéro@ S. Nu
# Auteur@
# Vie@
# Titre@ Guerre de Troie. Mort de Penthésilée. Tra- hison d'Anthénor. Dessin aquarellé
# Position@
# Raw@ S. N" — Guerre de Troie. La prise de la ville. Dessin aquarellé.,. —
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Guerre de Troie. La prise de la ville. Dessin aquarellé
# Position@
#
#
# Raw@ 1010 -- Portrait de Jean d'Albon, seigneur de Saint- André, âgé, en manteau brun à revers de fourrure blanche. , , , : , XI
# Numéro@ 1010
# Auteur@
# Vie@
# Titre@ Portrait de Jean d'Albon, seigneur de Saint- André, âgé, en manteau brun à revers de fourrure blanche. , , , : ,
# Position@ XI
#
#
# Raw@ 1011 - Portrait de Jean de Bourbon-Vendôme, comte d'Enghien, jeune, avec barbe blonde naissante. XI
# Numéro@ 1011
# Auteur@
# Vie@
# Titre@ Portrait de Jean de Bourbon-Vendôme, comte d'Enghien, jeune, avec barbe blonde naissante.
# Position@ XI
#
#
# Raw@ 1011 a — Portrait présumé de Louise de Rieux, Marquise d'Elbeuf. XI
# Numéro@ 1011 a
# Auteur@
# Vie@
# Titre@ Portrait présumé de Louise de Rieux, Marquise d'Elbeuf.
# Position@ XI
#
#
# Raw@ 1011 b — Portrait supposé de Henri de Bourbon, duc de Montpensier, en blanc. XI
# Numéro@ 1011 b
# Auteur@
# Vie@
# Titre@ Portrait supposé de Henri de Bourbon, duc de Montpensier, en blanc.
# Position@ XI
#
#
# Raw@ * XVIIlIle siècle. — Portrait d'Anne d'Autriche, assise dans un paysage. Ire S. de la Colonnade
# Numéro@ *
# Auteur@
# Vie@
# Titre@ XVIIlIle siècle. — Portrait d'Anne d'Autriche, assise dans un paysage.
# Position@ Ire S. de la Colonnade
#
#
# Raw@ * — Plafond aux armes d'Anne d'Autriche, prove- nant du château de Vincennes. Plafond —
# Numéro@ *
# Auteur@
# Vie@
# Titre@ Plafond aux armes d'Anne d'Autriche, prove- nant du château de Vincennes. Plafond
# Position@ Ire S. de la Colonnade
#
#
# Raw@ 1040 XVIIIIII, siècle. — Portrait de femme, les bras croisés sur une balustrade, terant un livre. XVI-N
# Numéro@ 1040
# Auteur@
# Vie@
# Titre@ XVIIIIII, siècle.
# Position@ — Portrait de femme, les bras croisés sur une balustrade, terant un livre. XVI-N
#
#
# Raw@ S. N" — Portrait de femme debout, le bras gauche sur une table. XVI-E
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait de femme debout, le bras gauche sur une table.
# Position@ XVI-E
#
#
# Raw@ S. N" — Portrait de Perronet, à l'âge de 40 ans. Pastel. Ille S. Meubles XVIIIe
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait de Perronet, à l'âge de 40 ans. Pastel. Ille
# Position@ S. Meubles XVIIIe
#
#
# Raw@ S. N" — Portrait présumé de Madame Louise, fille de Louis XV, abbesse des Carmélites de St. Denis. Pastel. S. des Pastels
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait présumé de Madame Louise, fille de Louis XV, abbesse des Carmélites de St. Denis. Pastel.
# Position@ S. des Pastels
#
#
# Raw@ ÉCOLES D'ITALIE La grande galerie salle VI, où sont exposés bon nombre de tableaux des écoles d'Italie, des Pays-Bas et d'Espagne, est divisée en six travées désignées par les lettres A à F. Nous avons exprimé ces divisions par l'abréviation : VI tr. A (ou B, ou C, etc.), suivie, comme pour les autres salles importantes, de l'indication des panneaux N (Nord), S (Sud), etc.
# Numéro@
# Auteur@
# Vie@
# Titre@ ÉCOLES D'ITALIE La grande galerie salle VI, où sont exposés bon nombre de tableaux des écoles d'Italie, des Pays-Bas et d'Espagne, est divisée en six travées désignées par les lettres A à F. Nous avons exprimé ces divisions par l'abréviation : VI tr. A (ou B, ou C, etc.), suivie, comme pour les autres salles importantes, de l'indication des panneaux N (Nord),
# Position@ S (Sud), etc.
#
#
# Raw@ 1120 Alunno, Niccolo da Foligno, voir Niccolo da Libera- tore, dit Alunno da Foligno.
# Numéro@ 1120
# Auteur@
# Vie@
# Titre@ Alunno, Niccolo da Foligno, voir Niccolo da Libera- tore, dit Alunno da Foligno
# Position@
#
#
# Raw@ S. Nu Barbarj, Jacopo de', dit le Maître au Caducée (vers
# Numéro@ S. Nu
# Auteur@
# Vie@
# Titre@ Barbarj, Jacopo de', dit le Maître au Caducée (ver
# Position@
#
#
# Raw@ 1450 - avant 1516). — La Vierge à la fon- taine VI tr. A-S
# Numéro@ 1450
# Auteur@
# Vie@
# Titre@ avant 1516).
# Position@ — La Vierge à la fon- taine VI tr. A-S
#
#
# Raw@ 1416 b — Triomphe de Vénus. VII-E Bassan, Jacques; voir Ponte, Jacopo da.
# Numéro@ 1416 b
# Auteur@ Bartolommeo di Giovanni, dit Alunno di Domenico.
# Vie@  (travaillait de i j80 à 1500).
# Titre@ Triomphe de Vénus. VII-E Bassan, Jacques; voir Ponte, Jacopo da
# Position@
#
#
# Raw@ 11 ~yb GIORGIONE S N° GIOVANNI BELLINI
# Numéro@ 11
# Auteur@
# Vie@
# Titre@ ~yb GIORGIONE
# Position@ S N° GIOVANNI BELLINI
#
#
# Raw@ 1181 Borgognone, Ambrogio da Fossano, dit Il (entre
# Numéro@ 1181
# Auteur@
# Vie@
# Titre@ Borgognone, Ambrogio da Fossano, dit Il (entr
# Position@
#
#
# Raw@ 1240 Carrucci, Jacopo, dit Jacopo da Puntormo (1494- 1557)- — Sainte Famille. VI tr. B-N
# Numéro@ 1240
# Auteur@
# Vie@
# Titre@ Carrucci, Jacopo, dit Jacopo da Puntormo (1494- 1557)-
# Position@ — Sainte Famille. VI tr. B-N
#
#
# Raw@ 1241 - Portrait d'un graveur en pierres fines VI tr. B-N
# Numéro@ 1241
# Auteur@
# Vie@
# Titre@ Portrait d'un graveur en pierres fines
# Position@ VI tr. B-N
#
#
# Raw@ 1242 — La Visitation de la Vierge (D'après) VI tr. B-N
# Numéro@ 1242
# Auteur@
# Vie@
# Titre@ La Visitation de la Vierge (D'après)
# Position@ VI tr. B-N
#
#
# Raw@ 1259 CIMA 12b! COSTA
# Numéro@ 1259
# Auteur@
# Vie@
# Titre@ CIMA 12b! COST
# Position@
#
#
# Raw@ 1252 a Catena, Vincenzo di Biagio, dit (travaillait déjà en
# Numéro@ 1252 a
# Auteur@
# Vie@
# Titre@ Catena, Vincenzo di Biagio, dit (travaillait déjà e
# Position@
#
#
# Raw@ * 1517 ou 1518). - La Vierge et l'Enfant Jésus entre la Madeleine et St. Jean-Baptiste VI tr. A-S
# Numéro@ *
# Auteur@
# Vie@
# Titre@ 1517 ou 1518).
# Position@ - La Vierge et l'Enfant Jésus entre la Madeleine et St. Jean-Baptiste VI tr. A-S
#
#
# Raw@ S. N° — La Vierge et l'Enfant Coll. Schlichting
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ La Vierge et l'Enfant
# Position@ Coll. Schlichting
#
#
# Raw@ 1260 Cimabue, Giovanni-Gualtieri (i240?-i302 ? ). — La Vierge aux anges. VII-0 Corrège; voir Allegri. Cortone, Pierre de, voir Berrettini.
# Numéro@ 1260
# Auteur@ Cimabue, Giovanni-Gualtieri
# Vie@  (i240?-i302 ? ).
# Titre@ La Vierge aux anges. VII-0 Corrège; voir Allegri. Cortone, Pierre de, voir Berrettini
# Position@
#
#
# Raw@ 1266 Crespi, Giuseppe-Maria, dit Lo Spagnuolo (1665- Inil. - Une école VI tr. D-N
# Numéro@ 1266
# Auteur@
# Vie@
# Titre@ Crespi, Giuseppe-Maria, dit Lo Spagnuolo (1665- Inil.
# Position@ - Une école VI tr. D-N
#
#
# Raw@ 1295 BOTTICELLI 12q6 BOTTICELLI
# Numéro@ 1295
# Auteur@
# Vie@
# Titre@ BOTTICELLI 12q6 BOTTICELL
# Position@ I
#
#
# Raw@ 1276 Dosso Dossi, Giovanni di Niccolo Lutero, dit (vers I479"r542)- — Saint Jérôme VI tr. A-N
# Numéro@ 1276
# Auteur@
# Vie@
# Titre@ Dosso Dossi, Giovanni di Niccolo Lutero, dit (vers I479"r542)-
# Position@ — Saint Jérôme VI tr. A-N
#
#
# Raw@ 1290 Fiesole, Fra Giovanni da, dit Beato Angelico ( 1^87- 14S5)- — Le couronnement de la Vierge VII-S
# Numéro@ 1290
# Auteur@
# Vie@
# Titre@ Fiesole, Fra Giovanni da, dit Beato Angelico ( 1^87- 14S5)-
# Position@ — Le couronnement de la Vierge VII-S
#
#
# Raw@ 1291 — La décollation de saint Jean-Baptiste (Ecole de). VII-S
# Numéro@ 1291
# Auteur@
# Vie@
# Titre@ La décollation de saint Jean-Baptiste (Ecole de).
# Position@ VII-S
#
#
# Raw@ 1293 — Martyre de saint Côme et de saint Damien VII-S
# Numéro@ 1293
# Auteur@
# Vie@
# Titre@ Martyre de saint Côme et de saint Damien
# Position@ VII-S
#
#
# Raw@ 1294 — La Crucifixion. Fresque. Esc. Daru
# Numéro@ 1294
# Auteur@
# Vie@
# Titre@ La Crucifixion. Fresque.
# Position@ Esc. Daru
#
#
# Raw@ 1294 a — La Résurrection., VII-0
# Numéro@ 1294 a
# Auteur@
# Vie@
# Titre@ La Résurrection
# Position@ VII-0
#
#
# Raw@ 1294 b — Ange en adoration. VII-S
# Numéro@ 1294 b
# Auteur@
# Vie@
# Titre@ Ange en adoration.
# Position@ VII-S
#
#
# Raw@ 1294 c — La Résurrection du Christ et scènes de la légende de saint Jérôme. VII-E 12Q7 BOTTICELLI 1298 BOTTICELLI
# Numéro@ 1294 c
# Auteur@
# Vie@
# Titre@ La Résurrection du Christ et scènes de la légende de saint Jérôme. VII-E 12Q7 BOTTICELLI 1298 BOTTICELL
# Position@ I
#
#
# Raw@ 1644 Franciabigio 1522 GRILLANDAJO
# Numéro@ 1644
# Auteur@
# Vie@
# Titre@ Franciabigio 1522 GRILLANDAJ
# Position@
#
#
# Raw@ 1319 Gozzoli, Benozzo di Lese di Sandro (1420 ou 1424-
# Numéro@ 1319
# Auteur@
# Vie@
# Titre@ Gozzoli, Benozzo di Lese di Sandro (1420 ou 1424
# Position@
#
#
# Raw@ 1317 Lorenzetti, Pietro, dit le Maître de la Ste. Humi- lité (travaillait entre r,ui et n,j8). - Niis- sance de St. Jean-Baptiste (Ecole de) VII-0
# Numéro@ 1317
# Auteur@
# Vie@
# Titre@ Lorenzetti, Pietro, dit le Maître de la Ste. Humi- lité (travaillait entre r,ui et n,j8).
# Position@ - Niis- sance de St. Jean-Baptiste (Ecole de) VII-0
#
#
# Raw@ 1374 MANTEGNA s. u MANTEGNA I)83 BIMONE MARTINI 1413 PELLEGRINi
# Numéro@ 1374
# Auteur@
# Vie@
# Titre@ MANTEGNA s. u MANTEGNA I)83 BIMONE MARTINI 1413 PELLEGRIN
# Position@
#
#
# Raw@ 1411 — Ruines antiques; la pyramide de Cestius. I-S
# Numéro@ 1411
# Auteur@
# Vie@
# Titre@ Ruines antiques; la pyramide de Cestius.
# Position@ I-S
#
#
# Raw@ 1412 — Ruines. 1-0
# Numéro@ 1412
# Auteur@
# Vie@
# Titre@ Ruines.
# Position@ 1-0
#
#
# Raw@ 1417 Pinturicchio, Bernardino di Betto di Biagio, dit Il (vers 1455-ISl 3). - La Vierge et l'Enfant avec St. Jean-Baptiste et St. Grégoire. (École de). VII-E Piombo, Sébastien del; voir Luciani.
# Numéro@ 1417
# Auteur@ Pinturicchio, Bernardino di Betto di Biagio, dit Il
# Vie@  (vers 1455-ISl 3).
# Titre@ La Vierge et l'Enfant avec St. Jean-Baptiste et St. Grégoire. (École de). VII-E Piombo, Sébastien del; voir Luciani
# Position@
#
#
# Raw@ (5) Preda, Giovanni Ambrogio, dit Ambrogio de Prédis. (vers 1450, 1460- après 15061. —Portrait de Bianca-Maria Sforza, seconde femme de Maxi- milien I" Coll. Arconati Visconti
# Numéro@ (5)
# Auteur@
# Vie@
# Titre@ Preda, Giovanni Ambrogio, dit Ambrogio de Prédis. (vers 1450, 1460- après 15061. —Portrait de Bianca-Maria Sforza, seconde femme de Maxi- milien I"
# Position@ Coll. Arconati Visconti
#
#
# Raw@ PARIS, MUSÉE NATIONAL DU LOUVRE 105 Puntormo ou Pontormo; voir Carrucci. Raffaellino del Garbo; voirGarbo. 1435 Raibolini, Francesco, dit Il Francia. IIISo- 1 S 1 t':. — La Nativité VI tr. A-N
# Numéro@
# Auteur@
# Vie@
# Titre@ PARIS, MUSÉE NATIONAL DU LOUVRE 105 Puntormo ou Pontormo; voir Carrucci. Raffaellino del Garbo; voirGarbo. 1435 Raibolini, Francesco, dit Il Francia. IIISo- 1
# Position@ S 1 t':. — La Nativité VI tr. A-N
#
#
# Raw@ 1436 — Le Christ en croix. VI tr. A-N
# Numéro@ 1436
# Auteur@
# Vie@
# Titre@ Le Christ en croix.
# Position@ VI tr. A-N
#
#
# Raw@ 1437 a — La Vierge et l'Enfant avec St. Joseph et un saint. École de) VII-0
# Numéro@ 1437 a
# Auteur@
# Vie@
# Titre@ La Vierge et l'Enfant avec St. Joseph et un saint. École de)
# Position@ VII-0
#
#
# Raw@ S. N° — La Vierge et l'Enfant (École de). Coll. Schlichting
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ La Vierge et l'Enfant (École de).
# Position@ Coll. Schlichting
#
#
# Raw@ 1462 Ricciarelli, Daniele, dit Daniel de Volterre. (1509- 1566). — David vainqueur de Goliath. VI entre tr. A et B
# Numéro@ 1462
# Auteur@ Ricciarelli, Daniele, dit Daniel de Volterre.
# Vie@  (1509- 1566).
# Titre@ David vainqueur de Goliath. VI entre tr. A et
# Position@
#
#
# Raw@ S. N° Rizzi, Gian Pietro, ou Pedrini, dit Giampietrino. (Ire moitié du XVlme siècle). — Cléopâtre VI tr. B-S
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Rizzi, Gian Pietro, ou Pedrini, dit Giampietrino. (Ire moitié du XVlme siècle).
# Position@ — Cléopâtre VI tr. B-S
#
#
# Raw@ 1677 a et 1677 b — SIe, Apolline et St. Michel (dans le même cadre) VI tr. A-N
# Numéro@ 1677 a
# Auteur@
# Vie@
# Titre@ et 1677 b
# Position@ — SIe, Apolline et St. Michel (dans le même cadre) VI tr. A-N
#
#
# Raw@ 1488 Sacchi, Pier-Francesco. (Iere moitié du XVllllc siècle). — Les quatre docteurs de l'Eglise: St. Au- gustin, St. Grégoire, St. Jérôme et St. Ambroise. VI tr. A-S
# Numéro@ 1488
# Auteur@
# Vie@
# Titre@ Sacchi, Pier-Francesco. (Iere moitié du XVllllc siècle).
# Position@ — Les quatre docteurs de l'Eglise: St. Au- gustin, St. Grégoire, St. Jérôme et St. Ambroise. VI tr. A-S
#
#
# Raw@ 1514 A. DEL SARTO 1515 A. DEL SARTO Sébastien del Piombo; voir Luciani.
# Numéro@ 1514
# Auteur@
# Vie@
# Titre@ A. DEL SARTO 1515 A. DEL SARTO Sébastien del Piombo; voir Luciani
# Position@
#
#
# Raw@ 1 566 a LE PÉRUGIN 1 =i81 LK TITIEN
# Numéro@ 1
# Auteur@
# Vie@
# Titre@ 566 a LE PÉRUGIN 1 =i81 LK TITIE
# Position@
#
#
# Raw@ 1601 —» La Joconde VI tr. C-S
# Numéro@ 1601
# Auteur@
# Vie@
# Titre@ —» La Joconde
# Position@ VI tr. C-S
#
#
# Raw@ 1602 — Bacchus. (Attribution discutée). VI tr. B-S
# Numéro@ 1602
# Auteur@
# Vie@
# Titre@ Bacchus. (Attribution discutée).
# Position@ VI tr. B-S
#
#
# Raw@ 1600 LÉONARD DE VINCI IÔOI LÉONARD DE VINCI Volterre, Daniel de; voir Ricciarelli. Wassenhove; voir Justus de Gand.
# Numéro@ 1600
# Auteur@
# Vie@
# Titre@ LÉONARD DE VINCI IÔOI LÉONARD DE VINCI Volterre, Daniel de; voir Ricciarelli. Wassenhove; voir Justus de Gand
# Position@
#
#
# Raw@ 1603 D'APRÈS LÉONARD DE VINCI 1345 Ec. FLORENTINE XV. S.'
# Numéro@ 1603
# Auteur@
# Vie@
# Titre@ D'APRÈS LÉONARD DE VINCI 1345 Ec. FLORENTINE XV. S.
# Position@
#
#
# Raw@ 1657 Ecole florentine du XV me siècle. (Maître dit du retable de San Miniato). - La Vierge et l'En- fant avec le petit St. Jean et des anges VII-E
# Numéro@ 1657
# Auteur@
# Vie@
# Titre@ Ecole florentine du XV me siècle. (Maître dit du retable de San Miniato).
# Position@ - La Vierge et l'En- fant avec le petit St. Jean et des anges VII-E
#
#
# Raw@ 1657 c - L'adoration des Mages. VII-S
# Numéro@ 1657 c
# Auteur@
# Vie@
# Titre@ L'adoration des Mages.
# Position@ VII-S
#
#
# Raw@ 6 — L'Annonciation. Coll. Arconati Visconti
# Numéro@ 6
# Auteur@
# Vie@
# Titre@ L'Annonciation.
# Position@ Coll. Arconati Visconti
#
#
# Raw@ 7) — La Vierge adorant l'Enfant. -
# Numéro@ 7)
# Auteur@
# Vie@
# Titre@ La Vierge adorant l'Enfant.
# Position@ Coll. Arconati Visconti
#
#
# Raw@ 1661 J - (Maître dit de la Nativité de Castello). — La Vierge et l'Enfant VII-E
# Numéro@ 1661
# Auteur@
# Vie@
# Titre@ J - (Maître dit de la Nativité de Castello).
# Position@ — La Vierge et l'Enfant VII-E
#
#
# Raw@ S. N" — La Vierge et l'Enfant entourés d'anges. VII-E
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ La Vierge et l'Enfant entourés d'anges.
# Position@ VII-E
#
#
# Raw@ 1668 ,7 Ecole Ombrienne, vers 1500. — Saint Sébastien. VI tr. B-S
# Numéro@ 1668
# Auteur@
# Vie@
# Titre@ 7 Ecole Ombrienne, vers 1500.
# Position@ — La Vierge et l'Enfant entourés Saint Sébastien. VI tr. B-S
#
#
# Raw@ 1670 J Ecole Vénitiennè du XVIme siècle. — Portrait d'homme VI tr. B-S
# Numéro@ 1670
# Auteur@
# Vie@
# Titre@ J Ecole Vénitiennè du XVIme siècle.
# Position@ — Réception de l'ambassadeur Le Christ en croix (peut-être par Femme Portrait d'homme VI tr. B-S
#
#
# Raw@ 1673 — Portrait de femme (peut-être par Lorenzo Costai. VI tr. B-S
# Numéro@ 1673
# Auteur@
# Vie@
# Titre@ Portrait de femme (peut-être par Lorenzo Costai.
# Position@ VI tr. B-S
#
#
# Raw@ 1674 — Portrait d'homme. I-S
# Numéro@ 1674
# Auteur@
# Vie@
# Titre@ Portrait d'homme.
# Position@ I-S
#
#
# Raw@ 1674 A — Hérodiade \peut-être par Battista di Dosso). VI tr. B-S
# Numéro@ 1674
# Auteur@
# Vie@
# Titre@ A
# Position@ — Hérodiade \peut-être par Battista di Dosso). VI tr. B-S
#
#
# Raw@ S. N" — Jeune femme aux cheveux ondulés, vue jusqu'aux épaules de trois-quarts à gauche VI tr. B-S
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Jeune femme aux cheveux ondulés, vue jusqu'aux épaules de trois-quarts à gauche
# Position@ VI tr. B-S
#
#
# Raw@ 1717 MURILLO 1722 Ribeka
# Numéro@ 1717
# Auteur@
# Vie@
# Titre@ MURILLO 1722 Ribek
# Position@
#
#
# Raw@ 1721 Ribera, José de, dit L'Espagnolet. (158N-1652). — L'adoration des bergers. —
# Numéro@ 1721
# Auteur@ Ribera, José de, dit L'Espagnolet.
# Vie@  (158N-1652).
# Titre@ L'adoration des bergers.
# Position@
#
#
# Raw@ 1722 — Le Christ au tombeau. -
# Numéro@ 1722
# Auteur@ Ribera, José de, dit L'Espagnolet.
# Vie@  (158N-1652).
# Titre@ Le Christ au tombeau.
# Position@
#
#
# Raw@ 1723 — Saint Paul ermite. , —
# ...
# Numéro@ 1929
# Auteur@
# Vie@
# Titre@ 0'. Jésus-Christ célébrant la pâque avec ses disciples.
# Position@ XII
#
#
# Raw@ 1930 - Le Christ en croix XIV-S
# Numéro@ 1930
# Auteur@
# Vie@
# Titre@ Le Christ en croix
# Position@ XIV-S
#
#
# Raw@ 1931 — Le Christ en croix, réduction du tableau précédent. XII
# Numéro@ 1931
# Auteur@
# Vie@
# Titre@ Le Christ en croix, réduction du tableau précédent.
# Position@ XII
#
#
# Raw@ 1951 Claessens, Claeys ou Claeissins, Pierre, le vieux ( 1499 ou l 500-1 576), — Tête de Vierge (Attribué). XXX
# Numéro@ 1951
# Auteur@
# Vie@
# Titre@ Claessens, Claeys ou Claeissins, Pierre, le vieux ( 1499 ou l 500-1 576),
# Position@ — Tête de Vierge (Attribué). XXX
#
#
# Raw@ 1952 b Colin de Coter. 1 milieu du XVe siècle 1. — La Trinité (Centre de triptyque) XXIX
# Numéro@ 1952 b
# Auteur@
# Vie@
# Titre@ Colin de Coter. 1 milieu du XVe siècle 1.
# Position@ — La Trinité (Centre de triptyque) XXIX
#
#
# Raw@ 1952 c - Les trois Maries en pleurs ( Volet droit d'un trip- tyque). - Revers : Sainte Barbe et les armes des d'Averhoult., XXIX
# Numéro@ 1952 c
# Auteur@
# Vie@
# Titre@ Les trois Maries en pleurs ( Volet droit d'un trip- tyque).
# Position@ - Revers : Sainte Barbe et les armes des d'Averhoult XXIX
#
#
# Raw@ 2340 Craesbeeck, Joos van (vers 1605-entre 1651 et 1661). — Un peintre peignant le portrait d'un jeune seigneur. XXIV 19(17 VAN DYCK 1983 VAN DYCK
# Numéro@ 2340
# Auteur@ Craesbeeck, Joos van
# Vie@  (vers 1605-entre 1651 et 1661).
# Titre@ Un peintre peignant le portrait d'un jeune seigneur. XXIV 19(17 VAN DYCK 1983 VAN DYC
# Position@
#
#
# Raw@ 1953 J — Le Christ en croix entre sainte Madeleine et saint François. XXXVI
# Numéro@ 1953
# Auteur@
# Vie@
# Titre@ J
# Position@ — Le Christ en croix entre sainte Madeleine et saint François. XXXVI
#
#
# Raw@ 1974 VAN DYCK lgb5 VAN DYCK
# Numéro@ 1974
# Auteur@
# Vie@
# Titre@ VAN DYCK lgb5 VAN DYC
# Position@
#
#
# Raw@ 1967 — Portrait de Charles 1er, roi d'Angleterre VI tr.--E-S
# Numéro@ 1967
# Auteur@ Dyck, Anthonis van
# Vie@  (i599-i64i).
# Titre@ Portrait de Charles 1er, roi d'Angleterre VI tr.-E-
# Position@
#
#
# Raw@ 1968 — Portraits des enfants de Charles Ier, roi d'An- gleterre. (École de) -
# Numéro@ 1968
# Auteur@ Dyck, Anthonis van
# Vie@  (i599-i64i).
# Titre@ Portraits des enfants de Charles Ier, roi d'An- gleterre. (École de)
# Position@
#
#
# Raw@ 1969 — Portraits de Charles-Louis, premier du nom, duc de Bavière, et de Robert (ou Rupert), son frère, créé plus tard duc de Cumberland par Charles 1er. -
# Numéro@ 1969
# Auteur@ Dyck, Anthonis van
# Vie@  (i599-i64i).
# Titre@ Portraits de Charles-Louis, premier du nom, duc de Bavière, et de Robert (ou Rupert), son frère, créé plus tard duc de Cumberland par Charles 1er.
# Position@
#
#
# Raw@ 1970 — Portrait d'Isabelle-Claire-Eugénie d'Autriche, in- fante d'Espagne, régente des Pays- Bas. -
# Numéro@ 1970
# Auteur@ Dyck, Anthonis van
# Vie@  (i599-i64i).
# Titre@ Portrait d'Isabelle-Claire-Eugénie d'Autriche, in- fante d'Espagne, régente des Pays- Bas.
# Position@
#
#
# Raw@ @l,'34 PARIS, MUSÉE NATIONAL DU LOUVRE
# Numéro@
# Auteur@
# Vie@
# Titre@ @l,'34 PARIS, MUSÉE NATIONAL DU LOUVR
# Position@
#
#
# Raw@ 2199 Goes, Hugo van der (vers 1437-14 ]2, mort en 1482). — Mise au tombeau. (D'après) XXIX U)07 GOSSAKT 1998 GOSSAKT
# Numéro@ 2199
# Auteur@ Goes, Hugo van der
# Vie@  (vers 1437-14 ]2, mort en 1482).
# Titre@ Mise au tombeau. (D'après) XXIX U)07 GOSSAKT 1998 GOSSAK
# Position@
#
#
# Raw@ 1997 et 1998 Gossart, Jan, dit Jan van Mabuse. vers 147S- entre 1533 et 1536). — Diptyque: à gauche, portrait de Jean Carondelet, chancelier per- pétuel de Flandre. — A droite, La Vierge et l'Enfant Jésus. — Revers : à gauche, armes, chiffre et devise de Carondelet; à droite, tête de mort XXX
# Numéro@ 1997
# Auteur@
# Vie@
# Titre@ et 1998 Gossart, Jan, dit Jan van Mabuse. vers 147S- entre 1533 et 1536). — Diptyque: à gauche, portrait de Jean Carondelet, chancelier per- pétuel de Flandre. — A droite, La Vierge et l'Enfant Jésus.
# Position@ — Revers : à gauche, armes, chiffre et devise de Carondelet; à droite, tête de mort XXX
#
#
# Raw@ 1999 — Portrait d'un religieux bénédictin, âgé de 40 ans. XXX
# Numéro@ 1999
# Auteur@
# Vie@
# Titre@ Portrait d'un religieux bénédictin, âgé de 40 ans.
# Position@ XXX
#
#
# Raw@ PARIS, MUSÉE NATIONAL DU LOUVRE /l:{S
# Numéro@
# Auteur@
# Vie@
# Titre@ PARIS, MUSÉE NATIONAL DU LOUVRE /l:{
# Position@
#
#
# Raw@ 2015 - «Les jeunes piaillent comme chantaient les vieux» , , , , , , , , , ,
# Numéro@ 2015
# Auteur@ Jordaens, Jacob.
# Vie@  (1593-1678).
# Titre@ «Les jeunes piaillent comme chantaient les vieux» , , , , , , , , ,
# Position@
#
#
# Raw@ 2016 — Portrait dénommé faussement autrefois celui de Michel-Adrien Ruyter, amiral hollandais. —
# Numéro@ 2016
# Auteur@ Jordaens, Jacob.
# Vie@  (1593-1678).
# Titre@ Portrait dénommé faussement autrefois celui de Michel-Adrien Ruyter, amiral hollandais.
# Position@
#
#
# Raw@ S. N° Maître de la Madeleine Mansi. (Ecole de Quentin Metsys). — La Vierge et l'Enfant Genre du). XXX
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ Maître de la Madeleine Mansi. (Ecole de Quentin Metsys).
# Position@ — La Vierge et l'Enfant Genre du). XXX
#
#
# Raw@ 2208 et 2209 — Adam et Eve (Revers de deux volets de trip- tyque) , , , , , , , , XXX
# Numéro@ 2208
# Auteur@
# Vie@
# Titre@ et 2209
# Position@ — Adam et Eve (Revers de deux volets de trip- tyque) , , , , , , , , XXX
#
#
# Raw@ S. N° — La Vierge et l'Enfant adorés par un abbé. XXXI
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ La Vierge et l'Enfant adorés par un abbé.
# Position@ XXXI
#
#
# Raw@ 2030 b Metsys, Massys ou Matsys, Jan. 11509, 1510 ou 1511 - avant 1575 ou avant 1580). — David et Bethsabée XXX
# Numéro@ 2030 b
# Auteur@
# Vie@
# Titre@ Metsys, Massys ou Matsys, Jan. 11509, 1510 ou 1511 - avant 1575 ou avant 1580).
# Position@ — David et Bethsabée XXX
#
#
# Raw@ 2052 Millet, Frans, dit Francisque. 1 1642- 1 679). - Scène pastorale.. , , , , o., , , XXXIV
# Numéro@ 2052
# Auteur@
# Vie@
# Titre@ Millet, Frans, dit Francisque. 1 1642- 1 679).
# Position@ - Scène pastorale , , , , o , , XXXIV
#
#
# Raw@ 2299 Monogrammiste du musée de Brunswick, probable- ment Jan Sanders van Hemessen (vers 1504-entre 1555 et 15661. — La montée au calvaire. XXXI
# Numéro@ 2299
# Auteur@
# Vie@
# Titre@ Monogrammiste du musée de Brunswick, probable- ment Jan Sanders van Hemessen (vers 1504-entre 1555 et 15661.
# Position@ — La montée au calvaire. XXXI
#
#
# Raw@ 2300 — Le Sacrifice d'Abraham.,..,,,. XXXI
# Numéro@ 2300
# Auteur@
# Vie@
# Titre@ Le Sacrifice d'Abraham
# Position@ XXXI
# Raw@ S. N° — Portrait de Henri IV. (Ecole de). lIme salle de la Colonnade
# Numéro@ S. N°
# Auteur@ Pourbus, Frans, dit le jeune.
# Vie@  (1=169 ou 15 70-1622).
# Titre@ Portrait de Henri IV. (Ecole de). lIme salle de la Colonnad
# Position@
#
#
# Raw@ 2151 -cr Les oiseaux sur la branche. I-E
# Numéro@ 2151
# Auteur@
# Vie@
# Titre@ -cr Les oiseaux sur la branche.
# Position@ I-E
#
#
# Raw@ 2152 — Les singes voleurs de fruits,.,.,..,..,.,.. XXXV
# Numéro@ 2152
# Auteur@
# Vie@
# Titre@ Les singes voleurs de fruits
# Position@ XXXV
#
#
# Raw@ 2153 - Dispute de deux singes et d'un perroquet autour d'une corbeille de fruits. XXXV
# Numéro@ 2153
# Auteur@
# Vie@
# Titre@ Dispute de deux singes et d'un perroquet autour d'une corbeille de fruits.
# Position@ XXXV
#
#
# Raw@ 2156 -* L'enfant prodigue à table avec des courtisanes. VI tr. E-N
# Numéro@ 2156
# Auteur@
# Vie@
# Titre@ -* L'enfant prodigue à table avec des courtisanes.
# Position@ VI tr. E-N
#
#
# Raw@ 2157 - Les sept œuvres de miséricorde XVII
# Numéro@ 2157
# Auteur@
# Vie@
# Titre@ Les sept œuvres de miséricorde
# Position@ XVII
#
#
# Raw@ 2185 -- Le paysage aux vaches et au taureau 1-0
# Numéro@ 2185
# Auteur@
# Vie@
# Titre@ Le paysage aux vaches et au taureau
# Position@ 1-0
#
#
# Raw@ 2186 — Le chemin tournant dans un site montagneux. XXXV
# Numéro@ 2186
# Auteur@
# Vie@
# Titre@ Le chemin tournant dans un site montagneux.
# Position@ XXXV
#
#
# Raw@ 2187 — Les environs d'Anvers.,.,., XXXV
# Numéro@ 2187
# Auteur@
# Vie@
# Titre@ Les environs d'Anvers
# Position@ XXXV
#
#
# Raw@ 2188 — Le troupeau.,. XXXV
# Numéro@ 2188
# Auteur@
# Vie@
# Titre@ Le troupeau
# Position@ XXXV
#
#
# Raw@ 2189 — La déposition du Christ. (D'après L. Lo-rTO.) XXXV
# Numéro@ 2189
# Auteur@
# Vie@
# Titre@ La déposition du Christ. (D'après L. Lo-rTO.)
# Position@ XXXV
#
#
# Raw@ 2190 — L'Adoration de l'Enfant Jésus tenu par la Vierge. (D'après TITIKNI XXXV
# Numéro@ 2190
# Auteur@
# Vie@
# Titre@ L'Adoration de l'Enfant Jésus tenu par la Vierge. (D'après TITIKNI
# Position@ XXXV
#
#
# Raw@ 2194 PAUL DE Vos 215g T ENIERS
# Numéro@ 2194
# Auteur@
# Vie@
# Titre@ PAUL DE Vos 215g T ENIER
# Position@
#
#
# Raw@ S. N° École de Louvain, XVme siècle. —La chute des réprou vés. (Probablement par Dirk Bouts le vieux) XXIX
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ École de Louvain, XVme siècle. —La chute des réprou vés. (Probablement par Dirk Bouts le vieux)
# Position@ XXIX
#
#
# Raw@ 2203 c École flamande, commencement du XVIme siècle. - La Vierge et l'Enfant Jésus. XXX
# Numéro@ 2203 c
# Auteur@
# Vie@
# Titre@ École flamande, commencement du XVIme siècle.
# Position@ - La Vierge et l'Enfant Jésus. XXX
#
#
# Raw@ 2204 — Portrait de femme tenant un livre XXX
# Numéro@ 2204
# Auteur@
# Vie@
# Titre@ Portrait de femme tenant un livre
# Position@ XXX
#
#
# Raw@ 2205 b — Portrait de Charles-Quint, à l'âge d'environ 20 ans.. , , , , XXX
# Numéro@ 2205 b
# Auteur@
# Vie@
# Titre@ Portrait de Charles-Quint, à l'âge d'environ 20 ans , , , ,
# Position@ XXX
#
#
# Raw@ S. N" — Le même portrait, copie ancienne avec variantes. Coll. Schlichting
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Le même portrait, copie ancienne avec variantes.
# Position@ Coll. Schlichting
#
#
# Raw@ 2018 b — Religieux offrant son cœur à l'Enfant Jésus (Genre du Maître de la Mort de Marie, avec paysage dans le goût de Patinir). o. XXXI
# Numéro@ 2018 b
# Auteur@
# Vie@
# Titre@ Religieux offrant son cœur à l'Enfant Jésus (Genre du Maître de la Mort de Marie, avec paysage dans le goût de Patinir). o.
# Position@ XXXI
#
#
# Raw@ 2742 — Portrait d'homme. (Autrefois attribué à Holbein, N. Neufchâtel, puis B. Bruyn; probablement du Maître de la Mort de Marie). XXXII
# Numéro@ 2742
# Auteur@
# Vie@
# Titre@ Portrait d'homme. (Autrefois attribué à Holbein, N. Neufchâtel, puis B. Bruyn; probablement du Maître de la Mort de Marie).
# Position@ XXXII
#
#
# Raw@ S. N° École de Bruges, deuxième moitié du XVIme siècle. - Portrait de femme XXX
# Numéro@ S. N°
# Auteur@
# Vie@
# Titre@ École de Bruges, deuxième moitié du XVIme siècle.
# Position@ — Portrait Au revers: Portrait de femme XXX
#
#
# Raw@ 2 ">4"; CUyp 2-548 GERARD Dou
# Numéro@ 2
# Auteur@
# Vie@
# Titre@ ">4"; CUyp 2-548 GERARD Do
# Position@
#
#
# Raw@ 2359 a Drost, Jacob ou Cornelis van (?-i678)—Bethsabée. XXVI
# Numéro@ 2359 a
# Auteur@
# Vie@
# Titre@ Drost, Jacob ou Cornelis van (?-i678)—Bethsabée.
# Position@ XXVI
#
#
# Raw@ 2360 Duck, Jacob. (vers 1600- après 1660) — Le dépôt du butin. (Autrefois attribué à Jan Duck). XXIII Dujardin, Karel. voir Jardin, Karel du.
# Numéro@ 2360
# Auteur@ Duck, Jacob.
# Vie@  (vers 1600- après 1660)
# Titre@ Le dépôt du butin. (Autrefois attribué à Jan Duck). XXIII Dujardin, Karel. voir Jardin, Karel du
# Position@
#
#
# Raw@ 2404 HOBBEMA 241; PlETER DE HOOCH
# Numéro@ 2404
# Auteur@
# Vie@
# Titre@ HOBBEMA 241; PlETER DE HOOC
# Position@
#
#
# Raw@ PARIS, MUSÉE NATIONAL DU LOUVRE 'l);)
# Numéro@
# Auteur@
# Vie@
# Titre@ PARIS, MUSÉE NATIONAL DU LOUVRE 'l);
# Position@
#
#
# Raw@ 2443 a Lastman, Pieter Pietersz. (1583-1633). — Le Sacrifice d'Abraham. XXI Leyde (Lukas van) voir Lukas van Leyden
# Numéro@ 2443 a
# Auteur@ Lastman, Pieter Pietersz.
# Vie@  (1583-1633).
# Titre@ Le Sacrifice d'Abraham. XXI Leyde (Lukas van) voir Lukas van Leyde
# Position@
#
#
# Raw@ 2444 Lievens, Jan. (1607-1674). — La Vierge visitant sainte Elisabeth VI, tr. F-N
# Numéro@ 2444
# Auteur@ Lievens, Jan.
# Vie@  (1607-1674).
# Titre@ La Vierge visitant sainte Elisabeth VI, tr. F-
# Position@
#
#
# Raw@ PARIS, MUSÉE NATIONAL DU LOUVRE /j;-{}
# Numéro@
# Auteur@
# Vie@
# Titre@ PARIS, MUSÉE NATIONAL DU LOUVRE /j;-{
# Position@
#
#
# Raw@ 2515 .7 Palamedesz, Anthonie. vers 1601-1073). — Portrait d'homme âgé de';! ans. XXIV 253X REMBRANDT 2^40 REMBRANDT 2527 PAULUS POTTHR
# Numéro@ 2515
# Auteur@ .7 Palamedesz, Anthonie. vers
# Vie@  1601-1073).
# Titre@ Portrait d'homme âgé de';! ans. XXIV 253X REMBRANDT 2^40 REMBRANDT 2527 PAULUS POTTH
# Position@
#
#
# Raw@ 254 L REMBRANDT 253b REMBRANDT
# Numéro@ 254
# Auteur@
# Vie@
# Titre@ L REMBRANDT 253b REMBRAND
# Position@
#
#
# Raw@ 2534 Ravesteyn, Jan Anthonisz van. (vers 1572-1 657)- — Portrait de femme âgée de 54 ans. I-N
# Numéro@ 2534
# Auteur@
# Vie@
# Titre@ Ravesteyn, Jan Anthonisz van. (vers 1572-1 657)-
# Position@ — Portrait de femme âgée de 54 ans. I-N
#
#
# Raw@ 2535 - Portrait de femme. XX
# Numéro@ 2535
# Auteur@
# Vie@
# Titre@ Portrait de femme.
# Position@ XX
#
#
# Raw@ 2541 -i — Ermite lisant XXII
# Numéro@ 2541
# Auteur@
# Vie@
# Titre@ -i
# Position@ — Ermite lisant XXII
#
#
# Raw@ 2555 a — Les pèlerins d'EmmaÜs. VI tr. F-N
# Numéro@ 2555 a
# Auteur@
# Vie@
# Titre@ Les pèlerins d'EmmaÜs.
# Position@ VI tr. F-N
#
#
# Raw@ S. N" - Portrait du frère de Rembrandt, Adriaen Har- mensz van Rijn, avec un médaillon suspendu à une chaîne d'or VI tr. F-N
# Numéro@ S. N"
# Auteur@
# Vie@
# Titre@ Portrait du frère de Rembrandt, Adriaen Har- mensz van Rijn, avec un médaillon suspendu à une chaîne d'or
# Position@ VI tr. F-N
#
#
# Raw@ 2562 Saftleven, dit aussi Zachtleven, Cornelis vers 1607-
# Numéro@ 2562
# Auteur@
# Vie@
# Titre@ Saftleven, dit aussi Zachtleven, Cornelis vers 1607
# Position@
#
#
# Raw@ 1681 1. — Portrait d'un peintre. XXIV
# Numéro@ 1681
# Auteur@
# Vie@
# Titre@ 1.
# Position@ — Portrait d'un peintre. XXIV
#
#
# Raw@ 2571 Sorgh, dit Rokes, Hendrik Martensz. vers 1011- 167°1. - Intérieur de cuisine. XXV
# Numéro@ 2571
# Auteur@
# Vie@
# Titre@ Sorgh, dit Rokes, Hendrik Martensz. vers 1011- 167°1.
# Position@ - Intérieur de cuisine. XXV
#
#
# Raw@ 2572 — Intérieur d'estaminet. XX
# Numéro@ 2572
# Auteur@
# Vie@
# Titre@ Intérieur d'estaminet.
# Position@ XX
#
#
# Raw@ 2577 Staveren, Johan-Andriaensz van. vers 1625-peu après 1668 — Un savant dans son cabinet XXV
# Numéro@ 2577
# Auteur@
# Vie@
# Titre@ Staveren, Johan-Andriaensz van. vers 1625-peu après 1668
# Position@ — Un savant dans son cabinet XXV
#
#
# Raw@ 2581 Steenwyk, Hendrik van, le jeune, (vers 1580-vers 16491. — Jésus-Christ chez Marthe et Marie. (Figuresattribuées à Cornelis van Poelenburgh). XXI
# Numéro@ 2581
# Auteur@
# Vie@
# Titre@ Steenwyk, Hendrik van, le jeune, (vers 1580-vers 16491.
# Position@ — Jésus-Christ chez Marthe et Marie. (Figuresattribuées à Cornelis van Poelenburgh). XXI
#
#
# Raw@ 2609 Weenix, Jan-Baptist, ou Giovanni-Battista. 1621 -1660). — Les corsaires repoussés XXIII
# Numéro@ 2609
# Auteur@
# Vie@
# Titre@ Weenix, Jan-Baptist, ou Giovanni-Battista. 1621 -1660).
# Position@ — Les corsaires repoussés XXIII
#
#
# Raw@ 2701 J Bruyn, Bartholomœus ou Barthel. (1493- entre 1553 et 1 s S 7^- — Portrait de Philipp Gail à 49 ans, avec ses fils dont : Philip et Andréas. XXXII
# Numéro@ 2701
# Auteur@
# Vie@
# Titre@ J Bruyn, Bartholomœus ou Barthel. (1493- entre 1553 et 1 s
# Position@ S 7^- — Portrait de Philipp Gail à 49 ans, avec ses fils dont : Philip et Andréas. XXXII
#
#
# Raw@ 2701 b — Portrait de la deuxième femme de Philipp Gail, à 37 ans, avec les filles de celui-ci. XXXII
# Numéro@ 2701 b
# Auteur@
# Vie@
# Titre@ Portrait de la deuxième femme de Philipp Gail, à 37 ans, avec les filles de celui-ci.
# Position@ XXXII
#
#
# Raw@ S. N° — Portrait de l'artiste, âgé de 22 ans., XXXIII 2702 a CRANACH
# Numéro@ S. N°
# Auteur@ Durer, Albrecht.
# Vie@  (1471-1528).
# Titre@ Portrait de l'artiste, âgé de 22 ans XXXIII 2702 a CRANAC
# Position@
#
#
# Raw@ 27 r, HOLBEIN 2714 Holbein
# Numéro@ 27
# Auteur@
# Vie@
# Titre@ r, HOLBEIN 2714 Holbei
# Position@
#
#
# Raw@ 2739 Maître de Messkirch. (XVlme siècle). — Le Christ devant Pilate. XXXII
# Numéro@ 2739
# Auteur@
# Vie@
# Titre@ Maître de Messkirch. (XVlme siècle).
# Position@ — Le Christ devant Pilate. XXXII
#
#
# Raw@ 2715 HoLBEiN 2738 MAÎTRE DE LA SAINTE PARENTÉ
# Numéro@ 2715
# Auteur@
# Vie@
# Titre@ HoLBEiN 2738 MAÎTRE DE LA SAINTE PARENT
# Position@
#
#
# Raw@ 2734 Ruthart, Karl Andreas. levers 1640-après* 1672). — Chasse à l'ours. XXXIII
# Numéro@ 2734
# Auteur@
# Vie@
# Titre@ Ruthart, Karl Andreas. levers 1640-après* 1672).
# Position@ — Chasse à l'ours. XXXIII

# %%
#Rows with an empty field are always incorrectly parsed. Here is a lower bound for the percentage of failures.
print(len(artworks_df[artworks_df.author.apply(lambda p : len(p) == 0)])/len(artworks_df))
# Out:
# 0.10668143226282761

# %%
#Join together words that were splitted in the catalogue due to line return.
artworks_df["title"] = artworks_df.title.apply(lambda text : re.sub("(\S)- (\S)","\\1\\2",text))

print(len(artworks_df))
print(len(artworks_df.replace("",np.nan).dropna()))
# Out:
# 2709
# 2254

# %%
artworks_df.replace("",np.nan).dropna().sample(10)
# Out:
#      number                                     author  \
# 560    340       Géricault, Jean-Louis-André-Théodore.
# 2312  2194                               Vos, Paul de.
# 87      75                           Bourdon,Sébastien
# 2578  2559            Ruisdael ou Ruysdael, Jacob van.
# 1199   828                         Rousseau, Théodore.
# 1681  1361                           Luini, Bernardino
# 1165   794                    Rigaud y Ros, Hyacinthe.
# 178    132   Clouet, François, dit Jehannet, ou Janet.
# 702   2954                             Isabey, Eugène.
# 420    249                        Desportes, François.
#
#                                       life  \
# 560                      (17° J - J 824).
# 2312                    (vers 1590-1678).
# 87                          .(1616-1671).
# 2578                (1628 ou 1620- 1682).
# 1199                          1812-1867).
# 1681   (entre 1475 et 1480-1531 ou 1532).
# 1165                         (1059-1743).
# 178                       (mort en 1572).
# 702                          (1804-1886).
# 420                          (1661-1743).
#
#                                                   title  \
# 560   Officiers de chasseurs à cheval de la garde im...
# 2312                              La mort du chevreuil
# 87                                 UnehaltedeBohémiens
# 2578                           Paysage, dit le Buisson
# 1199                     Lisière d'une forêt; esquisse
# 1681  Le Christ. Fresque de l'Oratoire de Greco Mila...
# 1165                             Portrait d'homme âgé.
# 178   Portrait de Charles IX, en buste, (réplique pr...
# 702                                            Le pont
# 420           Son portrait, par lui-même, en chasseur.
#
#                         position  \
# 560   E. F. XIXe S. 1er étage II
# 2312                         1-0
# 87                         XIV-N
# 2578                  VI tr. F-S
# 1199   E. F. XIXe S. 1er étage 1
# 1681                           V
# 1165                         I-E
# 178                           XI
# 702     E. F. XIXe S. 2e étage 1
# 420                        XVI-N
#
#                                                     raw
# 560   340 — Officiers de chasseurs à cheval de la ga...
# 2312                    2194 — La mort du chevreuil 1-0
# 87    75 Bourdon,Sébastien.(1616-1671). UnehaltedeBo...
# 2578          2559 — Paysage, dit le Buisson VI tr. F-S
# 1199  828 — Lisière d'une forêt; esquisse E. F. XIXe...
# 1681  1361 — Le Christ. Fresque de l'Oratoire de Gre...
# 1165  794 Rigaud y Ros, Hyacinthe. (1059-1743). — Po...
# 178   132 — Portrait de Charles IX, en buste, (répli...
# 702             2954 — Le pont E. F. XIXe S. 2e étage 1
# 420   249 — Son portrait, par lui-même, en chasseur....

# %%
clean_artworks_df = artworks_df.replace("",np.nan).dropna().drop("raw",axis = 1)
clean_artworks_df.to_csv("data/catalogue_artworks.csv")

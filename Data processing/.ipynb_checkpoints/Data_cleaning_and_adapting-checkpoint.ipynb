# %% [markdown]
# The goal of this notebook is to clean completely the data and adapt it to Unity3D.

# %%
import pandas as pd
import re
import numpy as np

from string import punctuation

import urllib.request

from tqdm.autonotebook import tqdm

from PIL import Image
from bs4 import BeautifulSoup

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## Séparation salles-murs

# %%
artworks_df = pd.read_csv("data/complete_artworks.csv")
artworks_df = artworks_df.drop('Unnamed: 0',axis = 1).drop('Unnamed: 0.1',axis = 1).drop('Unnamed: 0.1.1',axis = 1)

# %%
wall_regex = "-[NESO0]$|-[NESO0] "

def get_wall(text):
    for match in re.finditer(wall_regex,text):
        wall = match.group()[1]
        return "O" if wall == "0" else wall
    return np.NaN

def delete_wall(text):
    for match in re.finditer(wall_regex,text):
        start, end = match.span()
        return text[:start]
    return text

# %%
artworks_df["wall"] = artworks_df.position.apply(get_wall)
artworks_df["position"] = artworks_df.position.apply(delete_wall)

# %% [markdown]
# ## Nettoyage des positions

# %%
for text in artworks_df["position"].unique():
    print(text)
# Out:
# Ire S. de la Céramique antique
# VIII
# Palier esc.T.T.
# XVI
# Musée Charles X Salle IX Baptiste, J.-B. Monnoyer dit. Voir Monnoyer.
# T. T.
# Coll. Camondo
# S. Barye
# E. F. XIX S. 2e étage II
# XIV
# E. F. XIXe S. 2e étage II
# E. F. XIXe , , , X
# X
# Esc. T. T.
# II
# E. F. XIXe S. 1er étage I
# S. de Mécène
# S. d'Auguste
# S. Meubles XVIIe
# Gai. d'Apollon
# S. Meubles XVIIe S.
# Marine 1
# Coll. Schlichting
# Esc. Henri IV
# S. Meubles XVIIIe
# I
# S. des Pastels
# E. F. XIX^ S. 1er étage III
# XV
# XII
# - Voir Courtois
# S. N° Bureau, Pierre-Isidore. (1822-1876). — Clair de lune sur les bords de l'Oise à l'Isle - Adam E. F. XIXe S. 1er étage 1
# S. N° Bureau, Pierre-Isidore. (1822-1876). — Clair de lune sur les bords de l'Oise à l'Isle - Adam E. F. XIXe S. 1er étage III
# E. F XIXe S. 2e étage 1
# 1
# S. Meubles XVIIIme
# S. 2e étage I
# Palier esc.T. T
# E. F. XIXe S. 1er étage III
# E. F. XIXe S. 1er étage II
# E. F. XIXe S. 2e étage I
# E. F. XIXe S. 2e étage H
# XI
# - XI
# S. de la Colonnade
# III
# S. des fresques et verres antiques i^l) Constant, Benjamin. (1815-1902). Portrait d'A. Chau- chard Coll. Chauchard III
# E. F. XIXe S. 2e étage 1
# E. F. XIXe S. 1er étage 1
# Palier esc. T. T.
# Coll. Chauchard, galerie
# Coll. Chauchard, II
# Coll. Chauchard, IV
# Coll. Chauchard, III
# Coll. Chauchard, 1
# Vestibule Galerie d'Apollon, Coupole
# E. F. XIXe S' 1er étage II
# S. Blarenberghe
# Esc. Daru
# 111
# 11
# Coll. Chauchard, IV i36) — Le marchand d'oranges. , — galerie
# Coll. Camondo (159^ i36) La femme à la potiche. , galerie
# E. F. XIXe S. 2e étage 1 206' b — Arrestation de Charlotte Corday — II
# E. F. XIXe S. 2e étage 1 r [217 a — La jeune Martyre. E. F. XIXe S. 1er étage III
# IIe S. Meubles XVIIIe
# S. de Céramique antique
# - , 1
# Vest. S. anglaises
# Musée Charles X, S. IX
# T. T
# E. F. XIXe S. 2e étage 1 Fontenay. — Voir Blain ou Belin de Fontenay
# Céramique antique IVe S.
# Céramique antique VIe S.
# Musée Charles X, S. I
# S. VI corniche. - S. VI
# S. des sept cheminées.
# - 1
# E F. XIXe S. 2e étage II
# S. grecque ou de Phidias
# S. mobilier du XVIIe siècle
# Marine, 1
# IVe S. Meubles XVIIIe
# - Portrait de Fabre _d'Eglantine I
# — Napoléon sur le champ de bataille d'Evlau III
# S. dessins XIXe
# - de Gros. III
# Musée Charles X, S. 1
# S. V
# - GRos. (64) HENNER
# - GRos. (64) III
# S. des Antonins
# Vest. S. Bronzes
# S. dessins XIXe S.
# Marine
# E F. XIXe S. 1er étage III
# S. Isabey
# Coll. Chauchard 1
# V
# Coll. Chauchard, I
# Musée du Louvre, construit sous le premier Empire par Percier et Fontaine (Gouache) Vest. S. V.
# Coll. Chauchard, i
# S. dessins Watteau
# Coll. Arconati-Visconti
# Musée d'Angers T. XVI
# S. des pastels
# IX
# — Un maréchal dans sa forge XII
# — Jeunes gens jouant aux cartes. XII
# XIII
# Esc. Mollien
# non exposé
# Esc. Henri II
# Vest. Galerie d'Apollon, coupole
# S. bijoux antiques
# IIIe S. mobilier XVIIIe
# Coll. Chauchard IV
# Coll. Chauchard II
# Coll. Chauchard
# Coll. II
# Coll. IV
# - 1 b;2) Voir La Tour
# S. Grecque
# Palier escalier Daru
# — Voussures: Symbolisation des hon- neurs rendus aux artistes. Médaillons repré- sentant les peintres célèbres du siècle de Louis XIV à celui de Napoléon ler Salle V
# Musée Charles X, VIIme s.
# Coll. Chauchard III
# Coll. Camondo \192) — Londres, le Parlement. Trouée de soleil dans le brouillard  —
# E. F. XIXe S. 2e étgage II
# Galerie d'Apollon
# Vest. S. V.
# Ire S. Meubles XVIIIe
# Musée Charles X, Salle IV
# Musée Charles X, salle VI
# E. F. XIX« S. 2e étage II
# S. grecque
# Musée Charles X, S. II
# S. III
# E. F. XIXe S. 2e ét. II
# S. 1er étage III
# S , , XVI
# S. des La Tour de SI.-Quentin
# Vest. des S. anglaises
# S. Meubles XVIII"
# E. F XIXe S. 2e étage II
# S ANTERKE
# E. F. XIXe S. le, ét. II
# E. F. XIXeS. 1er étage III
# E. F. XIXe S. 2e étage II Sevin de la Pennaye, Charles. — Voir Rigaud
# E. F. XIXe S. 2e étage II Sevin de la Pennaye, Charles. 1er étage II
# Céramique antique S. II
# S. des La Tour de St.-Quentin
# E. F. XIXe S. 2" étage II
# S. des dessins XIXe
# Coll. Chauchard galerie i 120) — Le pâturage à la gardeuse d'oies — 1
# Coll. Chauchard galerie i 120) — Le pâturage à la gardeuse d'oies — IV
# Coll. Chauchard galerie i 120) — Le pâturage à la gardeuse d'oies — galerie
# — La vache blanche qui se gratte galerie
# E. F. XIXe S. 1er étage 1 Valentin, Le. Voir Boulongne, Jean de.
# — Q2 1 C. J. VERNET 961 VESTIER
# Musée Charles X, salle IV
# Musée Charles X, salle VII
# Musée Charles X, salle IX
# Coll. Chauchard, galerie 1^135' — Le Palais ducal, à Venise — 1
# Coll. Chauchard, galerie 1^135' — Le Palais ducal, à Venise — galerie
# Coll. Chauchard, galerie 1^135' — Le S. M. della Salute. — galerie
# Coll. Chauchard, galerie 1^135' — Le S. M. della Salute. — 1
# Coll. Chauchard, galerie 1^135' — Le S. galerie INCONNUS DE L'ÉCOLE FRANÇAISE
# — Au revers : les armes de Bourgogne (peut- être par Jean Malouel, peintre du duc de Bourgogne, t 1415) X vitrine
# — Au revers: les clous et la couronne d'épines. Forme ronde (Ecole de l'Ile de France, entre 1390 et 1410). X vitrine
# I tr. B
# I tr. D
# I tr. A
# I tr. C
# IV
# — Songe de saint Jérôme VII
# VII
# — L'Annon- ciation VI tr. A
# — La Vierge et l'Enfant, avec Ste. Martine. VI tr. B
# - La Circoncision. VI tr. A
# — La Vierge glori- euse entre saint Bernard et sainte Madeleine. VII
# — Saint François d'Assise VI tr. B
# IIIe S. Meubles XVIIIe
# — Le Christ et la Vierge apparaissant à saint François d'Assise VI tr. D
# — La Présen- tation au temple. VII
# - La Madone du Magnificat (Ecole de) VII
# — Portrait de jeune homme. VI tr. A
# — La Vierge et l'Enfant entourés d'anges. VII
# - Saint François d'Assise recevant les stigmates. VII
# — Vittorino da Feltre VII
# I tr A
# — Ag.ir dans le désert VI tr. D
# — Les saintes femmes préparant le tombeau. VII
# Coll. Arconati Visconti
# — La diseuse de bonne-aventure VI tr. D
# — La chaste Su- zanne. (Attribué) I
# — La prédication de saint Jean-Baptiste. VI tr. D
# — La prédication de Ecce Homo. VI tr. A
# - La Vierge et l'Enfant. VII
# — L'adoration des bergers VI tr. B
# — Tableau en deux compartiments: saint Fran- çois recevant les stigmates. Saint Côme et saint Damien soignant un malade. VII
# B
# S. des Saisons
# S. de la Paix
# S. de Septime Sévère
# - quatre saints. (Attribué) VII
# — Portrait présumé de Gaston de Foix VI tr. B
# — L'adoration des Mages. (Attribué) VI tr. A
# S. No TIEPOLO
# — La Vierge et l'Enfant avec des saints. (Attribué) VII
# — La Circoncision VI tr. A
# — Martyre de sainte Irène VI tr. D
# XXVIII
# — Fruits et instru- ments de musique VI tr. D
# — Inconnus de l'École Espagnole
# A-I
# S. N° LAWRENCE
# Marine à Greenwich. (Attribué) A-II
# XX
# XXXIV
# XXXI
# I tr. E
# XXIX
# V tr. E
# XXX
# XXXV
# Ire Salle de la Colonnade
# - van Eyck. XXI
# XVII
# Musée de Brunswick.
# XXXVI
# XXVII
# — La Vierge et l'Enfant La Cène. XXXI
# — Saint Jean-Bap- tiste. Sainte Marie-Madeleine. (Deux volets d'un même triptyque) XXIX
# Coll. Thiers
# XIX
# XVIII
# Galerie du Luxem- bourg VI tr. E
# - , , , , XXXV
# — Revers : Une tête de mort et une croix XXIX INCONNUS DE L'ÉCOLE FLAMANDE.
# — Portrait de jeune homme. XXI
# XXIII
# I tr. F
# XXIV
# XXVI
# XXV
# XXI
# Nouv. Acq.
# XXII
# Coll. Schlichting.
# - Lotli et ses filles. XXXI
# - La mise au tom- beau XXI
# Coll. Thiers.
# Coll. Schlichting Victors, Jan, voir Fictoor. 2604 Vlieger, Simon de. (1601-1613). — Marine par un temps calme" XXII
# — Lisière de forêt XXIV
# — Vénus et )'Amour. XXXI
# — A gau- che: Le peintre debout derrière son bureau.
# XXXII
# XXXIII

# %% [markdown]
# Les données sont visiblement encore particulièrement sales. Certaines salles apparaissent sous plusieurs formes (Gai. ou Gal) ou possèdent des déchets.
#
# On doit avoir un ensemble fini de salles avec un nom bien défini pour pouvoir choisir comment nommer les salles lors de l'utilisation du GUI. Il faut donc créer cet ensemble dès maintenant.
#
# Par ailleurs, la ponctuation ne semble pas essentielle. On peut la retirer.

# %%
def standardize_position(s):
    s = re.sub("(\S)- (\S)","\\1\\2",s)
    p = punctuation.replace("-","")
    p = p.replace("'","")
    s = s.translate({ord(i) : " " for i in p})
    s = " ".join(s.split())
    if (s.startswith("-") or s.startswith("—")):
        if len(s) > 10:
            return np.NaN
        else:
            return s[2:] #Cas tiret + numéro de salle
    else:
        return s

artworks_df.position = artworks_df.position.apply(standardize_position)

# %%
for text in sorted(list(str(x) for x in artworks_df["position"].unique())):
    print(text)
# Out:
# 1
# 11
# 111
# A-I
# B
# Coll Arconati Visconti
# Coll Arconati-Visconti
# Coll Camondo
# Coll Camondo 159 i36 La femme à la potiche galerie
# Coll Camondo 192 — Londres le Parlement Trouée de soleil dans le brouillard —
# Coll Chauchard
# Coll Chauchard 1
# Coll Chauchard I
# Coll Chauchard II
# Coll Chauchard III
# Coll Chauchard IV
# Coll Chauchard IV i36 — Le marchand d'oranges — galerie
# Coll Chauchard galerie
# Coll Chauchard galerie 1 135' — Le Palais ducal à Venise — 1
# Coll Chauchard galerie 1 135' — Le Palais ducal à Venise — galerie
# Coll Chauchard galerie 1 135' — Le S M della Salute — 1
# Coll Chauchard galerie 1 135' — Le S M della Salute — galerie
# Coll Chauchard galerie 1 135' — Le S galerie INCONNUS DE L'ÉCOLE FRANÇAISE
# Coll Chauchard galerie i 120 — Le pâturage à la gardeuse d'oies — 1
# Coll Chauchard galerie i 120 — Le pâturage à la gardeuse d'oies — IV
# Coll Chauchard galerie i 120 — Le pâturage à la gardeuse d'oies — galerie
# Coll Chauchard i
# Coll II
# Coll IV
# Coll Schlichting
# Coll Schlichting Victors Jan voir Fictoor 2604 Vlieger Simon de 1601-1613 — Marine par un temps calme XXII
# Coll Thiers
# Céramique antique IVe S
# Céramique antique S II
# Céramique antique VIe S
# E F XIX S 1er étage III
# E F XIX S 2e étage II
# E F XIXe S 1er étage 1
# E F XIXe S 1er étage 1 Valentin Le Voir Boulongne Jean de
# E F XIXe S 1er étage I
# E F XIXe S 1er étage II
# E F XIXe S 1er étage III
# E F XIXe S 2 étage II
# E F XIXe S 2e ét II
# E F XIXe S 2e étage 1
# E F XIXe S 2e étage 1 206' b — Arrestation de Charlotte Corday — II
# E F XIXe S 2e étage 1 Fontenay — Voir Blain ou Belin de Fontenay
# E F XIXe S 2e étage 1 r 217 a — La jeune Martyre E F XIXe S 1er étage III
# E F XIXe S 2e étage H
# E F XIXe S 2e étage I
# E F XIXe S 2e étage II
# E F XIXe S 2e étage II Sevin de la Pennaye Charles 1er étage II
# E F XIXe S 2e étage II Sevin de la Pennaye Charles — Voir Rigaud
# E F XIXe S 2e étgage II
# E F XIXe S le ét II
# E F XIXe S' 1er étage II
# E F XIXe X
# E F XIXeS 1er étage III
# E F XIX« S 2e étage II
# Esc Daru
# Esc Henri II
# Esc Henri IV
# Esc Mollien
# Esc T T
# Gai d'Apollon
# Galerie d'Apollon
# Galerie du Luxembourg VI tr E
# I
# I tr A
# I tr B
# I tr C
# I tr D
# I tr E
# I tr F
# II
# III
# IIIe S Meubles XVIIIe
# IIIe S mobilier XVIIIe
# IIe S Meubles XVIIIe
# IV
# IVe S Meubles XVIIIe
# IX
# Ire S Meubles XVIIIe
# Ire S de la Céramique antique
# Ire Salle de la Colonnade
# Marine
# Marine 1
# Marine à Greenwich Attribué A-II
# Musée Charles X S 1
# Musée Charles X S I
# Musée Charles X S II
# Musée Charles X S IX
# Musée Charles X Salle IV
# Musée Charles X Salle IX Baptiste J -B Monnoyer dit Voir Monnoyer
# Musée Charles X VIIme s
# Musée Charles X salle IV
# Musée Charles X salle IX
# Musée Charles X salle VI
# Musée Charles X salle VII
# Musée d'Angers T XVI
# Musée de Brunswick
# Musée du Louvre construit sous le premier Empire par Percier et Fontaine Gouache Vest S V
# Nouv Acq
# Palier esc T T
# Palier escalier Daru
# S 1er étage III
# S 2e étage I
# S ANTERKE
# S Barye
# S Blarenberghe
# S Grecque
# S III
# S Isabey
# S Meubles XVIII
# S Meubles XVIIIe
# S Meubles XVIIIme
# S Meubles XVIIe
# S Meubles XVIIe S
# S No TIEPOLO
# S N° Bureau Pierre-Isidore 1822-1876 — Clair de lune sur les bords de l'Oise à l'Isle - Adam E F XIXe S 1er étage 1
# S N° Bureau Pierre-Isidore 1822-1876 — Clair de lune sur les bords de l'Oise à l'Isle - Adam E F XIXe S 1er étage III
# S N° LAWRENCE
# S V
# S VI corniche - S VI
# S XVI
# S bijoux antiques
# S d'Auguste
# S de Céramique antique
# S de Mécène
# S de Septime Sévère
# S de la Colonnade
# S de la Paix
# S des Antonins
# S des La Tour de SI -Quentin
# S des La Tour de St -Quentin
# S des Pastels
# S des Saisons
# S des dessins XIXe
# S des fresques et verres antiques i l Constant Benjamin 1815-1902 Portrait d'A Chauchard Coll Chauchard III
# S des pastels
# S des sept cheminées
# S dessins Watteau
# S dessins XIXe
# S dessins XIXe S
# S grecque
# S grecque ou de Phidias
# S mobilier du XVIIe siècle
# T T
# V
# V tr E
# VII
# VIII
# Vest Galerie d'Apollon coupole
# Vest S Bronzes
# Vest S V
# Vest S anglaises
# Vest des S anglaises
# Vestibule Galerie d'Apollon Coupole
# X
# XI
# XII
# XIII
# XIV
# XIX
# XV
# XVI
# XVII
# XVIII
# XX
# XXI
# XXII
# XXIII
# XXIV
# XXIX
# XXV
# XXVI
# XXVII
# XXVIII
# XXX
# XXXI
# XXXII
# XXXIII
# XXXIV
# XXXV
# XXXVI
# nan
# non exposé

# %% [markdown]
# On constate que le merge position a parfois fail (Notamment S III ou S 1er étage III sont clairement des données incomplètes)

# %%
#Inverted dictionnary with unclean_value : clean_value
clean_rooms_inverted = {}
with open("Rooms.txt",encoding = "utf-8") as f:
    for line in f:
        (val, keys) = (line.split("/")[0].replace("\n",""), list(map(lambda text : text.replace("\n",""),line.split("/"))))
        for k in keys:
            clean_rooms_inverted[k] = val

# Attention : avec un startwith, on risque de choisir I au lieu de I tr E par exemple.
# Avec un match parfait, on ne va pas tenir compte de toutes les données dégénérées.
# Il faut donc choisir le plus long des match startwith.

def clean_room(text):
    text = str(text)
    possible_matches = []
    for room in clean_rooms_inverted:
        if text.startswith(room):
            possible_matches.append(room)
    
    if len(possible_matches) > 0:
        return clean_rooms_inverted.get(max(possible_matches, key = len))
    else:
        return np.NaN

# %%
artworks_df["clean_position"] = artworks_df.position.apply(clean_room)

# %%
artworks_df[artworks_df.clean_position.isnull()] #Pour l'instant, ça marche bien. Ce dataframe doit rester nul !
# Out:
# Empty DataFrame
# Columns: [number, author, life, title, position, width, height, image_url, wall, clean_position]
# Index: []

# %%
artworks_df = artworks_df.drop("position",axis = 1)
artworks_df = artworks_df.rename(columns = {"clean_position":"position"})

# %%
artworks_df.head()
# Out:
#    number                                             author  \
# 0      *                                   ['alaux', 'jean']
# 1      *                                   ['alaux', 'jean']
# 2      2   ['aligny', 'claude', 'françois', 'théodore', '...
# 3  S. N°                                 ['amaury', 'duval']
# 4      9                         ['aved', 'andré', 'joseph']
#
#                life                                              title width  \
# 0    (1786-1864').   poussin arrivant de rome est présenté par rich...   NaN
# 1    (1786-1864').   douze médaillons d'or représentant les travaux...   NaN
# 2   (r 798- 1871).                                 une villa itajienne   NaN
# 3     (1808-1885).                                 portrait de mille x   NaN
# 4     (1702-1766).                     portrait du marquis de mirabeau   NaN
#
#   height image_url wall             position
# 0    NaN       NaN  NaN  Céramique antique I
# 1    NaN       NaN  NaN  Céramique antique I
# 2    NaN       NaN    E                 VIII
# 3    NaN       NaN  NaN              Esc T T
# 4    NaN       NaN    S                  XVI

# %% [markdown]
# ## Nettoyage des dimensions

# %%
artworks_df[~artworks_df.width.isnull()].sample(5)
# Out:
#       number                        author            life  \
# 969     742         ['poussin', 'nicolas']   11594-1665).
# 283   S. N°          ['daumier', 'honoré']   (1808-1879).
# 61     50 a        ['boucher', 'françois']   (1703-1770).
# 2100   2499   ['ostade', 'adriaen', 'van']   (1610-1685).
# 1751   1966    ['dyck', 'anthonis', 'van']   (i599-i64i).
#
#                                      title                width  \
# 969             apollon amoureux de daphné        200±1 Q174728
# 283                      crispin et scapin        82 centimetre
# 61                             le déjeuner  65.5±0.1 centimetre
# 2100  un homme d'affaires dans son cabinet  27.8±0.1 centimetre
# 1751                      renaud et armide     109±1 centimetre
#
#                    height                                          image_url  \
# 969         155±1 Q174728  https://upload.wikimedia.org/wikipedia/commons...
# 283         61 centimetre  https://upload.wikimedia.org/wikipedia/commons...
# 61    81.5±0.1 centimetre  https://upload.wikimedia.org/wikipedia/commons...
# 2100  33.7±0.1 centimetre  https://upload.wikimedia.org/wikipedia/commons...
# 1751     133±1 centimetre  https://s3.eu-west-3.amazonaws.com/pop-photote...
#
#      wall position
# 969     S      XIV
# 283     S     VIII
# 61      S      XVI
# 2100  NaN      XXI
# 1751  NaN     XVII

# %%
# On trouve des textes de plusieurs types : absent (nan) ou des déchets (un seul à l'heure actuelle)
def clean_painting_size(text):
    #Unit : centimeter
    l = str(text).split(" ")
    if len(l) == 2:
        value, unit = l

        for match in re.finditer("±",value):
            start, end = match.span()
            value = value[:start]

        if unit in ["centimetre","Q174728"] and value.replace(".","",1).isdigit():
            return float(value)

    elif l[0] != "nan":
        print(l)

artworks_df.width = artworks_df.width.apply(clean_painting_size)
artworks_df.height = artworks_df.height.apply(clean_painting_size)
# Out:
# ['cultural', 'depictions', 'of', 'Jesus']

# %%
artworks_df.sample(5)
# Out:
#       number                                            author  \
# 1302   1195                               ['caliari', 'paolo']
# 1241  S. Nu   ['antoniazzo', 'romano', 'ant', 'aquili', 'dit']
# 76       60                          ['boulongne', 'valentin']
# 1140  (121)                             ['troyon', 'constant']
# 2116   2516                   ['poel', 'egbert', 'van', 'der']
#
#                                 life                    title  width  height  \
# 1302                   (1528-1588).             le calvaire v    NaN     NaN
# 1241   (2TUE moitié du XVe siècle).   la vierge et l'enfant v    NaN     NaN
# 76                     (1591-1634).                un concert    NaN     NaN
# 1140                   (1810-1865).      le retour à la ferme  261.0   391.0
# 2116                   (1621-1664).        la maison rustique    NaN     NaN
#
#                                               image_url wall  \
# 1302                                                NaN    S
# 1241                                                NaN    N
# 76                                                  NaN    N
# 1140  https://s3.eu-west-3.amazonaws.com/pop-photote...  NaN
# 2116                                                NaN  NaN
#
#                     position
# 1302                  I tr B
# 1241                  I tr A
# 76                       XIV
# 1140  Coll Chauchard galerie
# 2116                   XXIII

# %% [markdown]
# # Retrieve of Catalogue pictures

# %%
filename_alto = "data/alto_louvre_1923/alto_louvre_1923_{}.xml"
filename_iiif = "data/images_louvre_1923/iiif_louvre_1923_{}.jpg"

catalogue_index = range(21,193)

numbers_punct = punctuation.replace("(","").replace(")","") + "°"

def standardize_numbers(s):
    s = str(s)
    if "(" in s or ")" in s:
        s = "(" + s.strip(" )(") +")"
    return s if s == "*" else s.translate({ord(i) : None for i in punctuation + "°"})

def is_painting(number, author, row):
    #return row["number"] == number and row["author"].strip('][').split(', ')[0].replace("'","") == author
    return row["number"] == number and row["author"].lower().startswith(author)

# %%
#Retransformation des auteurs en plain text
artworks_df.author = artworks_df.author.apply(lambda l : " ".join(l.strip('][').split(', ')).replace("'","").capitalize())

#Standardisation des numéros
artworks_df.number = artworks_df.number.apply(standardize_numbers)

artworks_df["image_path"] = np.NaN

# %%
for i in tqdm(catalogue_index):
    
    im = Image.open(filename_iiif.format(i))

    xml_file = open(filename_alto.format(i),"rb")
    xml = xml_file.read()
    xml_file.close()
    
    soup = BeautifulSoup(xml,"lxml-xml")
    
    previous_was_illu = False
    for x in soup.findAll(["Illustration","TextBlock"]):
        if x.name == "Illustration":
            height = int(x['HEIGHT'])
            width = int(x['WIDTH'])
            hpos = int(x['HPOS'])
            vpos = int(x['VPOS'])
            previous_was_illu = True
        
        elif previous_was_illu:
            df_index = None
            text_list = []
            previous_was_illu = False
            if x.name == "TextBlock":
                
                for s in x.findAll("String"):
                    text_list.append(s["CONTENT"])
                    
                text = " ".join(text_list)
                
                regex_num = "^\* |^\(?\d+\)? ?[a-z]? |^S\.? [NXo].? "
                
                for match in re.finditer(regex_num, text):
                #Author and number are standardized
                    start, end = match.span()
                    author = text[end:].lower()
                    number = standardize_numbers(text[:end])
                    
                    #We keep only family name of author. Composed names are "la tour" or "de la tour"
                    if not (author.startswith("de") or author.startswith("la")):
                        author = author.split(" ")[-1]
                        
                    if number.startswith("S"):
                        number = "S N"
                    
                    # Numbers are not unique, but non unique are in parenthesis in the catalogue
                    # Unfortunately, the parenthesis are often not OCRised well
                    # Therefore, we test only with the number and then with the number and author                
                    indexes_hard = artworks_df.index\
                    [artworks_df.apply(lambda row : is_painting(number, author, row), axis = 1)].tolist()
                    
                    if len(indexes_hard) == 1:
                        df_index = indexes_hard[0]
                    
                    elif number != "S N":
                        indexes_soft = artworks_df.index\
                        [artworks_df.apply(lambda row : row["number"] == number, axis = 1)].tolist()
                        
                        if len(indexes_soft) == 1:
                            df_index = indexes_soft[0]
                
                    if df_index != None:
                        cropped = im.crop((hpos,vpos,hpos+width,vpos+height))
                        path = "data/images_paintings/{}.jpg".format(df_index)
                        cropped.save(path)
                    
                        artworks_df.loc[[df_index], ['image_path']] = path
# Out:
# HBox(children=(IntProgress(value=0, max=172), HTML(value='')))

# %% [markdown]
# # Retrieve images from URLs

# %%
#Tant qu'on cherche les urls après les images du catalogue, on va écraser les images du catalogue.
#Inverser si les images du catalogue sont les plus importantes.

# %%
for index, row in tqdm(artworks_df.dropna(subset = ["image_url"]).iterrows()):
    #if row["image_path"].isnull(): 
    path = "data/images_paintings/{}.jpg".format(index)
    urllib.request.urlretrieve(row["image_url"],path)
    artworks_df.loc[[index],["image_path"]] = path
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
artworks_df.dropna(subset = ["image_path"])
# Out:
#      number                                        author  \
# 2        2   Aligny claude françois théodore caruelle "d"
# 6     2800                            Barye antoine louis
# 9      S N                            Barye antoine louis
# 10     S N                            Barye antoine louis
# 16     995                               Bellechose henri
# ...     ...                                           ...
# 2235  2718                                   Holbein hans
# 2243  2737                     Maître de saint barthélemy
# 2244  2738                    Maître de la sainte parenté
# 2247  2724                                 Mignon abraham
# 2248  2728                                 Mignon abraham
#
#                                                    life  \
# 2                                       (r 798- 1871).
# 6                                         (1795-1875).
# 9                                         (1795-1875).
# 10                                        (1795-1875).
# 16     (travaillait à Dijon de 1415 à 1431, mort ver...
# ...                                                 ...
# 2235                                      (1497-1543).
# 2243                                (vers 1400-1 soo).
# 2244                                 (vers 1486-1520).
# 2247                                     ( 1640-1679).
# 2248                                     ( 1640-1679).
#
#                                                   title  width  height  \
# 2                                   une villa itajienne    NaN     NaN
# 6                              lions près de leur antre   49.5    38.5
# 9               le jean de paris forêt de fontainebleau   38.5    30.5
# 10                                      combat de cerfs   31.5    25.0
# 16    la dernière communion et le martyre de saint d...    NaN     NaN
# ...                                                 ...    ...     ...
# 2235  portrait d'anne de clèves reine d'angleterre q...    NaN     NaN
# 2243                     le christ descendu de la croix    NaN     NaN
# 2244  la présentation nu temple l'adoration des mage...    NaN     NaN
# 2247                                  le nid de pinsons  100.0    82.0
# 2248                   fleurs et fruits oiseaux insects   84.0    99.0
#
#                                               image_url wall  \
# 2                                                   NaN    E
# 6     https://upload.wikimedia.org/wikipedia/commons...  NaN
# 9     https://s3.eu-west-3.amazonaws.com/pop-photote...  NaN
# 10    https://s3.eu-west-3.amazonaws.com/pop-photote...  NaN
# 16                                                  NaN  NaN
# ...                                                 ...  ...
# 2235                                                NaN  NaN
# 2243                                                NaN  NaN
# 2244                                                NaN  NaN
# 2247  https://upload.wikimedia.org/wikipedia/commons...  NaN
# 2248  https://upload.wikimedia.org/wikipedia/commons...  NaN
#
#                    position                      image_path
# 2                      VIII     data/images_paintings/2.jpg
# 6                       T T     data/images_paintings/6.jpg
# 9                   S Barye     data/images_paintings/9.jpg
# 10                  S Barye    data/images_paintings/10.jpg
# 16    Musée Charles X S III    data/images_paintings/16.jpg
# ...                     ...                             ...
# 2235                 XXXIII  data/images_paintings/2235.jpg
# 2243                  XXXII  data/images_paintings/2243.jpg
# 2244                  XXXII  data/images_paintings/2244.jpg
# 2247                  XXXII  data/images_paintings/2247.jpg
# 2248                  XXXII  data/images_paintings/2248.jpg
#
# [728 rows x 10 columns]

# %% [markdown]
# # Saving

# %%
artworks_df.to_csv("data/full_final_artworks.csv")
pure_artworks_df = artworks_df.drop("number",axis=1).drop("image_url",axis=1)
pure_artworks_df.to_csv("data/final_artworks.csv")
# Out:
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Portrait_of_the_Artist_called_The_Wounded_Man_%28L%27homme_bless%C3%A9%29_by_Gustave_Courbet.jpg/1200px-Portrait_of_the_Artist_called_The_Wounded_Man_%28L%27homme_bless%C3%A9%29_by_Gustave_Courbet.jpg' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ef/David_sacr%C3%A9_roi_par_le_proph%C3%A8te_Samuel_-_Claude_Le_Lorrain_-_Mus%C3%A9e_du_Louvre_INV_4717.jpg/1200px-David_sacr%C3%A9_roi_par_le_proph%C3%A8te_Samuel_-_Claude_Le_Lorrain_-_Mus%C3%A9e_du_Louvre_INV_4717.jpg' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/JEAN_LOUIS_TH%C3%89ODORE_G%C3%89RICAULT_-_La_Balsa_de_la_Medusa_%28Museo_del_Louvre%2C_1818-19%29.jpg/1200px-JEAN_LOUIS_TH%C3%89ODORE_G%C3%89RICAULT_-_La_Balsa_de_la_Medusa_%28Museo_del_Louvre%2C_1818-19%29.jpg' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Ernest_h%C3%A9bert%2C_le_cervarole_%28le_donne_di_Cervara_di_Roma%2C_stati_romani%29%2C_1859_circa.JPG/1200px-Ernest_h%C3%A9bert%2C_le_cervarole_%28le_donne_di_Cervara_di_Roma%2C_stati_romani%29%2C_1859_circa.JPG' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/L%27Enl%C3%A8vement_des_Sabines_%E2%80%93_Nicolas_Poussin_%E2%80%93_Mus%C3%A9e_du_Louvre%2C_INV_7290_%E2%80%93_Q3110586.jpg/1200px-L%27Enl%C3%A8vement_des_Sabines_%E2%80%93_Nicolas_Poussin_%E2%80%93_Mus%C3%A9e_du_Louvre%2C_INV_7290_%E2%80%93_Q3110586.jpg' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\SysNumNoSpace\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:931: UserWarning: Ignoring URL 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/Paysage_avec_Orph%C3%A9e_et_Eurydice_%E2%80%93_Nicolas_Poussin_%E2%80%93_Mus%C3%A9e_du_Louvre%2C_INV_7307_%E2%80%93_Q6485124.jpg/1200px-Paysage_avec_Orph%C3%A9e_et_Eurydice_%E2%80%93_Nicolas_Poussin_%E2%80%93_Mus%C3%A9e_du_Louvre%2C_INV_7307_%E2%80%93_Q6485124.jpg' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %% [markdown]
# ## Saving per room

# %%
pure_artworks_df = pd.read_csv("data/final_artworks.csv")

with open("Rooms.txt",encoding = "utf-8") as f:
    for line in f:
        room = line.replace("é","e").split("/")[0].replace("\n","")
        pure_artworks_df[pure_artworks_df.position == room].to_json("data/paintings_json/{}.json".format(room), orient="records")

# %% [markdown]
# # Tests divers

# %%
l = list(map(lambda text : text.replace("\n",""),["a\n","ab\n"]))

# %%
l
# Out:
# ['a', 'ab']

# %%
len(artworks_df)
# Out:
# 2254

# %%
for k in {"w":"a"}:
    print(k)
# Out:
# w

# %%
sorted(["I","I tr A","I tr A c"])
# Out:
# ['I', 'I tr A', 'I tr A c']

# %%
#max([])

# %%
x =  {"a":"h"}.get("b")

# %%
print(x)
# Out:
# None

# %%
a, b = [1,2]

# %%
a
# Out:
# 1

# %%
"5.1".replace(".","").isdigit()
# Out:
# True

# %%
urllib.request.urlretrieve("https://gallica.bnf.fr/iiif/ark:/12148/bpt6k959891g/f1/full/full/0/native.jpg","data/images_paintings/test.jpg")
# Out:
# ('data/images_paintings/test.jpg', <http.client.HTTPMessage at 0x184fdbd6278>)

# %%
np.isnan("Jean")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0153e9236940> in <module>
# ----> 1 np.isnan("Jean")
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
